# %% [markdown]
# <a href="https://colab.research.google.com/github/jjyjung/ai/blob/gh-pages/torch_rotor_dignostics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **회전기계 고장진단 실습**
#
# **제목:** 회전기계의 고장유형 분석을 위한 AI 데이터셋 가이드북  <br>
# **Description:** 회전기계로부터 수집한 데이터를 전처리하고, 신경망 학습을 이용하여 회전기계의 정상/고장 여부 및 고장 유형을 판단하고자 함
#
# 본 자료는 정부에서 운영하는 아래의 KAMP(한국인공지능제조플랫폼)의 데이터 및 예제를 수정한 교육자료입니다.
#
# 중소벤처기업부, Korea AI Manufacturing Platform(KAMP), 회전기계 고장유형 AI 데이터셋, KAIST, 2021.12.27., https://kamp-ai.kr
#
# https://www.kamp-ai.kr/front/dataset/AiDataDetail.jsp?AI_SEARCH=&page=1&DATASET_SEQ=18

# %% [markdown]
# ※ 분석하기에 앞서 다음과 같은 가상환경이 구축되어있는지 확인해주세요. <br>
# Python 버전 : 3.7.3
#
# 위의 버전과 다른 경우 오류가 발생할 수 있습니다.

# %%
# !python --version
# Out:
# Python 3.8.15

# %% [markdown]
# # **Introduction**
#
# **제목:** 회전기계의 고장유형 분석을 위한 AI 데이터셋 가이드북  <br>
# **Description:** 회전기계로부터 수집한 데이터를 전처리하고, 신경망 학습을 이용하여 회전기계의 정상/고장 여부 및 고장 유형을 판단하고자 함

# %% [markdown]
# ## 0. 회전기계 (Rotor testbed)
#
# > 산업 현장에서 사용되는 기계 구조물은 대부분 정상 상태로 가동되며, 수집되는 데이터 역시 정상 유형이 90% 이상을 차지한다. 고장유형의 경우 자연 발생적으로 취득되는 데이터가 매우 희박하고, 실제 구조물에 인위적인 고장을 가하여 데이터를 취득하는 방식은 비효율적이므로, 이는 데이터간 불균형 문제를 초래할 수 있다. Rotor testbed를 이용하면, 여러 고장유형에 대해 특징을 분석하고, 정상 및 고장유형을 분류할 수 있는 충분한 양의 고장 데이터를 수집할 수 있다. 많은 산업 현장(발전소 등)에서 주로 사용되는 회전 설비의 진동데이터를 수집하고, 고장을 분석 및 진단하는 학습 모델을 구축하여, 이후 기술 확장을 통해 발전소나, 대규모 공장의 자동화 라인 등에 활용을 목표로 한다.
#
# ![fig.01.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.01.png)

# %% [markdown]
# (1) Controller Module
# - Rotor testbed의 controller는 수동 모드와 자동 모드 2개의 모드가 있다.
# - 수동 모드의 경우 0 ~ 3000 RPM 까지 Motor의 회전속도 조절이 가능하다.
# - 본 가이드 북에서는 수동 모드를 이용하여 Motor 회전속도가 약 1500 RPM인 경우, 진동 데이터를 구축하였다. <br>
# <br>
#
# (2) BLDC Motor
# - 본 가이드 북에서 사용된 rotor testbed의 BLDC Motor는 Brush가 제거된 형태로 브러쉬를 통한 기계적인 접촉이 없는 DC Motor이다.
# - BLDC Motor는 소음이 비교적 적으며, 출력을 세밀하게 조절할 수 있다는 장점이 있다.<br>
# <br>
#
# (3) Disks
# ![fig.02.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.02.png)
# - 본 가이드 북에서 사용된 rotor testbed는 총 2개의 aluminum disk가 있다.
# - 각각의 disk에는 회전 불균형을 구현할 수 있는 bolt 체결 홀이 있다.
# - 축의 중심으로부터 bolt 체결 홀의 거리는 약 60mm이며, Blot 체결 홀은 모두 36개이다.<br>
# <br>
#
# (4) Spec
# - 본 가이드 북에서 사용된 rotor testbed의 사양은 다음과 같다.
#
# |    구분    |                 사양                 |
# |:----------:|:------------------------------------:|
# | Size       | 673 mm (W) x 280 mm (D) x 281 mm (H) |
# | Weight     |                 25kg                 |
# | Material   |               Aluminum               |
# | Bearing    |             6202ZZ x 2EA             |
# | Motor      |  DC 12V x 0.25HP (0.2W), 0-3000 RPM  |
# | Main power |                220 VAC               |
#
# (5) Experiment environment
# - 본 가이드 북에서 사용된 rotor testbed의 실험 환경은 다음과 같다.
# - 회전 속도는 약 1500 RPM을 사용하였으며, 이 경우 기계의 최대 주파수는 25 Hz가 된다.
# - Nyquist 이론에 의해 기계의 최대 주파수의 2배 이상으로 sampling rate을 설정해야하며, 측정값의 신호를 분석하기 위해서는 5-10배 정도의 sampling rate이 요구된다. 본 가이드 북에서 사용된 RPM에 따른 적절한 sampling rate는 125-250 Hz 정도이며, 이번  실험에서는 1 kHz로 Z방향 진동 데이터(가속도)가 측정되었다.
#
# | Rotor testbed |                   |
# |:-------------:|:-----------------:|
# | RPM           |     about 1500    |
# | Sampling rate | 1 kHz (0.001 sec) |

# %% [markdown]
# ## 1. 라이브러리 / 데이터 불러오기
#
# ### 1-1. 라이브러리 불러오기
#
# 필요한 라이브러리를 불러온다.  <br>
# 오류가 발생할 경우, !pip install 패키지명을 입력하여 설치하도록 한다.
#
# (EX) !pip install numpy
#
# 본 가이드북에서 필요한 패키지들은 모두 requirements.txt에 있다.

# %%
# 아래 requirements.txt의 버전에 맞는 module을 설치하지 않았다면 오류가 발생할 수 있습니다.
# !pip install -r requirements.txt

# %%
import numpy as np
import pandas as pd
import random
import seaborn as sns
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1-2. 데이터 불러오기
#
# pd.read_csv(“데이터파일_경로명”)을 통해 csv 형태의 데이터를 pandas의 DataFrame으로 읽어 들인다.  <br>
#
# - 총 4개의 센서를 사용하므로 sensor1~sensor4로 명명하였다.  <br>
# - 센서 데이터 취득 위치는 다음과 같다.<br>
# <br>
#
# ![sensor1.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/sensor1.png)<br>
# <center>[센서 설치 위치 (사진)]</center> <br>
#
# ![sensor2.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/sensor2.png)<br>
# <center>[group 1]</center> <br>
#
# ![sensor3.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/sensor3.png)<br>
# <center>[group 2]</center> <br>
# <br>
#
# - data는 데이터 취득 시간, 정상 유형(normal)과 고장유형 1-3 (type1, type2, type3)일 경우 센서 취득값으로 구성된다.  <br>
# - 고장유형 1,2,3은 다음의 사진과 표를 확인하면 알 수 있다.<br>
#
# ![fault_type.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fault_type.png)<br>
#
# | 구분   | 특징                                                |
# |--------|-----------------------------------------------------|
# | Type 1 | Disk 2에 회전 불균형 (270도 위치에 볼트, 너트 부착) |
# | Type 2 | Support 4에 지지 불균형                             |
# | Type 3 | Type 1 + Type 2                                     |

# %%
from google.colab import drive
drive.mount('/content/gdrive')   # google drive를 google colab에 연결. 처음 실행 시, 인증 필요
# Out:
# Mounted at /content/gdrive

# %%
# 데이터를 읽어 들이고 정규화하기
dir = "/content/gdrive/My Drive/Colab Notebooks/kamp/14. Dataset_Rotor/"  ### [중요!!] Colab의 경우, 파일을 저장할 위치를 기록하시오.

# %%
# group 1의 데이터를 사용할 경우, 아래 코드를 실행합니다.
sensor1 = pd.read_csv(dir+'raw_data/g1_sensor1.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
sensor2 = pd.read_csv(dir+'raw_data/g1_sensor2.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
sensor3 = pd.read_csv(dir+'raw_data/g1_sensor3.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
sensor4 = pd.read_csv(dir+'raw_data/g1_sensor4.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])

# # group 2의 데이터를 사용할 경우, 주석을 제거하고 아래 코드를 실행합니다.
# sensor1 = pd.read_csv(dir+'raw_data/g2_sensor1.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
# sensor2 = pd.read_csv(dir+'raw_data/g2_sensor2.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
# sensor3 = pd.read_csv(dir+'raw_data/g2_sensor3.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])
# sensor4 = pd.read_csv(dir+'raw_data/g2_sensor4.csv', names = ['time', 'normal', 'type1', 'type2', 'type3'])

# %% [markdown]
# ### 1-3. 데이터 확인
# 불러온 데이터프레임의 변수 이름(normal_)을 입력하면 해당 내용을 확인해 볼 수 있다.

# %%
sensor1
# Out:
#               time    normal     type1     type2     type3
# 0         0.000000 -0.853307 -3.464579  0.555219  3.919664
# 1         0.000736 -0.740463 -2.448986 -0.234687  4.145351
# 2         0.001472 -0.138630 -1.922383 -0.009000  2.941685
# 3         0.002208  0.049443 -0.906790 -0.272301  2.603155
# 4         0.002944 -0.289088 -0.568259 -0.986978  1.361874
# ...            ...       ...       ...       ...       ...
# 190213  139.996768 -1.156354 -2.696750  0.844491 -2.109427
# 190214  139.997504 -0.930666 -1.380241  0.919720 -2.222270
# 190215  139.998240 -0.554521 -2.132532  0.731647 -2.109427
# 190216  139.998976 -1.419655 -2.433448  1.183022 -3.087405
# 190217  139.999712 -0.441677 -2.245376  1.333480 -2.184656
#
# [190218 rows x 5 columns]

# %% [markdown]
# 데이터는 140초 간의 시간을 포함하여 총 5개의 컬럼으로 이루어져 있다. <br>

# %%
print('sensor 1의 데이터 크기', sensor1.shape)
print('sensor 2의 데이터 크기', sensor2.shape)
print('sensor 3의 데이터 크기', sensor3.shape)
print('sensor 4의 데이터 크기', sensor4.shape)
# Out:
# sensor 1의 데이터 크기 (190218, 5)
# sensor 2의 데이터 크기 (184211, 5)
# sensor 3의 데이터 크기 (196079, 5)
# sensor 4의 데이터 크기 (183969, 5)

# %% [markdown]
# 그러나 데이터를 확인하면 센서마다 데이터를 취득하는 sampling rate이 다르기 때문에, 데이터의 사이즈가 다른 것을 확인할 수 있다. <br>
# 따라서 본 가이드북에서는 동일한 time interval의 데이터를 취득하기 위해 데이터를 0.001 sec 간격으로 선형보간하였다.

# %% [markdown]
# ### 1-4. 데이터 보간
# #### 데이터 선형보간
#
# 각 센서별 sampling rate은 다음과 같다. <br>
#
# | Sensor 1 | Sensor 2 | Sensor 3 | Sensor 4 |
# |:--------:|:--------:|----------|----------|
# | 0.000736 | 0.000760 | 0.000714 | 0.000761 |
#
# 계측된 센서 데이터의 계측 시간 간격 (sampling rate)이 일정하지 않은 경우, 데이터 간 정확한 비교가 어려우므로 계측 시간의 동일화를 위해 전처리(선형 보간)가 요구된다. 선형보간의 방법은 아래 그림과 같다.
# <br>
# ![interpolation.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/interpolation.png)<br>
# <br>
# 따라서 표에 나온 sampling rate을 이용하여 각 센서의 데이터를 0.001 sec 간격으로 선형보간 한다 (총 140초). <br>
#  - interpolate.interp1d() : [선형보간 함수](https://docs.scipy.org/doc/scipy/reference/generated/scipy.interpolate.interp1d.html)를 이용하였다.

# %%
from scipy import interpolate

x_new = np.arange(0, 140, 0.001)

y_new1 = []; y_new2 = []; y_new3 = []; y_new4 = []
for item in ['normal', 'type1', 'type2', 'type3']:
    f_linear1 = interpolate.interp1d(sensor1['time'], sensor1[item], kind='linear'); y_new1.append(f_linear1(x_new))
    f_linear2 = interpolate.interp1d(sensor2['time'], sensor2[item], kind='linear'); y_new2.append(f_linear2(x_new))
    f_linear3 = interpolate.interp1d(sensor3['time'], sensor3[item], kind='linear'); y_new3.append(f_linear3(x_new))
    f_linear4 = interpolate.interp1d(sensor4['time'], sensor4[item], kind='linear'); y_new4.append(f_linear4(x_new))
    
sensor1 = pd.DataFrame(np.array(y_new1).T, columns = ['normal', 'type1', 'type2', 'type3'])
sensor2 = pd.DataFrame(np.array(y_new2).T, columns = ['normal', 'type1', 'type2', 'type3'])
sensor3 = pd.DataFrame(np.array(y_new3).T, columns = ['normal', 'type1', 'type2', 'type3'])
sensor4 = pd.DataFrame(np.array(y_new4).T, columns = ['normal', 'type1', 'type2', 'type3'])

# %%
sensor1
# Out:
#           normal     type1     type2     type3
# 0      -0.853307 -3.464579  0.555219  3.919664
# 1      -0.524588 -2.260096 -0.153734  3.713601
# 2      -0.003708 -1.193805 -0.197890  2.698827
# 3      -0.297674 -0.490986 -0.972668  1.338978
# 4      -0.091203  0.790771 -0.913384  0.701167
# ...          ...       ...       ...       ...
# 139995 -1.057411 -1.389236  0.664186 -1.498190
# 139996 -0.513635 -1.368793  1.050553 -0.982626
# 139997 -1.085213 -2.281763  0.868204 -2.144997
# 139998 -0.677177 -1.887220  0.792975 -2.146224
# 139999 -1.387764 -2.427315  1.187928 -3.057968
#
# [140000 rows x 4 columns]

# %% [markdown]
# 선형 보간 작업을 위해 데이터를 센서별로 묶어두었지만, 실제 취득된 형태로 데이터를 다시 조정한다.

# %%
normal_ = pd.concat([sensor1['normal'],sensor2['normal'],sensor3['normal'],sensor4['normal']],axis=1)
type1_  = pd.concat([sensor1['type1'], sensor2['type1'], sensor3['type1'], sensor4['type1']], axis=1)
type2_  = pd.concat([sensor1['type2'], sensor2['type2'], sensor3['type2'], sensor4['type2']], axis=1)
type3_  = pd.concat([sensor1['type3'], sensor2['type3'], sensor3['type3'], sensor4['type3']], axis=1)

normal_.columns = ['s1', 's2', 's3', 's4']; type1_.columns = ['s1', 's2', 's3', 's4']
type2_.columns  = ['s1', 's2', 's3', 's4']; type3_.columns = ['s1', 's2', 's3', 's4']

# %%
normal_
# Out:
#               s1        s2        s3        s4
# 0      -0.853307  0.048823 -0.437626 -1.116226
# 1      -0.524588 -0.029477 -0.149817 -0.659694
# 2      -0.003708 -0.004751  0.280889 -0.857345
# 3      -0.297674  0.009673 -0.303281 -0.685318
# 4      -0.091203  0.096215 -0.320263 -0.303108
# ...          ...       ...       ...       ...
# 139995 -1.057411  0.587429  0.275044  0.289837
# 139996 -0.513635 -0.137874 -0.045973  0.131462
# 139997 -1.085213  0.002242 -0.164593 -0.087380
# 139998 -0.677177 -0.308897  0.288252  1.319862
# 139999 -1.387764 -0.731303  0.395425 -0.125739
#
# [140000 rows x 4 columns]

# %%
print('normal 상태 데이터의 사이즈', normal_.shape)
print('type1  상태 데이터의 사이즈', type1_.shape)
print('type2  상태 데이터의 사이즈', type2_.shape)
print('type3  상태 데이터의 사이즈', type3_.shape)
# Out:
# normal 상태 데이터의 사이즈 (140000, 4)
# type1  상태 데이터의 사이즈 (140000, 4)
# type2  상태 데이터의 사이즈 (140000, 4)
# type3  상태 데이터의 사이즈 (140000, 4)

# %% [markdown]
# ### 1-5. 데이터 분석
# #### 데이터 시각화
# 특정 시간에서의 시계열 샘플을 플롯

# %%
# python 버전 : 3.7.3 (버전에 따라, jupyter notebook에서 아래 코드가 실행되지 않을 수 있습니다)
# 실행이 되지 않는 경우, 아래 코드는 주석처리하고 넘어가도 학습에 영향을 주지 않습니다 (데이터 확인용)

plt.figure(figsize = (10, 4))
plt.scatter(range(0,300), normal_['s1'][:300], label="class = " + str(1), marker='o', s=5)
plt.scatter(range(0,300), type1_['s1'][:300], label="class = " + str(2), marker='o', s=5)
    
plt.legend(loc="lower right")
plt.xlabel("Sensor", fontsize=15)
plt.ylabel("Sensor Value", fontsize=15)
plt.show()
plt.close()

# %% [markdown]
# #### 데이터 상관분석
# df.corr()을 입력하면 센서 별 상관관계를 확인할 수 있다.

# %%
normal_.corr()
# Out:
#           s1        s2        s3        s4
# s1  1.000000 -0.007093  0.004297 -0.003377
# s2 -0.007093  1.000000 -0.002992  0.111121
# s3  0.004297 -0.002992  1.000000 -0.006434
# s4 -0.003377  0.111121 -0.006434  1.000000

# %% [markdown]
# Correlation Matrix(상관 행렬)를 통해 센서값 별 상관관계를 이미지로 확인할 수 있다.

# %%
# python 버전 : 3.7.3 (버전에 따라, jupyter notebook에서 아래 코드가 실행되지 않을 수 있습니다)
# 실행이 되지 않는 경우, 아래 코드는 주석처리하고 넘어가도 학습에 영향을 주지 않습니다 (데이터 확인용)

names = ['s1','s2','s3','s4']
cm = np.corrcoef(normal_[names].values.T)
sns.set(font_scale=0.8)
sns.heatmap(cm, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=names, xticklabels=names, cmap=plt.cm.Blues)

# %% [markdown]
# 절대값이 0.6보다 클 수록 강한 상관관계를 가지며, 0.3보다 작을 수록 약한 상관관계를 갖는다. <br>
# 양수의 경우 정(+)의 상관관계, 음수의 경우 부(-)의 상관관계를 갖는다.

# %% [markdown]
# ## 2. 데이터 전처리
#
# ### 2-1. 데이터 필터링 (Filtering)
#
# 센서로부터 취득한 데이터는 기본적으로 기계학습에 좋지 않은 영향을 주는 노이즈(Noise)가 포함되어 있다. 센서 데이터에 평균을 취하면 데이터의 노이즈를 제거할 수 있는데, 측정하려는 물리량이 시간에따라 변하는 경우에는 적절하지 않다(데이터의 동적인 변화를 모두 smoothing하는 결과). 따라서 데이터에서 노이즈를 제거하면서, 동적인 변화를 반영하는 방법으로 이동평균필터가 있으며, 본 가이드북에서는 데이터의 노이즈를 처리하기 위해 이동평균필터(Moving Average filter)를 사용하였다.
#
# - 이동평균필터 (Moving Average filter)는 python에서 [np.convolve()](https://numpy.org/doc/stable/reference/generated/numpy.convolve.html) 함수로 구현된다 (MATLAB의 filter 함수와 동일). <br>
#     - np.convolve() : 1차원 신호를 입력으로 받아, 최근 M개의 측정값들의 평균을 구한다.
#
#     - 모든 데이터의 평균이 아니라, 정해진 크기(M개)의 최근 측정값들로만 평균을 구한다. <br>
#     - 일반적으로 신호 데이터의 변동이 빠른 경우에는 M값을 작게하고, 신호 데이터의 변동이 느린 경우에는 M값을 크게한다. <br>
#     - 자세한 이론은 [자료](https://www.analog.com/media/en/technical-documentation/dsp-book/dsp_book_Ch15.pdf)를 참고하면 좋다.

# %%
M = 15

normal_s1 = np.convolve(normal_['s1'], np.ones(M), 'valid') / M; normal_s1 = normal_s1.reshape(len(normal_s1),1)
normal_s2 = np.convolve(normal_['s2'], np.ones(M), 'valid') / M; normal_s2 = normal_s2.reshape(len(normal_s2),1)
normal_s3 = np.convolve(normal_['s3'], np.ones(M), 'valid') / M; normal_s3 = normal_s3.reshape(len(normal_s3),1)
normal_s4 = np.convolve(normal_['s4'], np.ones(M), 'valid') / M; normal_s4 = normal_s4.reshape(len(normal_s4),1)

type1_s1 = np.convolve(type1_['s1'], np.ones(M), 'valid') / M; type1_s1 = type1_s1.reshape(len(type1_s1),1)
type1_s2 = np.convolve(type1_['s2'], np.ones(M), 'valid') / M; type1_s2 = type1_s2.reshape(len(type1_s2),1)
type1_s3 = np.convolve(type1_['s3'], np.ones(M), 'valid') / M; type1_s3 = type1_s3.reshape(len(type1_s3),1)
type1_s4 = np.convolve(type1_['s4'], np.ones(M), 'valid') / M; type1_s4 = type1_s4.reshape(len(type1_s4),1)

type2_s1 = np.convolve(type2_['s1'], np.ones(M), 'valid') / M; type2_s1 = type2_s1.reshape(len(type2_s1),1)
type2_s2 = np.convolve(type2_['s2'], np.ones(M), 'valid') / M; type2_s2 = type2_s2.reshape(len(type2_s2),1)
type2_s3 = np.convolve(type2_['s3'], np.ones(M), 'valid') / M; type2_s3 = type2_s3.reshape(len(type2_s3),1)
type2_s4 = np.convolve(type2_['s4'], np.ones(M), 'valid') / M; type2_s4 = type2_s4.reshape(len(type2_s4),1)

type3_s1 = np.convolve(type3_['s1'], np.ones(M), 'valid') / M; type3_s1 = type3_s1.reshape(len(type3_s1),1)
type3_s2 = np.convolve(type3_['s2'], np.ones(M), 'valid') / M; type3_s2 = type3_s2.reshape(len(type3_s2),1)
type3_s3 = np.convolve(type3_['s3'], np.ones(M), 'valid') / M; type3_s3 = type3_s3.reshape(len(type3_s3),1)
type3_s4 = np.convolve(type3_['s4'], np.ones(M), 'valid') / M; type3_s4 = type3_s4.reshape(len(type3_s4),1)

# %%
normal_temp = np.concatenate((normal_s1,normal_s2,normal_s3,normal_s4), axis = 1)
type1_temp = np.concatenate((type1_s1,type1_s2,type1_s3,type1_s4), axis = 1)
type2_temp = np.concatenate((type2_s1,type2_s2,type2_s3,type2_s4), axis = 1)
type3_temp = np.concatenate((type3_s1,type3_s2,type3_s3,type3_s4), axis = 1)

# %% [markdown]
# ### 2-2. 데이터 정규화
#
# 데이터 (140,000,4)의 센서 값들이 다양한 Range를 갖는다. <br>
# 이는 신경망 학습에 그대로 이용하기엔 적절하지 않다. <br>
# 일반적으로 인풋 값들을 정규화(Normalization)하는데, 본 가이드북에서는 Min-max normalization 활용하여 진행하였다. <br>
# Min-max normalization는 데이터를 0과 1 사이의 값으로 scaling한다.
#
# 1) Normal data의 최대값(max)과 최소값(min)을 구한다. <br>
# 2) 정규화할 데이터 값(x)과 앞서 구한 최대값(Xmax), 최소값(Xmin)을 다음의 식에 대입한다.
# ![minmax.png](image/minmax.png)
# 3) 이와 같은 식은 sklearn.preprocessing의 MinMaxScaler에 구현되어있다.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(normal_)
normal = scaler.transform(normal_temp)
type1  = scaler.transform(type1_temp)
type2  = scaler.transform(type2_temp)
type3  = scaler.transform(type3_temp)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# 1) MinMaxScaler.fit을 통해 normal data의 min, max를 구한다. <br>
# 2) MinMaxScaler.transform를 통해 각 데이터를 normal data의 min, max 값으로 정규화한다.
#
# 데이터 확인

# %%
print(normal)
print('------------------------------------------------')
print('normal data size = ', normal.shape)
# Out:
# [[0.57598822 0.50553898 0.56439491 0.44551164]
#  [0.60960317 0.50513674 0.58169332 0.44848001]
#  [0.62990663 0.5047345  0.59547186 0.46260474]
#  ...
#  [0.51874981 0.50106998 0.60999194 0.50715712]
#  [0.49713039 0.51588928 0.6074125  0.53093987]
#  [0.45708747 0.52025039 0.60349765 0.53976513]]
# ------------------------------------------------
# normal data size =  (139986, 4)

# %% [markdown]
# 이동평균 필터링 후에 데이터의 사이즈를 조정한다(옵션, 본 가이드 북에서는 숫자를 쉽게 확인할 수 있도록 함). <br>
# rotor testbed 가동 후 몇 초간 (약 30초)의 데이터를 탈락시키고 이후 데이터를 사용하였다(steady state). <br>
#
# 데이터 사이즈를 (100000, 4)로 맞춰주었다.

# %%
normal = normal[30000:130000][:]
type1  = type1[30000:130000][:]
type2  = type2[30000:130000][:]
type3  = type3[30000:130000][:]

# %%
print(normal)
print('------------------------------------------------')
print('normal data size = ', normal.shape)
# Out:
# [[0.42588581 0.56360116 0.59076635 0.45259554]
#  [0.39980512 0.54859132 0.57699856 0.4486034 ]
#  [0.38031149 0.54190146 0.57998374 0.44726771]
#  ...
#  [0.48028648 0.53048363 0.62114742 0.51024851]
#  [0.44818273 0.53444251 0.62103995 0.49126006]
#  [0.42832757 0.5501298  0.60917718 0.47827626]]
# ------------------------------------------------
# normal data size =  (100000, 4)

# %% [markdown]
# ### 2-3. 데이터 분배
#
# Normal, type1-3 abnormal data를 1:1:1:1의 비율로 각각 training data, validation data, test data로 나눈다. <br>
# 이 때, 학습 : 검증 : 테스트 = 6 : 2 : 2 이다.

# %%
# 데이터 분배
normal_train = normal[:][:60000]; normal_valid = normal[:][60000:80000]; normal_test = normal[:][80000:]
type1_train  = type1[:][:60000];  type1_valid  = type1[:][60000:80000];  type1_test  = type1[:][80000:]
type2_train  = type2[:][:60000];  type2_valid  = type2[:][60000:80000];  type2_test  = type2[:][80000:]
type3_train  = type3[:][:60000];  type3_valid  = type3[:][60000:80000];  type3_test  = type3[:][80000:]

train = np.concatenate((normal_train,type1_train,type2_train,type3_train))
valid = np.concatenate((normal_valid,type1_valid,type2_valid,type3_valid))
test = np.concatenate((normal_test,type1_test,type2_test,type3_test))

# %%
print("train data의 형태:", train.shape)
print("valid data의 형태:", valid.shape)
print(" test data의 형태:", test.shape)
# Out:
# train data의 형태: (240000, 4)
# valid data의 형태: (80000, 4)
#  test data의 형태: (80000, 4)

# %% [markdown]
# #### 데이터 라벨 부여 및 뒤섞기
# Normal data = 0 <br>
# Type1  data = 1 <br>
# Type2  data = 2 <br>
# Type3  data = 3 <br>
# 학습을 위해 각 데이터에 라벨을 부여하고, 학습을 위해 뒤섞는다. <br>
# - train data는 train epoch마다 랜덤한 순서로 학습하기 위해 dataloader를 이용하여 shuffle<br>
# - valid data와 test data는 실행할 때 고정된 임의의 순서로 가져오기 위해 shuffle 함수 사용<br>

# %%
train_label = np.concatenate((np.full((60000,1),0),np.full((60000,1),1),np.full((60000,1),2),np.full((60000,1),3)))
valid_label = np.concatenate((np.full((20000,1),0),np.full((20000,1),1),np.full((20000,1),2),np.full((20000,1),3)))
test_label = np.concatenate((np.full((20000,1),0),np.full((20000,1),1),np.full((20000,1),2),np.full((20000,1),3)))

# %%
idx = np.arange(train.shape[0]); np.random.shuffle(idx); train = train[:][idx]; 
train_label = train_label[:][idx]

idx_v = np.arange(valid.shape[0]); np.random.shuffle(idx_v); valid = valid[:][idx_v]; 
valid_label = valid_label[:][idx_v]

idx_t = np.arange(test.shape[0]); np.random.shuffle(idx_t); test = test[:][idx_t]; 
test_label = test_label[:][idx_t]

# %% [markdown]
# 신경망 구조에 입력하기 전 data를 tensor 형태로 변경

# %%
x_train = torch.from_numpy(train).float()
y_train = torch.from_numpy(train_label).float().T[0]

x_valid = torch.from_numpy(valid).float()
y_valid = torch.from_numpy(valid_label).float().T[0]

x_test = torch.from_numpy(test).float()
y_test = torch.from_numpy(test_label).float().T[0]

# %%
print("변경 전")
train
# Out:
# 변경 전
# array([[0.67707628, 0.43270422, 0.59257561, 0.47558705],
#        [0.29611452, 0.65107654, 0.59095536, 0.54483126],
#        [0.72106098, 0.36729787, 0.61884304, 0.59289582],
#        ...,
#        [0.54721291, 0.51912732, 0.62135599, 0.4676334 ],
#        [0.63962282, 0.49002082, 0.57138576, 0.59663027],
#        [0.35863447, 0.45308909, 0.56654978, 0.46680803]])

# %%
print("변경 후")
x_train
# Out:
# 변경 후
# tensor([[0.6771, 0.4327, 0.5926, 0.4756],
#         [0.2961, 0.6511, 0.5910, 0.5448],
#         [0.7211, 0.3673, 0.6188, 0.5929],
#         ...,
#         [0.5472, 0.5191, 0.6214, 0.4676],
#         [0.6396, 0.4900, 0.5714, 0.5966],
#         [0.3586, 0.4531, 0.5665, 0.4668]])

# %%
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

train = TensorDataset(x_train, y_train)
train_dataloader = DataLoader(train, batch_size = 5000, shuffle=True)

valid = TensorDataset(x_valid, y_valid)
valid_dataloader = DataLoader(valid, batch_size = len(x_valid), shuffle=False)

test = TensorDataset(x_test, y_test)
test_dataloader = DataLoader(test, batch_size = len(x_valid), shuffle=False)

# %% [markdown]
# ## 3. 모델 구축
#
# ### 3-1. 심층신경망 (DNN)
#
# 심층신경망(DNN)은 인공신경망에서 모델 내 은닉층을 많이 늘려서 학습의 결과를 향상시키는 방법이다. <br>
# 라벨이 있는 데이터이므로, supervised learning을 통해 classification을 위한 학습 모델을 구축한다.
#
# pytorch의 network는 class 형태로 구성된다.
# 자세한 내용은 pytorch 공식 사이트에서 확인 가능하다(링크 포함).
#
# 1. ```KAMP_DNN을 구현하는 class는 nn.Module class를 상속한다.```
# 2. ```__init__에서는 신경망 layer를 초기화한다.```
#    -   nn.Linear() : [선형계층](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)으로 weight와 bias을 사용하여 입력에 선형 변환을 적용하는 모듈
#        - in_features  : 신경망으로 입력되는 size
#        - out_features : 신경망에서 출력되는 size <br>
#        <br>
#    -   nn.Relu() : [ReLU 활성화함수 계층](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html)으로 비선형 활성화를 통해 모델의 입력과 출력 사이에 복잡한 관계(mapping)를 만든다. <br>
#        비선형 활성화는 nn.Linear로 이루어진 선형계층에 비선형성을 도입하여 신경망이 보다 복잡한 현상을 학습할 수 있도록 돕는다.<br>
#        <br>
#    -   nn.Dropout() : [드롭아웃 계층](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html)으로 신경망의 일부를 의도적으로 학습에서 제외함으로써 모델을 일반화하는 역할을 한다(과적합 방지). <br>
#        ![fig.03.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.03.png)<br>
#         <br>
#    -   input_size = 4 : 계측되는 sensor 값들 4개
#    -   ouput_size = 4 : 정상 + 고장유형 개수 4개
#    -   hidden_size는 본 가이드 북에서는 100으로 하였으나, parameter study를 통해 조절
#    -   layer의 개수는 데이터에 따라 조절 (여기서는 2~4개의 layer 사용) <br>
#    <br>
# 3. ```forward 에서는 초기화된 레이어에 입력 데이터를 전달하고 최종 출력을 얻는다.```

# %%
# layer를 더 늘리고 싶은 경우 주석을 제거하고 사용합니다.

class KAMP_DNN(nn.Module):
    def __init__(self):
        super(KAMP_DNN, self).__init__()
        self.layer1   = nn.Linear(in_features = 4, out_features = 100)
        self.layer2   = nn.Linear(in_features = 100, out_features = 100)
        self.layer3   = nn.Linear(in_features = 100, out_features = 100)
        self.layer4   = nn.Linear(in_features = 100, out_features = 4)
        
        self.dropout  = nn.Dropout(0.2)
        self.relu     = nn.ReLU()

    def forward(self, input):
        out = self.layer1(input)
        out = self.relu(out)
        out = self.dropout(out)
        
        out = self.layer2(out)
        out = self.relu(out)
        out = self.dropout(out)
        
        out = self.layer3(out)
        out = self.relu(out)
        out = self.dropout(out)
        
        out = self.layer4(out)
        return out
    
model_check = KAMP_DNN()
print(model_check)
# Out:
# KAMP_DNN(
#   (layer1): Linear(in_features=4, out_features=100, bias=True)
#   (layer2): Linear(in_features=100, out_features=100, bias=True)
#   (layer3): Linear(in_features=100, out_features=100, bias=True)
#   (layer4): Linear(in_features=100, out_features=4, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (relu): ReLU()
# )

# %% [markdown]
# ### 3-2. 합성곱신경망 (CNN)
# 합성곱신경망(CNN)은 인공신경망의 한 종류이며, 주로 Matrix 데이터나 이미지 데이터에 대하여 특징을 추출하는데에 쓰인다. <br>
# 라벨이 있는 데이터이므로, supervised learning을 통해 classification을 위한 학습 모델을 구축한다. <br>
#
# pytorch의 network는 class 형태로 구성된다. 자세한 내용은 pytorch 공식 사이트에서 확인 가능하다(링크 포함).
#
# 1. ```KAMP_CNN을 구현하는 class는 nn.Module class를 상속한다.```
# 2. ```__init__에서는 신경망 layer를 초기화한다.```
#    -   nn.Sequential() : 계층이 순차적으로 실행되도록 담는 [sequential container](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html)로서 연산순서를 원하는데로 다음 계층으로 전달할 수 있다. <br>
#    <br>
#    -   nn.Conv1d() : [1차원 합성곱 계층](https://pytorch.org/docs/stable/generated/torch.nn.Conv1d.html)으로서 주로 센서와 같은 시계열 데이터에 많이 사용된다.
#        - 이미지처리에서 주로 사용되는 2차원 합성곱 계층은 filter가 가로와 세로로 이동하면서 연산된다.
#        - 반면 1차원 합성곱 계층의 연산은 filter가 가로로만 이동하면서 output을 계산한다. <br>
#        ![fig.04.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.04.png)<br>
#        <br>
#        - input shape : torch.nn.conv1d의 입력 사이즈는 [Batch size, Input channel size, sequence length]이다. <br>
#            데이터를 학습하는 방식에 따라 입력 사이즈를 조절할 수 있으며, 본 가이드 북의 입력 사이즈는 다음과 같다. <br>
#            [Batch size = 80000, Input channel size = 1, sequence length = 4]
#             ![fig.05.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.05.png)<br>
#        <br>
#        - in_channels : 신경망으로 입력되는 데이터의 channel size (컬러 이미지의 경우 첫 계층에서 RGB = 3을 사용)<br>
#        - out_channels : 신경망에서 출력되는 데이터의 channel size (본 가이드북에서는 100을 사용하였으나 parameter study로 조절)<br>
#        - kernel_size : 특징을 추출하는 filter의 size<br>
#        - stride : kernel(filter)이 적용될 때, 이동하는 step size (2 이상인 경우, 데이터 size가 줄어든다)<br>
#        - padding : 데이터 가장자리에 0을 채워 넣는 역할 (default는 valid)<br>
#            {'vaild' : padding 안함, 'same' : 입력과 출력 size가 동일하도록 zero-padding, 혹은 다른 값}<br>
#        - bias : bias term의 사용 여부 (default는 True)<br>
#        <br>
#    -   nn.BatchNorm1d() : [Batch 차원에서의 정규화 계층](https://pytorch.org/docs/stable/generated/torch.nn.BatchNorm1d.html)으로 학습의 안정화에 기여한다.<br>
#        <br>
#    -   nn.Relu() : [ReLU 활성화함수 계층](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html)으로 비선형 활성화를 통해 모델의 입력과 출력 사이에 복잡한 관계(mapping)를 만든다. <br>
#        비선형 활성화는 nn.Linear로 이루어진 선형계층에 비선형성을 도입하여 신경망이 보다 복잡한 현상을 학습할 수 있도록 돕는다.<br>
#        <br>
#    -   nn.MaxPool1d() : [subsampling 계층](https://pytorch.org/docs/stable/generated/torch.nn.MaxPool1d.html)으로 데이터의 특징을 보존하면서 크기를 줄여주는 역할을 한다 (과적합 방지에 사용).<br>
#        평균적인 정보를 담는 average pooling과 가장 큰 정보를 담는 max pooling이 있다.
#        nn.Conv1d() 계층의 stride와 비슷한 역할을 하지만, 모든 정보를 가진 상태로 정보를 희석한다는 특징을 갖는다.
#    <br>
#    -   nn.Dropout() : [드롭아웃 계층](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html)으로 신경망의 일부를 의도적으로 학습에서 제외함으로써 모델을 일반화하는 역할을 한다(과적합 방지).<br>
#    <br>
#    -   layer의 개수는 데이터에 따라 조절 (여기서는 2~4개의 layer 사용) <br>
#    <br>
# 3. ```forward 에서는 초기화된 레이어에 입력 데이터를 전달하고 최종 출력을 얻는다.```

# %%
# layer를 더 늘리고 싶은 경우 주석을 제거하고 사용합니다.

class KAMP_CNN(nn.Module):
    def __init__(self):
        super(KAMP_CNN, self).__init__()
        self.conv1 = nn.Sequential(
        nn.Conv1d(in_channels=1, out_channels=100, kernel_size=2, stride=1, padding='same'),
        nn.BatchNorm1d(100),
        nn.ReLU(),
        nn.MaxPool1d(kernel_size=1, stride=1),
        nn.Dropout(p=0.2))
        
#         self.conv2 = nn.Sequential(
#         nn.Conv1d(in_channels=100, out_channels=100, kernel_size=2, stride=1, padding='same'),
#         nn.BatchNorm1d(100),
#         nn.ReLU(),
#         nn.MaxPool1d(kernel_size=1, stride=1),
#         nn.Dropout(p=0.2))
        
#         self.conv3 = nn.Sequential(
#         nn.Conv1d(in_channels=100, out_channels=100, kernel_size=2, stride=1, padding='same'),
#         nn.BatchNorm1d(100),
#         nn.ReLU(),
#         nn.MaxPool1d(kernel_size=1, stride=1),
#         nn.Dropout(p=0.2))
        
        self.conv4 = nn.Sequential(
        nn.Conv1d(in_channels=100, out_channels=4, kernel_size=2, stride=1, padding='same'),
        nn.BatchNorm1d(4),
        nn.ReLU(),
        nn.MaxPool1d(kernel_size=1, stride=1))
        
        self.final_pool = nn.AdaptiveAvgPool1d(1)
        self.linear = nn.Linear(4, 4)

    def forward(self, input):
        # 초기 input shape은 [80000, 4]이므로 input의 2번째 열(python에서는 1로 나타냄)에 채널 축을 확장 시킨다.
        input = input.unsqueeze(1)
        out = self.conv1(input)
#         out = self.conv2(out)
#         out = self.conv3(out)
        out = self.conv4(out)
        out = self.final_pool(out)
        out = self.linear(out.squeeze(-1))
        return out

model_check = KAMP_CNN()
print(model_check)
# Out:
# KAMP_CNN(
#   (conv1): Sequential(
#     (0): Conv1d(1, 100, kernel_size=(2,), stride=(1,), padding=same)
#     (1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.2, inplace=False)
#   )
#   (conv4): Sequential(
#     (0): Conv1d(100, 4, kernel_size=(2,), stride=(1,), padding=same)
#     (1): BatchNorm1d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=False)
#   )
#   (final_pool): AdaptiveAvgPool1d(output_size=1)
#   (linear): Linear(in_features=4, out_features=4, bias=True)
# )

# %% [markdown]
# 아래의 그림은 본 가이드 북에서 사용한 kernel과 stride size가 어떻게 작용하는지 시각적으로 확인하기 위한 예시를 나타내었다.
# ![fig.06.png](https://raw.githubusercontent.com/jjyjung/ai/gh-pages/img/fig.06.png)
#
# 다음의 코드로 확인 가능하다 (out_channels = 4).

# %%
print('--------------------------------------------------------------------')
input = torch.tensor([[[0.0, 6.0, 9.0, 1.0]]])
print('"input is same below."')
print(input)
print('--------------------------------------------------------------------')
model = nn.Conv1d(1, 4, 2, bias = False)
model.weight.data = torch.zeros(model.weight.data.size())
model.weight.data[:, :, :2] = 1
print('"kernal is same below."')
print(model.weight.data)
print('--------------------------------------------------------------------')
output = model(input)
print('"output is same below (without bias)."')
print(output)
print('--------------------------------------------------------------------')
model1 = nn.Conv1d(1, 4, 2)
model1.weight.data = torch.zeros(model1.weight.data.size())
model1.weight.data[:, :, :2] = 1
output = model1(input)
print('"output is same below (with bias)."')
print(output)
print('--------------------------------------------------------------------')
# Out:
# --------------------------------------------------------------------
# "input is same below."
# tensor([[[0., 6., 9., 1.]]])
# --------------------------------------------------------------------
# "kernal is same below."
# tensor([[[1., 1.]],
#
#         [[1., 1.]],
#
#         [[1., 1.]],
#
#         [[1., 1.]]])
# --------------------------------------------------------------------
# "output is same below (without bias)."
# tensor([[[ 6., 15., 10.],
#          [ 6., 15., 10.],
#          [ 6., 15., 10.],
#          [ 6., 15., 10.]]], grad_fn=<ConvolutionBackward0>)
# --------------------------------------------------------------------
# "output is same below (with bias)."
# tensor([[[ 6.4959, 15.4959, 10.4959],
#          [ 5.7920, 14.7920,  9.7920],
#          [ 5.4475, 14.4475,  9.4475],
#          [ 6.0115, 15.0115, 10.0115]]], grad_fn=<ConvolutionBackward0>)
# --------------------------------------------------------------------

# %% [markdown]
# ### 3-3. 순환신경망 (RNN)
# 순환신경망 (RNN, LSTM, GRU)은 과거의 학습을 가중치를 통해 현재 학습에 반영하는 특징이 있다. <br>
# 따라서 순차적으로 변화하는 시계열(time series) 데이터의 학습에 탁월한 효과를 갖는다.
# 본 가이드북에서는 pytorch의 LSTM 모듈을 사용하였다.
#
# 1. ```KAMP_CNN을 구현하는 class는 nn.Module class를 상속한다.```
# 2. ```__init__에서는 신경망 layer를 초기화한다.``` <br>
#
# | 구분 | 특징                                 |
# |------|--------------------------------------|
# | RNN  | 가장 기본적인 모델                   |
# | LSTM | RNN에서 gradient vanishing 문제 해소 |
# | GRU  | LSTM보다 빠른 속도                   |
#
#    -   nn.LSTM() : [LSTM 순환신경망 계층](https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html) (Long Short-Term Memory Network)으로서 주로 시계열 데이터 처리에 많이 사용된다. <br>
#       - input shape : torch.nn.LSTM의 입력 사이즈는 [Batch size, sequence length, input size] 이다.
#        <br>
#        데이터를 학습시키는 방식에 따라 입력 사이즈를 조절할 수 있으며, 본 가이드 북의 입력 사이즈는 다음과 같다.<br>
#        [Batch size = 80000, sequence length = 1, input size = 4]<br>
#        <br>
#        - input size : 신경망으로 입력되는 데이터의 특징 개수 (time step 아님)
#        - hidden size : 은닉층에서 사용할 특징 개수 (적절한 값 사용)
#        - batch_first : [batch, sequence, feature]로 input data 사용 (default는 False, [sequence, batch, feature])
#        - num_layers : LSTM layer 개수 조절 옵션 (여기서는 4개의 layer 사용)
#        - dropout :  드롭아웃 옵션 (과적합 방지, default는 0)<br>
#    <br>
#    -   nn.Linear() : 선형계층으로 weight와 bias을 사용하여 입력에 선형 변환을 적용하는 모듈 <br>
#        여기서는 LSTM의 fully connected layer로 사용하였다.<br>
#        - in_features  : 신경망으로 입력되는 size
#        - out_features : 신경망에서 출력되는 size <br>
#         <br>
#
# 3. ```forward 에서는 초기화된 레이어에 입력 데이터를 전달하고 최종 출력을 얻는다.```

# %%
import torch
import torch.nn as nn

class KAMP_RNN(nn.Module):
    def __init__(self):
        super(KAMP_RNN, self).__init__()
        self.lstm    = nn.LSTM(input_size = 4, hidden_size = 100, num_layers = 2, batch_first=True, dropout = 0.2)
        self.fc      = nn.Linear(in_features = 100, out_features = 4)

    def forward(self, input):
        # 초기 input shape은 [80000, 4]이므로 input의 2번째 열(python에서는 1로 나타냄)에 채널 축을 확장 시킨다.
        input = input.unsqueeze(1)
        out, _ = self.lstm(input)
        # FC 계층에 입력하기 위해 채널 축을 축소한다.
        out = out.view(-1,100)
        output = self.fc(out)
        return output
    
model_check = KAMP_RNN()
print(model_check)
# Out:
# KAMP_RNN(
#   (lstm): LSTM(4, 100, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=100, out_features=4, bias=True)
# )

# %% [markdown]
# ## 4. 모델 학습

# %%
def train_model(model, criterion, optimizer, num_epoch, train_dataloader, PATH):
    loss_values = []
    loss_values_v = []
    check = 0; accuracy_past = 0
    for epoch in range(1, num_epochs + 1):
        #---------------------- 모델 학습 ---------------------#
        model.train()
        batch_number = 0
        running_loss = 0.0
        for batch_idx, samples in enumerate(train_dataloader):
            x_train, y_train = samples
            
            # 변수 초기화
            optimizer.zero_grad() 
            y_hat = model.forward(x_train)
            loss = criterion(y_hat,y_train.long())
            # 모델의 파라미터와 관련된 loss의 그래디언트 계산
            loss.backward()
            # 신경망 가중치(parameter) 업데이트
            optimizer.step()
            
            running_loss += loss.item()
            batch_number += 1
        loss_values.append(running_loss / batch_number)
        #------------------------------------------------------#
        
        #---------------------- 모델 검증 ---------------------#
        model.eval()
        accuracy = 0.0
        total = 0.0
        for batch_idx, data in enumerate(valid_dataloader):
            x_valid, y_valid = data
            
            v_hat = model.forward(x_valid)
            v_loss = criterion(v_hat,y_valid.long())

            _, predicted = torch.max(v_hat.data, 1)
            total += y_valid.size(0)
            accuracy += (predicted == y_valid).sum().item()
        loss_values_v.append(loss.item())
        accuracy = (accuracy / total)
        #------------------------------------------------------#
        # Check for early stopping
        
        if epoch % 1 == 0:
            print('[Epoch {}/{}] [Train_Loss: {:.6f} /Valid_Loss: {:.6f}]'.format(epoch, num_epochs, loss.item(),v_loss.item()))
            print('[Epoch {}/{}] [Accuracy  : {:.6f}]'.format(epoch, num_epochs, accuracy))
            
        if accuracy_past > accuracy:
            check += 1
        else:
            check = 0
            accuracy_past = accuracy
        
        if check > 50:
            print('This is time to do early stopping')
            break
                
    torch.save(model, PATH + 'model.pt')
    print("모델 저장:", PATH + 'model.pt')
    return loss_values, loss_values_v

# %% [markdown]
# ### 4-1. 심층신경망 (DNN) 모델 학습

# %% [markdown]
# ### 4-2. 합성곱신경망 (CNN) 모델 학습

# %% [markdown]
# ### 4-3. 순환신경망 (RNN) 모델 학습

# %% [markdown]
# ## 5. 모델 평가

# %% [markdown]
# #### 모델 평가

# %%
def test_model(model, PATH):
    model = torch.load(PATH + 'model.pt')
    #---------------------- 모델 시험 ---------------------#
    model.eval()
    total = 0.0
    accuracy = 0.0
    for batch_idx, data in enumerate(test_dataloader):
        x_test, y_test = data
            
        t_hat = model(x_test)
        _, predicted = torch.max(t_hat.data, 1)
        total += y_test.size(0)
        accuracy += (predicted == y_test).sum().item()
    accuracy = (accuracy / total)
    #------------------------------------------------------#
    print(accuracy)

# %% [markdown]
# #### 혼동 행렬 (Confusion matrix)

# %%
from sklearn.metrics import classification_report, confusion_matrix

def draw_confusion_matrix(model, xt, yt, PATH):
    y_pred = []; y_true = []
    
    model.eval()
    y_hat = model(xt)
    output = (torch.max(torch.exp(y_hat), 1)[1]).data.cpu().numpy()
    y_pred.extend(output) # Save Prediction
    
    labels = y_test.data.cpu().numpy()
    y_true.extend(labels) # Save Truth
    
    # 분류 항목
    classes = ('Normal', 'Type1', 'Type2', 'Type3')
    
    # Confussion Matrix 생성
    plt.figure(figsize = (7,5))
    dlen = float(len(x_test)) # test data 크기 : 여기서는 80000
    
    cm = confusion_matrix(y_true, y_pred)
    df_cm = pd.DataFrame(cm/dlen, index = [i for i in classes],columns = [i for i in classes])
    
    # annot : 각 셀의 데이터 값을 나타내는 옵션
    sns.heatmap(df_cm, annot=True, cmap=plt.cm.Blues)
    plt.title("Confusion Matrix", size=24, fontweight='bold')
    plt.xlabel("Predicted Label", size=16); plt.ylabel("Actual Label", size=16)
    # 각 축의 font 조정
    plt.rc('xtick', labelsize=12); plt.rc('ytick', labelsize=12); plt.yticks(rotation=0)
    # 결과 저장
    plt.savefig(PATH + 'cm_output.png')

# %% [markdown]
# #### 손실(Loss) 그래프

# %%
def plot_loss_graph(loss_values, loss_values_v):
    plt.figure()
    plt.plot(loss_values)
    plt.plot(loss_values_v)
    plt.title("Training & Validation Loss")
    plt.ylabel("loss", fontsize="large")
    plt.xlabel("epoch", fontsize="large")
    plt.legend(["train", "validation"])
    plt.tight_layout()
    # 결과 저장
    plt.savefig(PATH + 'lossplot_output.png')

# %% [markdown]
# ### 5-1. 심층신경망 (DNN) 모델 성능 평가

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

DNN_model = KAMP_DNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(DNN_model.parameters())
PATH = dir+'dnn_'

DNN_loss_values, DNN_loss_values_v = train_model(DNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

DNN_model = KAMP_DNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(DNN_model.parameters())
PATH = dir+'dnn_'

DNN_loss_values, DNN_loss_values_v = train_model(DNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)
# Out:
# [Epoch 1/1000] [Train_Loss: 1.191477 /Valid_Loss: 1.145718]
# [Epoch 1/1000] [Accuracy  : 0.434075]
# [Epoch 2/1000] [Train_Loss: 0.945126 /Valid_Loss: 0.899004]
# [Epoch 2/1000] [Accuracy  : 0.489912]
# [Epoch 3/1000] [Train_Loss: 0.889309 /Valid_Loss: 0.850821]
# [Epoch 3/1000] [Accuracy  : 0.493900]
# [Epoch 4/1000] [Train_Loss: 0.869215 /Valid_Loss: 0.840918]
# [Epoch 4/1000] [Accuracy  : 0.510062]
# [Epoch 5/1000] [Train_Loss: 0.861877 /Valid_Loss: 0.830266]
# [Epoch 5/1000] [Accuracy  : 0.518288]
# [Epoch 6/1000] [Train_Loss: 0.838445 /Valid_Loss: 0.826400]
# [Epoch 6/1000] [Accuracy  : 0.521487]
# [Epoch 7/1000] [Train_Loss: 0.842657 /Valid_Loss: 0.813215]
# [Epoch 7/1000] [Accuracy  : 0.534350]
# [Epoch 8/1000] [Train_Loss: 0.826020 /Valid_Loss: 0.800785]
# [Epoch 8/1000] [Accuracy  : 0.548963]
# [Epoch 9/1000] [Train_Loss: 0.812838 /Valid_Loss: 0.778214]
# [Epoch 9/1000] [Accuracy  : 0.587250]
# [Epoch 10/1000] [Train_Loss: 0.775512 /Valid_Loss: 0.753990]
# [Epoch 10/1000] [Accuracy  : 0.613675]
# [Epoch 11/1000] [Train_Loss: 0.754323 /Valid_Loss: 0.726191]
# [Epoch 11/1000] [Accuracy  : 0.641162]
# [Epoch 12/1000] [Train_Loss: 0.741508 /Valid_Loss: 0.707221]
# [Epoch 12/1000] [Accuracy  : 0.653238]
# [Epoch 13/1000] [Train_Loss: 0.719569 /Valid_Loss: 0.697536]
# [Epoch 13/1000] [Accuracy  : 0.660775]
# [Epoch 14/1000] [Train_Loss: 0.723404 /Valid_Loss: 0.691307]
# [Epoch 14/1000] [Accuracy  : 0.663500]
# [Epoch 15/1000] [Train_Loss: 0.710732 /Valid_Loss: 0.679054]
# [Epoch 15/1000] [Accuracy  : 0.668500]
# [Epoch 16/1000] [Train_Loss: 0.691991 /Valid_Loss: 0.671455]
# [Epoch 16/1000] [Accuracy  : 0.675175]
# [Epoch 17/1000] [Train_Loss: 0.668922 /Valid_Loss: 0.668827]
# [Epoch 17/1000] [Accuracy  : 0.675288]
# [Epoch 18/1000] [Train_Loss: 0.677465 /Valid_Loss: 0.661683]
# [Epoch 18/1000] [Accuracy  : 0.680187]
# [Epoch 19/1000] [Train_Loss: 0.684159 /Valid_Loss: 0.657863]
# [Epoch 19/1000] [Accuracy  : 0.684875]
# [Epoch 20/1000] [Train_Loss: 0.667350 /Valid_Loss: 0.653789]
# [Epoch 20/1000] [Accuracy  : 0.685275]
# [Epoch 21/1000] [Train_Loss: 0.660991 /Valid_Loss: 0.652441]
# [Epoch 21/1000] [Accuracy  : 0.687937]
# [Epoch 22/1000] [Train_Loss: 0.646980 /Valid_Loss: 0.648497]
# [Epoch 22/1000] [Accuracy  : 0.696450]
# [Epoch 23/1000] [Train_Loss: 0.638674 /Valid_Loss: 0.645341]
# [Epoch 23/1000] [Accuracy  : 0.699625]
# [Epoch 24/1000] [Train_Loss: 0.643079 /Valid_Loss: 0.644439]
# [Epoch 24/1000] [Accuracy  : 0.700125]
# [Epoch 25/1000] [Train_Loss: 0.640775 /Valid_Loss: 0.640988]
# [Epoch 25/1000] [Accuracy  : 0.706575]
# [Epoch 26/1000] [Train_Loss: 0.631381 /Valid_Loss: 0.638057]
# [Epoch 26/1000] [Accuracy  : 0.707488]
# [Epoch 27/1000] [Train_Loss: 0.628585 /Valid_Loss: 0.638434]
# [Epoch 27/1000] [Accuracy  : 0.704862]
# [Epoch 28/1000] [Train_Loss: 0.627901 /Valid_Loss: 0.631600]
# [Epoch 28/1000] [Accuracy  : 0.711150]
# [Epoch 29/1000] [Train_Loss: 0.633308 /Valid_Loss: 0.631086]
# [Epoch 29/1000] [Accuracy  : 0.711287]
# [Epoch 30/1000] [Train_Loss: 0.619072 /Valid_Loss: 0.625033]
# [Epoch 30/1000] [Accuracy  : 0.715750]
# [Epoch 31/1000] [Train_Loss: 0.641246 /Valid_Loss: 0.628592]
# [Epoch 31/1000] [Accuracy  : 0.712650]
# [Epoch 32/1000] [Train_Loss: 0.623281 /Valid_Loss: 0.625234]
# [Epoch 32/1000] [Accuracy  : 0.712512]
# [Epoch 33/1000] [Train_Loss: 0.614090 /Valid_Loss: 0.619896]
# [Epoch 33/1000] [Accuracy  : 0.717487]
# [Epoch 34/1000] [Train_Loss: 0.606469 /Valid_Loss: 0.621591]
# [Epoch 34/1000] [Accuracy  : 0.715812]
# [Epoch 35/1000] [Train_Loss: 0.616159 /Valid_Loss: 0.619081]
# [Epoch 35/1000] [Accuracy  : 0.717025]
# [Epoch 36/1000] [Train_Loss: 0.613843 /Valid_Loss: 0.619689]
# [Epoch 36/1000] [Accuracy  : 0.715762]
# [Epoch 37/1000] [Train_Loss: 0.607394 /Valid_Loss: 0.617304]
# [Epoch 37/1000] [Accuracy  : 0.718487]
# [Epoch 38/1000] [Train_Loss: 0.617877 /Valid_Loss: 0.621134]
# [Epoch 38/1000] [Accuracy  : 0.714175]
# [Epoch 39/1000] [Train_Loss: 0.599264 /Valid_Loss: 0.618908]
# [Epoch 39/1000] [Accuracy  : 0.717562]
# [Epoch 40/1000] [Train_Loss: 0.604345 /Valid_Loss: 0.617848]
# [Epoch 40/1000] [Accuracy  : 0.713638]
# [Epoch 41/1000] [Train_Loss: 0.588195 /Valid_Loss: 0.617194]
# [Epoch 41/1000] [Accuracy  : 0.718313]
# [Epoch 42/1000] [Train_Loss: 0.595413 /Valid_Loss: 0.612555]
# [Epoch 42/1000] [Accuracy  : 0.719237]
# [Epoch 43/1000] [Train_Loss: 0.598706 /Valid_Loss: 0.612158]
# [Epoch 43/1000] [Accuracy  : 0.720063]
# [Epoch 44/1000] [Train_Loss: 0.598480 /Valid_Loss: 0.611374]
# [Epoch 44/1000] [Accuracy  : 0.720850]
# [Epoch 45/1000] [Train_Loss: 0.580985 /Valid_Loss: 0.612155]
# [Epoch 45/1000] [Accuracy  : 0.721337]
# [Epoch 46/1000] [Train_Loss: 0.590169 /Valid_Loss: 0.610767]
# [Epoch 46/1000] [Accuracy  : 0.720838]
# [Epoch 47/1000] [Train_Loss: 0.589884 /Valid_Loss: 0.605495]
# [Epoch 47/1000] [Accuracy  : 0.723525]
# [Epoch 48/1000] [Train_Loss: 0.583384 /Valid_Loss: 0.610539]
# [Epoch 48/1000] [Accuracy  : 0.720700]
# [Epoch 49/1000] [Train_Loss: 0.599789 /Valid_Loss: 0.610954]
# [Epoch 49/1000] [Accuracy  : 0.720337]
# [Epoch 50/1000] [Train_Loss: 0.584413 /Valid_Loss: 0.605029]
# [Epoch 50/1000] [Accuracy  : 0.725788]
# [Epoch 51/1000] [Train_Loss: 0.581803 /Valid_Loss: 0.606781]
# [Epoch 51/1000] [Accuracy  : 0.726625]
# [Epoch 52/1000] [Train_Loss: 0.578802 /Valid_Loss: 0.614175]
# [Epoch 52/1000] [Accuracy  : 0.718988]
# [Epoch 53/1000] [Train_Loss: 0.588140 /Valid_Loss: 0.608772]
# [Epoch 53/1000] [Accuracy  : 0.722200]
# [Epoch 54/1000] [Train_Loss: 0.579849 /Valid_Loss: 0.607290]
# [Epoch 54/1000] [Accuracy  : 0.727475]
# [Epoch 55/1000] [Train_Loss: 0.592256 /Valid_Loss: 0.603832]
# [Epoch 55/1000] [Accuracy  : 0.727738]
# [Epoch 56/1000] [Train_Loss: 0.575254 /Valid_Loss: 0.604933]
# [Epoch 56/1000] [Accuracy  : 0.726588]
# [Epoch 57/1000] [Train_Loss: 0.579091 /Valid_Loss: 0.603608]
# [Epoch 57/1000] [Accuracy  : 0.729275]
# [Epoch 58/1000] [Train_Loss: 0.578443 /Valid_Loss: 0.602736]
# [Epoch 58/1000] [Accuracy  : 0.730625]
# [Epoch 59/1000] [Train_Loss: 0.587908 /Valid_Loss: 0.607701]
# [Epoch 59/1000] [Accuracy  : 0.724175]
# [Epoch 60/1000] [Train_Loss: 0.579302 /Valid_Loss: 0.600211]
# [Epoch 60/1000] [Accuracy  : 0.733550]
# [Epoch 61/1000] [Train_Loss: 0.606975 /Valid_Loss: 0.599402]
# [Epoch 61/1000] [Accuracy  : 0.733725]
# [Epoch 62/1000] [Train_Loss: 0.572851 /Valid_Loss: 0.604133]
# [Epoch 62/1000] [Accuracy  : 0.730888]
# [Epoch 63/1000] [Train_Loss: 0.574567 /Valid_Loss: 0.599709]
# [Epoch 63/1000] [Accuracy  : 0.732950]
# [Epoch 64/1000] [Train_Loss: 0.578944 /Valid_Loss: 0.603486]
# [Epoch 64/1000] [Accuracy  : 0.729363]
# [Epoch 65/1000] [Train_Loss: 0.569832 /Valid_Loss: 0.602332]
# [Epoch 65/1000] [Accuracy  : 0.730463]
# [Epoch 66/1000] [Train_Loss: 0.572486 /Valid_Loss: 0.611711]
# [Epoch 66/1000] [Accuracy  : 0.721487]
# [Epoch 67/1000] [Train_Loss: 0.567593 /Valid_Loss: 0.611104]
# [Epoch 67/1000] [Accuracy  : 0.721588]
# [Epoch 68/1000] [Train_Loss: 0.590766 /Valid_Loss: 0.599046]
# [Epoch 68/1000] [Accuracy  : 0.731825]
# [Epoch 69/1000] [Train_Loss: 0.556536 /Valid_Loss: 0.598185]
# [Epoch 69/1000] [Accuracy  : 0.730850]
# [Epoch 70/1000] [Train_Loss: 0.572551 /Valid_Loss: 0.602932]
# [Epoch 70/1000] [Accuracy  : 0.729213]
# [Epoch 71/1000] [Train_Loss: 0.564889 /Valid_Loss: 0.606773]
# [Epoch 71/1000] [Accuracy  : 0.726450]
# [Epoch 72/1000] [Train_Loss: 0.558820 /Valid_Loss: 0.597840]
# [Epoch 72/1000] [Accuracy  : 0.730363]
# [Epoch 73/1000] [Train_Loss: 0.576584 /Valid_Loss: 0.598257]
# [Epoch 73/1000] [Accuracy  : 0.729788]
# [Epoch 74/1000] [Train_Loss: 0.568727 /Valid_Loss: 0.601302]
# [Epoch 74/1000] [Accuracy  : 0.732788]
# [Epoch 75/1000] [Train_Loss: 0.576323 /Valid_Loss: 0.597504]
# [Epoch 75/1000] [Accuracy  : 0.734112]
# [Epoch 76/1000] [Train_Loss: 0.562208 /Valid_Loss: 0.600144]
# [Epoch 76/1000] [Accuracy  : 0.730738]
# [Epoch 77/1000] [Train_Loss: 0.567127 /Valid_Loss: 0.592441]
# [Epoch 77/1000] [Accuracy  : 0.732862]
# [Epoch 78/1000] [Train_Loss: 0.576868 /Valid_Loss: 0.592369]
# [Epoch 78/1000] [Accuracy  : 0.736988]
# [Epoch 79/1000] [Train_Loss: 0.564061 /Valid_Loss: 0.598930]
# [Epoch 79/1000] [Accuracy  : 0.731337]
# [Epoch 80/1000] [Train_Loss: 0.567820 /Valid_Loss: 0.596422]
# [Epoch 80/1000] [Accuracy  : 0.729575]
# [Epoch 81/1000] [Train_Loss: 0.556584 /Valid_Loss: 0.596125]
# [Epoch 81/1000] [Accuracy  : 0.734150]
# [Epoch 82/1000] [Train_Loss: 0.572174 /Valid_Loss: 0.603277]
# [Epoch 82/1000] [Accuracy  : 0.731062]
# [Epoch 83/1000] [Train_Loss: 0.547034 /Valid_Loss: 0.594937]
# [Epoch 83/1000] [Accuracy  : 0.732925]
# [Epoch 84/1000] [Train_Loss: 0.572240 /Valid_Loss: 0.604462]
# [Epoch 84/1000] [Accuracy  : 0.728275]
# [Epoch 85/1000] [Train_Loss: 0.560869 /Valid_Loss: 0.595891]
# [Epoch 85/1000] [Accuracy  : 0.734000]
# [Epoch 86/1000] [Train_Loss: 0.575822 /Valid_Loss: 0.597641]
# [Epoch 86/1000] [Accuracy  : 0.731825]
# [Epoch 87/1000] [Train_Loss: 0.571480 /Valid_Loss: 0.594842]
# [Epoch 87/1000] [Accuracy  : 0.736138]
# [Epoch 88/1000] [Train_Loss: 0.556397 /Valid_Loss: 0.588123]
# [Epoch 88/1000] [Accuracy  : 0.738975]
# [Epoch 89/1000] [Train_Loss: 0.567152 /Valid_Loss: 0.594917]
# [Epoch 89/1000] [Accuracy  : 0.735738]
# [Epoch 90/1000] [Train_Loss: 0.550893 /Valid_Loss: 0.596643]
# [Epoch 90/1000] [Accuracy  : 0.733900]
# [Epoch 91/1000] [Train_Loss: 0.563624 /Valid_Loss: 0.601121]
# [Epoch 91/1000] [Accuracy  : 0.727912]
# [Epoch 92/1000] [Train_Loss: 0.550174 /Valid_Loss: 0.596035]
# [Epoch 92/1000] [Accuracy  : 0.734838]
# [Epoch 93/1000] [Train_Loss: 0.555735 /Valid_Loss: 0.595922]
# [Epoch 93/1000] [Accuracy  : 0.734475]
# [Epoch 94/1000] [Train_Loss: 0.558895 /Valid_Loss: 0.599563]
# [Epoch 94/1000] [Accuracy  : 0.730988]
# [Epoch 95/1000] [Train_Loss: 0.569310 /Valid_Loss: 0.592147]
# [Epoch 95/1000] [Accuracy  : 0.735475]
# [Epoch 96/1000] [Train_Loss: 0.567669 /Valid_Loss: 0.588299]
# [Epoch 96/1000] [Accuracy  : 0.741275]
# [Epoch 97/1000] [Train_Loss: 0.563756 /Valid_Loss: 0.595694]
# [Epoch 97/1000] [Accuracy  : 0.730912]
# [Epoch 98/1000] [Train_Loss: 0.548450 /Valid_Loss: 0.592729]
# [Epoch 98/1000] [Accuracy  : 0.734800]
# [Epoch 99/1000] [Train_Loss: 0.549715 /Valid_Loss: 0.593676]
# [Epoch 99/1000] [Accuracy  : 0.735800]
# [Epoch 100/1000] [Train_Loss: 0.554084 /Valid_Loss: 0.594599]
# [Epoch 100/1000] [Accuracy  : 0.734225]
# [Epoch 101/1000] [Train_Loss: 0.562596 /Valid_Loss: 0.589070]
# [Epoch 101/1000] [Accuracy  : 0.739475]
# [Epoch 102/1000] [Train_Loss: 0.548664 /Valid_Loss: 0.603571]
# [Epoch 102/1000] [Accuracy  : 0.728062]
# [Epoch 103/1000] [Train_Loss: 0.554120 /Valid_Loss: 0.595324]
# [Epoch 103/1000] [Accuracy  : 0.735012]
# [Epoch 104/1000] [Train_Loss: 0.554991 /Valid_Loss: 0.595969]
# [Epoch 104/1000] [Accuracy  : 0.734075]
# [Epoch 105/1000] [Train_Loss: 0.542256 /Valid_Loss: 0.592726]
# [Epoch 105/1000] [Accuracy  : 0.736163]
# [Epoch 106/1000] [Train_Loss: 0.567090 /Valid_Loss: 0.598308]
# [Epoch 106/1000] [Accuracy  : 0.732088]
# [Epoch 107/1000] [Train_Loss: 0.561681 /Valid_Loss: 0.598091]
# [Epoch 107/1000] [Accuracy  : 0.734962]
# [Epoch 108/1000] [Train_Loss: 0.568689 /Valid_Loss: 0.595031]
# [Epoch 108/1000] [Accuracy  : 0.734725]
# [Epoch 109/1000] [Train_Loss: 0.575191 /Valid_Loss: 0.591404]
# [Epoch 109/1000] [Accuracy  : 0.735712]
# [Epoch 110/1000] [Train_Loss: 0.551699 /Valid_Loss: 0.592728]
# [Epoch 110/1000] [Accuracy  : 0.735112]
# [Epoch 111/1000] [Train_Loss: 0.564134 /Valid_Loss: 0.592423]
# [Epoch 111/1000] [Accuracy  : 0.735425]
# [Epoch 112/1000] [Train_Loss: 0.559655 /Valid_Loss: 0.595947]
# [Epoch 112/1000] [Accuracy  : 0.731975]
# [Epoch 113/1000] [Train_Loss: 0.585667 /Valid_Loss: 0.592463]
# [Epoch 113/1000] [Accuracy  : 0.737525]
# [Epoch 114/1000] [Train_Loss: 0.542100 /Valid_Loss: 0.589369]
# [Epoch 114/1000] [Accuracy  : 0.739088]
# [Epoch 115/1000] [Train_Loss: 0.546373 /Valid_Loss: 0.591241]
# [Epoch 115/1000] [Accuracy  : 0.737988]
# [Epoch 116/1000] [Train_Loss: 0.553919 /Valid_Loss: 0.596511]
# [Epoch 116/1000] [Accuracy  : 0.733938]
# [Epoch 117/1000] [Train_Loss: 0.539429 /Valid_Loss: 0.597243]
# [Epoch 117/1000] [Accuracy  : 0.731838]
# [Epoch 118/1000] [Train_Loss: 0.559837 /Valid_Loss: 0.594541]
# [Epoch 118/1000] [Accuracy  : 0.735375]
# [Epoch 119/1000] [Train_Loss: 0.563623 /Valid_Loss: 0.591243]
# [Epoch 119/1000] [Accuracy  : 0.736038]
# [Epoch 120/1000] [Train_Loss: 0.557492 /Valid_Loss: 0.591646]
# [Epoch 120/1000] [Accuracy  : 0.737125]
# [Epoch 121/1000] [Train_Loss: 0.551075 /Valid_Loss: 0.592662]
# [Epoch 121/1000] [Accuracy  : 0.735500]
# [Epoch 122/1000] [Train_Loss: 0.552566 /Valid_Loss: 0.591994]
# [Epoch 122/1000] [Accuracy  : 0.734675]
# [Epoch 123/1000] [Train_Loss: 0.555595 /Valid_Loss: 0.592638]
# [Epoch 123/1000] [Accuracy  : 0.735875]
# [Epoch 124/1000] [Train_Loss: 0.536491 /Valid_Loss: 0.593038]
# [Epoch 124/1000] [Accuracy  : 0.735363]
# [Epoch 125/1000] [Train_Loss: 0.544551 /Valid_Loss: 0.592919]
# [Epoch 125/1000] [Accuracy  : 0.735675]
# [Epoch 126/1000] [Train_Loss: 0.542195 /Valid_Loss: 0.600472]
# [Epoch 126/1000] [Accuracy  : 0.729788]
# [Epoch 127/1000] [Train_Loss: 0.529608 /Valid_Loss: 0.592468]
# [Epoch 127/1000] [Accuracy  : 0.738363]
# [Epoch 128/1000] [Train_Loss: 0.557308 /Valid_Loss: 0.593619]
# [Epoch 128/1000] [Accuracy  : 0.732475]
# [Epoch 129/1000] [Train_Loss: 0.529034 /Valid_Loss: 0.598431]
# [Epoch 129/1000] [Accuracy  : 0.732762]
# [Epoch 130/1000] [Train_Loss: 0.544939 /Valid_Loss: 0.588897]
# [Epoch 130/1000] [Accuracy  : 0.736850]
# [Epoch 131/1000] [Train_Loss: 0.543935 /Valid_Loss: 0.595288]
# [Epoch 131/1000] [Accuracy  : 0.734387]
# [Epoch 132/1000] [Train_Loss: 0.538376 /Valid_Loss: 0.599891]
# [Epoch 132/1000] [Accuracy  : 0.730550]
# [Epoch 133/1000] [Train_Loss: 0.553586 /Valid_Loss: 0.594970]
# [Epoch 133/1000] [Accuracy  : 0.733700]
# [Epoch 134/1000] [Train_Loss: 0.543733 /Valid_Loss: 0.597460]
# [Epoch 134/1000] [Accuracy  : 0.731463]
# [Epoch 135/1000] [Train_Loss: 0.552901 /Valid_Loss: 0.599677]
# [Epoch 135/1000] [Accuracy  : 0.728387]
# [Epoch 136/1000] [Train_Loss: 0.559004 /Valid_Loss: 0.595965]
# [Epoch 136/1000] [Accuracy  : 0.732350]
# [Epoch 137/1000] [Train_Loss: 0.532015 /Valid_Loss: 0.599137]
# [Epoch 137/1000] [Accuracy  : 0.731850]
# [Epoch 138/1000] [Train_Loss: 0.561424 /Valid_Loss: 0.589300]
# [Epoch 138/1000] [Accuracy  : 0.738613]
# [Epoch 139/1000] [Train_Loss: 0.547967 /Valid_Loss: 0.593265]
# [Epoch 139/1000] [Accuracy  : 0.735537]
# [Epoch 140/1000] [Train_Loss: 0.557905 /Valid_Loss: 0.591666]
# [Epoch 140/1000] [Accuracy  : 0.735537]
# [Epoch 141/1000] [Train_Loss: 0.548080 /Valid_Loss: 0.596910]
# [Epoch 141/1000] [Accuracy  : 0.732450]
# [Epoch 142/1000] [Train_Loss: 0.541213 /Valid_Loss: 0.597002]
# [Epoch 142/1000] [Accuracy  : 0.733187]
# [Epoch 143/1000] [Train_Loss: 0.545924 /Valid_Loss: 0.597104]
# [Epoch 143/1000] [Accuracy  : 0.733400]
# [Epoch 144/1000] [Train_Loss: 0.544677 /Valid_Loss: 0.594314]
# [Epoch 144/1000] [Accuracy  : 0.736088]
# [Epoch 145/1000] [Train_Loss: 0.539675 /Valid_Loss: 0.588991]
# [Epoch 145/1000] [Accuracy  : 0.738225]
# [Epoch 146/1000] [Train_Loss: 0.548899 /Valid_Loss: 0.597820]
# [Epoch 146/1000] [Accuracy  : 0.730838]
# [Epoch 147/1000] [Train_Loss: 0.551035 /Valid_Loss: 0.599956]
# [Epoch 147/1000] [Accuracy  : 0.731413]
# This is time to do early stopping
# 모델 저장: /content/gdrive/My Drive/Colab Notebooks/kamp/14. Dataset_Rotor/dnn_model.pt

# %% [markdown]
# #### (1) 모델 평가

# %%
PATH = dir+'dnn_'
test_model(DNN_model, PATH)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-42d731539b5e> in <module>
# ----> 1 PATH = dir+'dnn_'
#       2 test_model(DNN_model, PATH)
#
# TypeError: unsupported operand type(s) for +: 'builtin_function_or_method' and 'str'

# %% [markdown]
# #### (2) 혼동 행렬 (Confusion matrix)

# %%
draw_confusion_matrix(DNN_model, x_test, y_test, PATH)

# %% [markdown]
# #### (3) 손실(Loss) 그래프

# %%
plot_loss_graph(DNN_loss_values, DNN_loss_values_v)

# %% [markdown]
# ### 5-2. 합성곱신경망 (CNN) 모델  성능 평가

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

CNN_model = KAMP_CNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(CNN_model.parameters())
PATH = dir+'cnn_'

CNN_loss_values, CNN_loss_values_v = train_model(CNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

CNN_model = KAMP_CNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(CNN_model.parameters())
PATH = dir+'cnn_'

CNN_loss_values, CNN_loss_values_v = train_model(CNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py:303: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ../aten/src/ATen/native/Convolution.cpp:882.)
#   return F.conv1d(input, weight, bias, self.stride,
# [Epoch 1/1000] [Train_Loss: 1.297222 /Valid_Loss: 1.363497]
# [Epoch 1/1000] [Accuracy  : 0.249963]
# [Epoch 2/1000] [Train_Loss: 1.234386 /Valid_Loss: 1.222897]
# [Epoch 2/1000] [Accuracy  : 0.438987]
# [Epoch 3/1000] [Train_Loss: 1.166199 /Valid_Loss: 1.157878]
# [Epoch 3/1000] [Accuracy  : 0.492525]
# [Epoch 4/1000] [Train_Loss: 1.113933 /Valid_Loss: 1.104968]
# [Epoch 4/1000] [Accuracy  : 0.484613]
# [Epoch 5/1000] [Train_Loss: 1.065624 /Valid_Loss: 1.052055]
# [Epoch 5/1000] [Accuracy  : 0.553825]
# [Epoch 6/1000] [Train_Loss: 1.019922 /Valid_Loss: 1.011376]
# [Epoch 6/1000] [Accuracy  : 0.555850]
# [Epoch 7/1000] [Train_Loss: 0.984519 /Valid_Loss: 0.968190]
# [Epoch 7/1000] [Accuracy  : 0.612100]
# [Epoch 8/1000] [Train_Loss: 0.946996 /Valid_Loss: 0.939522]
# [Epoch 8/1000] [Accuracy  : 0.637650]
# [Epoch 9/1000] [Train_Loss: 0.923010 /Valid_Loss: 0.906228]
# [Epoch 9/1000] [Accuracy  : 0.631938]
# [Epoch 10/1000] [Train_Loss: 0.901956 /Valid_Loss: 0.889841]
# [Epoch 10/1000] [Accuracy  : 0.629000]
# [Epoch 11/1000] [Train_Loss: 0.871019 /Valid_Loss: 0.865377]
# [Epoch 11/1000] [Accuracy  : 0.639362]
# [Epoch 12/1000] [Train_Loss: 0.858181 /Valid_Loss: 0.849070]
# [Epoch 12/1000] [Accuracy  : 0.647275]
# [Epoch 13/1000] [Train_Loss: 0.832232 /Valid_Loss: 0.830333]
# [Epoch 13/1000] [Accuracy  : 0.635450]
# [Epoch 14/1000] [Train_Loss: 0.822464 /Valid_Loss: 0.811000]
# [Epoch 14/1000] [Accuracy  : 0.650075]
# [Epoch 15/1000] [Train_Loss: 0.816798 /Valid_Loss: 0.795740]
# [Epoch 15/1000] [Accuracy  : 0.660500]
# [Epoch 16/1000] [Train_Loss: 0.807814 /Valid_Loss: 0.785082]
# [Epoch 16/1000] [Accuracy  : 0.654250]
# [Epoch 17/1000] [Train_Loss: 0.807512 /Valid_Loss: 0.774473]
# [Epoch 17/1000] [Accuracy  : 0.650825]
# [Epoch 18/1000] [Train_Loss: 0.782647 /Valid_Loss: 0.764813]
# [Epoch 18/1000] [Accuracy  : 0.652900]
# [Epoch 19/1000] [Train_Loss: 0.771836 /Valid_Loss: 0.757230]
# [Epoch 19/1000] [Accuracy  : 0.660737]
# [Epoch 20/1000] [Train_Loss: 0.768196 /Valid_Loss: 0.752656]
# [Epoch 20/1000] [Accuracy  : 0.667763]
# [Epoch 21/1000] [Train_Loss: 0.763381 /Valid_Loss: 0.741802]
# [Epoch 21/1000] [Accuracy  : 0.659238]
# [Epoch 22/1000] [Train_Loss: 0.748994 /Valid_Loss: 0.735529]
# [Epoch 22/1000] [Accuracy  : 0.667013]
# [Epoch 23/1000] [Train_Loss: 0.733756 /Valid_Loss: 0.725420]
# [Epoch 23/1000] [Accuracy  : 0.667750]
# [Epoch 24/1000] [Train_Loss: 0.714663 /Valid_Loss: 0.714310]
# [Epoch 24/1000] [Accuracy  : 0.682288]
# [Epoch 25/1000] [Train_Loss: 0.725464 /Valid_Loss: 0.721310]
# [Epoch 25/1000] [Accuracy  : 0.675687]
# [Epoch 26/1000] [Train_Loss: 0.721184 /Valid_Loss: 0.696312]
# [Epoch 26/1000] [Accuracy  : 0.670850]
# [Epoch 27/1000] [Train_Loss: 0.707938 /Valid_Loss: 0.689945]
# [Epoch 27/1000] [Accuracy  : 0.689638]
# [Epoch 28/1000] [Train_Loss: 0.697639 /Valid_Loss: 0.681668]
# [Epoch 28/1000] [Accuracy  : 0.689388]
# [Epoch 29/1000] [Train_Loss: 0.687078 /Valid_Loss: 0.681093]
# [Epoch 29/1000] [Accuracy  : 0.682013]
# [Epoch 30/1000] [Train_Loss: 0.685919 /Valid_Loss: 0.685137]
# [Epoch 30/1000] [Accuracy  : 0.684262]
# [Epoch 31/1000] [Train_Loss: 0.675250 /Valid_Loss: 0.673882]
# [Epoch 31/1000] [Accuracy  : 0.685875]
# [Epoch 32/1000] [Train_Loss: 0.683316 /Valid_Loss: 0.665864]
# [Epoch 32/1000] [Accuracy  : 0.698300]
# [Epoch 33/1000] [Train_Loss: 0.677495 /Valid_Loss: 0.665984]
# [Epoch 33/1000] [Accuracy  : 0.693975]
# [Epoch 34/1000] [Train_Loss: 0.655591 /Valid_Loss: 0.665724]
# [Epoch 34/1000] [Accuracy  : 0.701063]
# [Epoch 35/1000] [Train_Loss: 0.666257 /Valid_Loss: 0.663581]
# [Epoch 35/1000] [Accuracy  : 0.691113]
# [Epoch 36/1000] [Train_Loss: 0.670066 /Valid_Loss: 0.664265]
# [Epoch 36/1000] [Accuracy  : 0.696550]
# [Epoch 37/1000] [Train_Loss: 0.658233 /Valid_Loss: 0.651961]
# [Epoch 37/1000] [Accuracy  : 0.699075]
# [Epoch 38/1000] [Train_Loss: 0.665616 /Valid_Loss: 0.662583]
# [Epoch 38/1000] [Accuracy  : 0.700712]
# [Epoch 39/1000] [Train_Loss: 0.638950 /Valid_Loss: 0.646552]
# [Epoch 39/1000] [Accuracy  : 0.704313]
# [Epoch 40/1000] [Train_Loss: 0.649954 /Valid_Loss: 0.642337]
# [Epoch 40/1000] [Accuracy  : 0.703738]
# [Epoch 41/1000] [Train_Loss: 0.654940 /Valid_Loss: 0.650558]
# [Epoch 41/1000] [Accuracy  : 0.694175]
# [Epoch 42/1000] [Train_Loss: 0.646391 /Valid_Loss: 0.643063]
# [Epoch 42/1000] [Accuracy  : 0.710263]
# [Epoch 43/1000] [Train_Loss: 0.667009 /Valid_Loss: 0.639920]
# [Epoch 43/1000] [Accuracy  : 0.701488]
# [Epoch 44/1000] [Train_Loss: 0.653989 /Valid_Loss: 0.641667]
# [Epoch 44/1000] [Accuracy  : 0.709963]
# [Epoch 45/1000] [Train_Loss: 0.662239 /Valid_Loss: 0.644064]
# [Epoch 45/1000] [Accuracy  : 0.707450]
# [Epoch 46/1000] [Train_Loss: 0.655077 /Valid_Loss: 0.638677]
# [Epoch 46/1000] [Accuracy  : 0.708225]
# [Epoch 47/1000] [Train_Loss: 0.637437 /Valid_Loss: 0.638962]
# [Epoch 47/1000] [Accuracy  : 0.705950]
# [Epoch 48/1000] [Train_Loss: 0.630836 /Valid_Loss: 0.640167]
# [Epoch 48/1000] [Accuracy  : 0.707638]
# [Epoch 49/1000] [Train_Loss: 0.635161 /Valid_Loss: 0.631637]
# [Epoch 49/1000] [Accuracy  : 0.710050]
# [Epoch 50/1000] [Train_Loss: 0.653409 /Valid_Loss: 0.634551]
# [Epoch 50/1000] [Accuracy  : 0.712075]
# [Epoch 51/1000] [Train_Loss: 0.645418 /Valid_Loss: 0.638736]
# [Epoch 51/1000] [Accuracy  : 0.705000]
# [Epoch 52/1000] [Train_Loss: 0.645796 /Valid_Loss: 0.636554]
# [Epoch 52/1000] [Accuracy  : 0.711000]
# [Epoch 53/1000] [Train_Loss: 0.638972 /Valid_Loss: 0.630290]
# [Epoch 53/1000] [Accuracy  : 0.712950]
# [Epoch 54/1000] [Train_Loss: 0.633870 /Valid_Loss: 0.625174]
# [Epoch 54/1000] [Accuracy  : 0.721125]
# [Epoch 55/1000] [Train_Loss: 0.640947 /Valid_Loss: 0.625032]
# [Epoch 55/1000] [Accuracy  : 0.717087]
# [Epoch 56/1000] [Train_Loss: 0.632861 /Valid_Loss: 0.630761]
# [Epoch 56/1000] [Accuracy  : 0.710325]
# [Epoch 57/1000] [Train_Loss: 0.639352 /Valid_Loss: 0.622821]
# [Epoch 57/1000] [Accuracy  : 0.720325]
# [Epoch 58/1000] [Train_Loss: 0.633694 /Valid_Loss: 0.644004]
# [Epoch 58/1000] [Accuracy  : 0.713325]
# [Epoch 59/1000] [Train_Loss: 0.628112 /Valid_Loss: 0.624867]
# [Epoch 59/1000] [Accuracy  : 0.716612]
# [Epoch 60/1000] [Train_Loss: 0.647296 /Valid_Loss: 0.622123]
# [Epoch 60/1000] [Accuracy  : 0.722237]
# [Epoch 61/1000] [Train_Loss: 0.628030 /Valid_Loss: 0.615555]
# [Epoch 61/1000] [Accuracy  : 0.721912]
# [Epoch 62/1000] [Train_Loss: 0.626086 /Valid_Loss: 0.618781]
# [Epoch 62/1000] [Accuracy  : 0.719463]
# [Epoch 63/1000] [Train_Loss: 0.615797 /Valid_Loss: 0.624368]
# [Epoch 63/1000] [Accuracy  : 0.721988]
# [Epoch 64/1000] [Train_Loss: 0.622667 /Valid_Loss: 0.617619]
# [Epoch 64/1000] [Accuracy  : 0.722000]
# [Epoch 65/1000] [Train_Loss: 0.624855 /Valid_Loss: 0.616095]
# [Epoch 65/1000] [Accuracy  : 0.719900]
# [Epoch 66/1000] [Train_Loss: 0.616978 /Valid_Loss: 0.612774]
# [Epoch 66/1000] [Accuracy  : 0.722350]
# [Epoch 67/1000] [Train_Loss: 0.622629 /Valid_Loss: 0.613648]
# [Epoch 67/1000] [Accuracy  : 0.725838]
# [Epoch 68/1000] [Train_Loss: 0.610090 /Valid_Loss: 0.611121]
# [Epoch 68/1000] [Accuracy  : 0.724662]
# [Epoch 69/1000] [Train_Loss: 0.615653 /Valid_Loss: 0.610309]
# [Epoch 69/1000] [Accuracy  : 0.724800]
# [Epoch 70/1000] [Train_Loss: 0.612021 /Valid_Loss: 0.619464]
# [Epoch 70/1000] [Accuracy  : 0.718700]
# [Epoch 71/1000] [Train_Loss: 0.604260 /Valid_Loss: 0.611964]
# [Epoch 71/1000] [Accuracy  : 0.729838]
# [Epoch 72/1000] [Train_Loss: 0.606092 /Valid_Loss: 0.614917]
# [Epoch 72/1000] [Accuracy  : 0.727537]
# [Epoch 73/1000] [Train_Loss: 0.619141 /Valid_Loss: 0.611763]
# [Epoch 73/1000] [Accuracy  : 0.726387]
# [Epoch 74/1000] [Train_Loss: 0.617716 /Valid_Loss: 0.604181]
# [Epoch 74/1000] [Accuracy  : 0.726437]
# [Epoch 75/1000] [Train_Loss: 0.612009 /Valid_Loss: 0.615739]
# [Epoch 75/1000] [Accuracy  : 0.719788]
# [Epoch 76/1000] [Train_Loss: 0.620510 /Valid_Loss: 0.606600]
# [Epoch 76/1000] [Accuracy  : 0.731688]
# [Epoch 77/1000] [Train_Loss: 0.620799 /Valid_Loss: 0.605122]
# [Epoch 77/1000] [Accuracy  : 0.732875]
# [Epoch 78/1000] [Train_Loss: 0.636346 /Valid_Loss: 0.611403]
# [Epoch 78/1000] [Accuracy  : 0.725962]
# [Epoch 79/1000] [Train_Loss: 0.607913 /Valid_Loss: 0.605145]
# [Epoch 79/1000] [Accuracy  : 0.733487]
# [Epoch 80/1000] [Train_Loss: 0.612475 /Valid_Loss: 0.613672]
# [Epoch 80/1000] [Accuracy  : 0.720688]
# [Epoch 81/1000] [Train_Loss: 0.610038 /Valid_Loss: 0.602319]
# [Epoch 81/1000] [Accuracy  : 0.727775]
# [Epoch 82/1000] [Train_Loss: 0.604136 /Valid_Loss: 0.606014]
# [Epoch 82/1000] [Accuracy  : 0.730700]
# [Epoch 83/1000] [Train_Loss: 0.603476 /Valid_Loss: 0.602676]
# [Epoch 83/1000] [Accuracy  : 0.737862]
# [Epoch 84/1000] [Train_Loss: 0.605268 /Valid_Loss: 0.604236]
# [Epoch 84/1000] [Accuracy  : 0.731125]
# [Epoch 85/1000] [Train_Loss: 0.611998 /Valid_Loss: 0.604161]
# [Epoch 85/1000] [Accuracy  : 0.730700]
# [Epoch 86/1000] [Train_Loss: 0.614911 /Valid_Loss: 0.601017]
# [Epoch 86/1000] [Accuracy  : 0.736563]
# [Epoch 87/1000] [Train_Loss: 0.620516 /Valid_Loss: 0.602960]
# [Epoch 87/1000] [Accuracy  : 0.730650]
# [Epoch 88/1000] [Train_Loss: 0.604583 /Valid_Loss: 0.602140]
# [Epoch 88/1000] [Accuracy  : 0.737738]
# [Epoch 89/1000] [Train_Loss: 0.608165 /Valid_Loss: 0.605938]
# [Epoch 89/1000] [Accuracy  : 0.724437]
# [Epoch 90/1000] [Train_Loss: 0.607203 /Valid_Loss: 0.598277]
# [Epoch 90/1000] [Accuracy  : 0.733825]
# [Epoch 91/1000] [Train_Loss: 0.597097 /Valid_Loss: 0.599845]
# [Epoch 91/1000] [Accuracy  : 0.738187]
# [Epoch 92/1000] [Train_Loss: 0.627985 /Valid_Loss: 0.599063]
# [Epoch 92/1000] [Accuracy  : 0.732962]
# [Epoch 93/1000] [Train_Loss: 0.595146 /Valid_Loss: 0.597669]
# [Epoch 93/1000] [Accuracy  : 0.737125]
# [Epoch 94/1000] [Train_Loss: 0.607170 /Valid_Loss: 0.598037]
# [Epoch 94/1000] [Accuracy  : 0.734100]
# [Epoch 95/1000] [Train_Loss: 0.597465 /Valid_Loss: 0.601554]
# [Epoch 95/1000] [Accuracy  : 0.731575]
# [Epoch 96/1000] [Train_Loss: 0.596658 /Valid_Loss: 0.600980]
# [Epoch 96/1000] [Accuracy  : 0.737912]
# [Epoch 97/1000] [Train_Loss: 0.603903 /Valid_Loss: 0.604632]
# [Epoch 97/1000] [Accuracy  : 0.733850]
# [Epoch 98/1000] [Train_Loss: 0.619272 /Valid_Loss: 0.594198]
# [Epoch 98/1000] [Accuracy  : 0.738775]
# [Epoch 99/1000] [Train_Loss: 0.602315 /Valid_Loss: 0.599146]
# [Epoch 99/1000] [Accuracy  : 0.737138]
# [Epoch 100/1000] [Train_Loss: 0.608141 /Valid_Loss: 0.598466]
# [Epoch 100/1000] [Accuracy  : 0.734563]
# [Epoch 101/1000] [Train_Loss: 0.604897 /Valid_Loss: 0.596686]
# [Epoch 101/1000] [Accuracy  : 0.739700]
# [Epoch 102/1000] [Train_Loss: 0.598131 /Valid_Loss: 0.593159]
# [Epoch 102/1000] [Accuracy  : 0.738975]
# [Epoch 103/1000] [Train_Loss: 0.601032 /Valid_Loss: 0.594163]
# [Epoch 103/1000] [Accuracy  : 0.743663]
# [Epoch 104/1000] [Train_Loss: 0.609929 /Valid_Loss: 0.597053]
# [Epoch 104/1000] [Accuracy  : 0.740237]
# [Epoch 105/1000] [Train_Loss: 0.598364 /Valid_Loss: 0.600479]
# [Epoch 105/1000] [Accuracy  : 0.735725]
# [Epoch 106/1000] [Train_Loss: 0.577277 /Valid_Loss: 0.597001]
# [Epoch 106/1000] [Accuracy  : 0.737475]
# [Epoch 107/1000] [Train_Loss: 0.600795 /Valid_Loss: 0.596036]
# [Epoch 107/1000] [Accuracy  : 0.740250]
# [Epoch 108/1000] [Train_Loss: 0.604262 /Valid_Loss: 0.593305]
# [Epoch 108/1000] [Accuracy  : 0.741150]
# [Epoch 109/1000] [Train_Loss: 0.607031 /Valid_Loss: 0.589992]
# [Epoch 109/1000] [Accuracy  : 0.742050]
# [Epoch 110/1000] [Train_Loss: 0.608929 /Valid_Loss: 0.590279]
# [Epoch 110/1000] [Accuracy  : 0.743938]
# [Epoch 111/1000] [Train_Loss: 0.601918 /Valid_Loss: 0.592900]
# [Epoch 111/1000] [Accuracy  : 0.737537]
# [Epoch 112/1000] [Train_Loss: 0.591398 /Valid_Loss: 0.593590]
# [Epoch 112/1000] [Accuracy  : 0.742000]
# [Epoch 113/1000] [Train_Loss: 0.610644 /Valid_Loss: 0.600372]
# [Epoch 113/1000] [Accuracy  : 0.733750]
# [Epoch 114/1000] [Train_Loss: 0.590774 /Valid_Loss: 0.592045]
# [Epoch 114/1000] [Accuracy  : 0.741613]
# [Epoch 115/1000] [Train_Loss: 0.578425 /Valid_Loss: 0.595141]
# [Epoch 115/1000] [Accuracy  : 0.741175]
# [Epoch 116/1000] [Train_Loss: 0.598892 /Valid_Loss: 0.595285]
# [Epoch 116/1000] [Accuracy  : 0.739675]
# [Epoch 117/1000] [Train_Loss: 0.606101 /Valid_Loss: 0.597504]
# [Epoch 117/1000] [Accuracy  : 0.735550]
# [Epoch 118/1000] [Train_Loss: 0.592205 /Valid_Loss: 0.594917]
# [Epoch 118/1000] [Accuracy  : 0.735862]
# [Epoch 119/1000] [Train_Loss: 0.599343 /Valid_Loss: 0.592452]
# [Epoch 119/1000] [Accuracy  : 0.743975]
# [Epoch 120/1000] [Train_Loss: 0.589032 /Valid_Loss: 0.593420]
# [Epoch 120/1000] [Accuracy  : 0.736988]
# [Epoch 121/1000] [Train_Loss: 0.606252 /Valid_Loss: 0.588732]
# [Epoch 121/1000] [Accuracy  : 0.743500]
# [Epoch 122/1000] [Train_Loss: 0.594841 /Valid_Loss: 0.592052]
# [Epoch 122/1000] [Accuracy  : 0.741950]
# [Epoch 123/1000] [Train_Loss: 0.609654 /Valid_Loss: 0.600336]
# [Epoch 123/1000] [Accuracy  : 0.738537]
# [Epoch 124/1000] [Train_Loss: 0.586670 /Valid_Loss: 0.598274]
# [Epoch 124/1000] [Accuracy  : 0.735688]
# [Epoch 125/1000] [Train_Loss: 0.598276 /Valid_Loss: 0.590962]
# [Epoch 125/1000] [Accuracy  : 0.741775]
# [Epoch 126/1000] [Train_Loss: 0.595647 /Valid_Loss: 0.591921]
# [Epoch 126/1000] [Accuracy  : 0.742400]
# [Epoch 127/1000] [Train_Loss: 0.598396 /Valid_Loss: 0.588732]
# [Epoch 127/1000] [Accuracy  : 0.743225]
# [Epoch 128/1000] [Train_Loss: 0.590613 /Valid_Loss: 0.588787]
# [Epoch 128/1000] [Accuracy  : 0.740862]
# [Epoch 129/1000] [Train_Loss: 0.598784 /Valid_Loss: 0.590100]
# [Epoch 129/1000] [Accuracy  : 0.740650]
# [Epoch 130/1000] [Train_Loss: 0.595012 /Valid_Loss: 0.593974]
# [Epoch 130/1000] [Accuracy  : 0.743050]
# [Epoch 131/1000] [Train_Loss: 0.603653 /Valid_Loss: 0.590504]
# [Epoch 131/1000] [Accuracy  : 0.739275]
# [Epoch 132/1000] [Train_Loss: 0.588714 /Valid_Loss: 0.588351]
# [Epoch 132/1000] [Accuracy  : 0.744112]
# [Epoch 133/1000] [Train_Loss: 0.585118 /Valid_Loss: 0.588682]
# [Epoch 133/1000] [Accuracy  : 0.743950]
# [Epoch 134/1000] [Train_Loss: 0.593210 /Valid_Loss: 0.591036]
# [Epoch 134/1000] [Accuracy  : 0.740650]
# [Epoch 135/1000] [Train_Loss: 0.578587 /Valid_Loss: 0.587504]
# [Epoch 135/1000] [Accuracy  : 0.745575]
# [Epoch 136/1000] [Train_Loss: 0.588217 /Valid_Loss: 0.588327]
# [Epoch 136/1000] [Accuracy  : 0.743675]
# [Epoch 137/1000] [Train_Loss: 0.589162 /Valid_Loss: 0.589563]
# [Epoch 137/1000] [Accuracy  : 0.741812]
# [Epoch 138/1000] [Train_Loss: 0.590887 /Valid_Loss: 0.592954]
# [Epoch 138/1000] [Accuracy  : 0.742425]
# [Epoch 139/1000] [Train_Loss: 0.581604 /Valid_Loss: 0.586061]
# [Epoch 139/1000] [Accuracy  : 0.745400]
# [Epoch 140/1000] [Train_Loss: 0.581265 /Valid_Loss: 0.587882]
# [Epoch 140/1000] [Accuracy  : 0.740375]
# [Epoch 141/1000] [Train_Loss: 0.585431 /Valid_Loss: 0.586217]
# [Epoch 141/1000] [Accuracy  : 0.746825]
# [Epoch 142/1000] [Train_Loss: 0.611555 /Valid_Loss: 0.592166]
# [Epoch 142/1000] [Accuracy  : 0.742012]
# [Epoch 143/1000] [Train_Loss: 0.583524 /Valid_Loss: 0.583816]
# [Epoch 143/1000] [Accuracy  : 0.747300]
# [Epoch 144/1000] [Train_Loss: 0.599380 /Valid_Loss: 0.589364]
# [Epoch 144/1000] [Accuracy  : 0.741988]
# [Epoch 145/1000] [Train_Loss: 0.589850 /Valid_Loss: 0.589016]
# [Epoch 145/1000] [Accuracy  : 0.742263]
# [Epoch 146/1000] [Train_Loss: 0.584421 /Valid_Loss: 0.587331]
# [Epoch 146/1000] [Accuracy  : 0.745325]
# [Epoch 147/1000] [Train_Loss: 0.591432 /Valid_Loss: 0.587921]
# [Epoch 147/1000] [Accuracy  : 0.739350]
# [Epoch 148/1000] [Train_Loss: 0.593378 /Valid_Loss: 0.588932]
# [Epoch 148/1000] [Accuracy  : 0.742687]
# [Epoch 149/1000] [Train_Loss: 0.602691 /Valid_Loss: 0.585428]
# [Epoch 149/1000] [Accuracy  : 0.745213]
# [Epoch 150/1000] [Train_Loss: 0.596373 /Valid_Loss: 0.597230]
# [Epoch 150/1000] [Accuracy  : 0.737500]
# [Epoch 151/1000] [Train_Loss: 0.576746 /Valid_Loss: 0.585324]
# [Epoch 151/1000] [Accuracy  : 0.743812]
# [Epoch 152/1000] [Train_Loss: 0.569663 /Valid_Loss: 0.588951]
# [Epoch 152/1000] [Accuracy  : 0.742475]
# [Epoch 153/1000] [Train_Loss: 0.585814 /Valid_Loss: 0.583585]
# [Epoch 153/1000] [Accuracy  : 0.743550]
# [Epoch 154/1000] [Train_Loss: 0.596667 /Valid_Loss: 0.588057]
# [Epoch 154/1000] [Accuracy  : 0.740287]
# [Epoch 155/1000] [Train_Loss: 0.573112 /Valid_Loss: 0.587226]
# [Epoch 155/1000] [Accuracy  : 0.742888]
# [Epoch 156/1000] [Train_Loss: 0.583099 /Valid_Loss: 0.584611]
# [Epoch 156/1000] [Accuracy  : 0.745600]
# [Epoch 157/1000] [Train_Loss: 0.575029 /Valid_Loss: 0.583583]
# [Epoch 157/1000] [Accuracy  : 0.744650]
# [Epoch 158/1000] [Train_Loss: 0.587165 /Valid_Loss: 0.583757]
# [Epoch 158/1000] [Accuracy  : 0.744625]
# [Epoch 159/1000] [Train_Loss: 0.598838 /Valid_Loss: 0.583717]
# [Epoch 159/1000] [Accuracy  : 0.746425]
# [Epoch 160/1000] [Train_Loss: 0.577974 /Valid_Loss: 0.587732]
# [Epoch 160/1000] [Accuracy  : 0.743712]
# [Epoch 161/1000] [Train_Loss: 0.584645 /Valid_Loss: 0.586165]
# [Epoch 161/1000] [Accuracy  : 0.744000]
# [Epoch 162/1000] [Train_Loss: 0.596031 /Valid_Loss: 0.583559]
# [Epoch 162/1000] [Accuracy  : 0.742062]
# [Epoch 163/1000] [Train_Loss: 0.600146 /Valid_Loss: 0.586710]
# [Epoch 163/1000] [Accuracy  : 0.744437]
# [Epoch 164/1000] [Train_Loss: 0.577843 /Valid_Loss: 0.582064]
# [Epoch 164/1000] [Accuracy  : 0.748212]
# [Epoch 165/1000] [Train_Loss: 0.596653 /Valid_Loss: 0.583939]
# [Epoch 165/1000] [Accuracy  : 0.745550]
# [Epoch 166/1000] [Train_Loss: 0.597536 /Valid_Loss: 0.586369]
# [Epoch 166/1000] [Accuracy  : 0.742862]
# [Epoch 167/1000] [Train_Loss: 0.577062 /Valid_Loss: 0.587943]
# [Epoch 167/1000] [Accuracy  : 0.743437]
# [Epoch 168/1000] [Train_Loss: 0.585679 /Valid_Loss: 0.582597]
# [Epoch 168/1000] [Accuracy  : 0.747337]
# [Epoch 169/1000] [Train_Loss: 0.581842 /Valid_Loss: 0.583476]
# [Epoch 169/1000] [Accuracy  : 0.745525]
# [Epoch 170/1000] [Train_Loss: 0.580362 /Valid_Loss: 0.585953]
# [Epoch 170/1000] [Accuracy  : 0.746363]
# [Epoch 171/1000] [Train_Loss: 0.583405 /Valid_Loss: 0.586297]
# [Epoch 171/1000] [Accuracy  : 0.744487]
# [Epoch 172/1000] [Train_Loss: 0.581132 /Valid_Loss: 0.589170]
# [Epoch 172/1000] [Accuracy  : 0.741475]
# [Epoch 173/1000] [Train_Loss: 0.590758 /Valid_Loss: 0.583256]
# [Epoch 173/1000] [Accuracy  : 0.742550]
# [Epoch 174/1000] [Train_Loss: 0.584203 /Valid_Loss: 0.584374]
# [Epoch 174/1000] [Accuracy  : 0.744413]
# [Epoch 175/1000] [Train_Loss: 0.583404 /Valid_Loss: 0.584653]
# [Epoch 175/1000] [Accuracy  : 0.744450]
# [Epoch 176/1000] [Train_Loss: 0.591645 /Valid_Loss: 0.579455]
# [Epoch 176/1000] [Accuracy  : 0.748387]
# [Epoch 177/1000] [Train_Loss: 0.587492 /Valid_Loss: 0.582301]
# [Epoch 177/1000] [Accuracy  : 0.744850]
# [Epoch 178/1000] [Train_Loss: 0.579357 /Valid_Loss: 0.581399]
# [Epoch 178/1000] [Accuracy  : 0.746563]
# [Epoch 179/1000] [Train_Loss: 0.587750 /Valid_Loss: 0.582753]
# [Epoch 179/1000] [Accuracy  : 0.747062]
# [Epoch 180/1000] [Train_Loss: 0.579257 /Valid_Loss: 0.579907]
# [Epoch 180/1000] [Accuracy  : 0.746525]
# [Epoch 181/1000] [Train_Loss: 0.586112 /Valid_Loss: 0.586108]
# [Epoch 181/1000] [Accuracy  : 0.742150]
# [Epoch 182/1000] [Train_Loss: 0.579233 /Valid_Loss: 0.583603]
# [Epoch 182/1000] [Accuracy  : 0.745750]
# [Epoch 183/1000] [Train_Loss: 0.581684 /Valid_Loss: 0.583438]
# [Epoch 183/1000] [Accuracy  : 0.746100]
# [Epoch 184/1000] [Train_Loss: 0.592676 /Valid_Loss: 0.580570]
# [Epoch 184/1000] [Accuracy  : 0.747587]
# [Epoch 185/1000] [Train_Loss: 0.583930 /Valid_Loss: 0.583054]
# [Epoch 185/1000] [Accuracy  : 0.745912]
# [Epoch 186/1000] [Train_Loss: 0.584539 /Valid_Loss: 0.583718]
# [Epoch 186/1000] [Accuracy  : 0.744775]
# [Epoch 187/1000] [Train_Loss: 0.575784 /Valid_Loss: 0.584796]
# [Epoch 187/1000] [Accuracy  : 0.744563]
# [Epoch 188/1000] [Train_Loss: 0.585984 /Valid_Loss: 0.579660]
# [Epoch 188/1000] [Accuracy  : 0.748637]
# [Epoch 189/1000] [Train_Loss: 0.593605 /Valid_Loss: 0.579948]
# [Epoch 189/1000] [Accuracy  : 0.748050]
# [Epoch 190/1000] [Train_Loss: 0.588083 /Valid_Loss: 0.588021]
# [Epoch 190/1000] [Accuracy  : 0.745600]
# [Epoch 191/1000] [Train_Loss: 0.590355 /Valid_Loss: 0.582675]
# [Epoch 191/1000] [Accuracy  : 0.745363]
# [Epoch 192/1000] [Train_Loss: 0.588713 /Valid_Loss: 0.586078]
# [Epoch 192/1000] [Accuracy  : 0.741850]
# [Epoch 193/1000] [Train_Loss: 0.568753 /Valid_Loss: 0.580047]
# [Epoch 193/1000] [Accuracy  : 0.748263]
# [Epoch 194/1000] [Train_Loss: 0.586581 /Valid_Loss: 0.584615]
# [Epoch 194/1000] [Accuracy  : 0.745475]
# [Epoch 195/1000] [Train_Loss: 0.588208 /Valid_Loss: 0.584623]
# [Epoch 195/1000] [Accuracy  : 0.743025]
# [Epoch 196/1000] [Train_Loss: 0.577491 /Valid_Loss: 0.587334]
# [Epoch 196/1000] [Accuracy  : 0.741962]
# [Epoch 197/1000] [Train_Loss: 0.579055 /Valid_Loss: 0.587246]
# [Epoch 197/1000] [Accuracy  : 0.743025]
# [Epoch 198/1000] [Train_Loss: 0.588511 /Valid_Loss: 0.580022]
# [Epoch 198/1000] [Accuracy  : 0.745888]
# [Epoch 199/1000] [Train_Loss: 0.588305 /Valid_Loss: 0.580131]
# [Epoch 199/1000] [Accuracy  : 0.746950]
# [Epoch 200/1000] [Train_Loss: 0.593347 /Valid_Loss: 0.580835]
# [Epoch 200/1000] [Accuracy  : 0.748525]
# [Epoch 201/1000] [Train_Loss: 0.577205 /Valid_Loss: 0.584012]
# [Epoch 201/1000] [Accuracy  : 0.741637]
# [Epoch 202/1000] [Train_Loss: 0.583527 /Valid_Loss: 0.585683]
# [Epoch 202/1000] [Accuracy  : 0.741900]
# [Epoch 203/1000] [Train_Loss: 0.578440 /Valid_Loss: 0.583239]
# [Epoch 203/1000] [Accuracy  : 0.743325]
# [Epoch 204/1000] [Train_Loss: 0.582855 /Valid_Loss: 0.578984]
# [Epoch 204/1000] [Accuracy  : 0.749225]
# [Epoch 205/1000] [Train_Loss: 0.583385 /Valid_Loss: 0.580546]
# [Epoch 205/1000] [Accuracy  : 0.746938]
# [Epoch 206/1000] [Train_Loss: 0.593503 /Valid_Loss: 0.581622]
# [Epoch 206/1000] [Accuracy  : 0.745537]
# [Epoch 207/1000] [Train_Loss: 0.596284 /Valid_Loss: 0.579734]
# [Epoch 207/1000] [Accuracy  : 0.748838]
# [Epoch 208/1000] [Train_Loss: 0.585491 /Valid_Loss: 0.588026]
# [Epoch 208/1000] [Accuracy  : 0.738350]
# [Epoch 209/1000] [Train_Loss: 0.585499 /Valid_Loss: 0.579942]
# [Epoch 209/1000] [Accuracy  : 0.748750]
# [Epoch 210/1000] [Train_Loss: 0.571529 /Valid_Loss: 0.581745]
# [Epoch 210/1000] [Accuracy  : 0.745175]
# [Epoch 211/1000] [Train_Loss: 0.591836 /Valid_Loss: 0.580333]
# [Epoch 211/1000] [Accuracy  : 0.746912]
# [Epoch 212/1000] [Train_Loss: 0.599099 /Valid_Loss: 0.579323]
# [Epoch 212/1000] [Accuracy  : 0.746700]
# [Epoch 213/1000] [Train_Loss: 0.578255 /Valid_Loss: 0.582036]
# [Epoch 213/1000] [Accuracy  : 0.746188]
# [Epoch 214/1000] [Train_Loss: 0.579053 /Valid_Loss: 0.582912]
# [Epoch 214/1000] [Accuracy  : 0.746237]
# [Epoch 215/1000] [Train_Loss: 0.572853 /Valid_Loss: 0.579845]
# [Epoch 215/1000] [Accuracy  : 0.747237]
# [Epoch 216/1000] [Train_Loss: 0.561059 /Valid_Loss: 0.583982]
# [Epoch 216/1000] [Accuracy  : 0.746175]
# [Epoch 217/1000] [Train_Loss: 0.586158 /Valid_Loss: 0.586812]
# [Epoch 217/1000] [Accuracy  : 0.744613]
# [Epoch 218/1000] [Train_Loss: 0.572169 /Valid_Loss: 0.586696]
# [Epoch 218/1000] [Accuracy  : 0.741962]
# [Epoch 219/1000] [Train_Loss: 0.587637 /Valid_Loss: 0.583254]
# [Epoch 219/1000] [Accuracy  : 0.745950]
# [Epoch 220/1000] [Train_Loss: 0.588414 /Valid_Loss: 0.580739]
# [Epoch 220/1000] [Accuracy  : 0.744838]
# [Epoch 221/1000] [Train_Loss: 0.580415 /Valid_Loss: 0.582005]
# [Epoch 221/1000] [Accuracy  : 0.743550]
# [Epoch 222/1000] [Train_Loss: 0.600634 /Valid_Loss: 0.586587]
# [Epoch 222/1000] [Accuracy  : 0.743387]
# [Epoch 223/1000] [Train_Loss: 0.589229 /Valid_Loss: 0.578004]
# [Epoch 223/1000] [Accuracy  : 0.747012]
# [Epoch 224/1000] [Train_Loss: 0.586693 /Valid_Loss: 0.580627]
# [Epoch 224/1000] [Accuracy  : 0.747550]
# [Epoch 225/1000] [Train_Loss: 0.583194 /Valid_Loss: 0.579995]
# [Epoch 225/1000] [Accuracy  : 0.745850]
# [Epoch 226/1000] [Train_Loss: 0.599633 /Valid_Loss: 0.587143]
# [Epoch 226/1000] [Accuracy  : 0.740575]
# [Epoch 227/1000] [Train_Loss: 0.592075 /Valid_Loss: 0.579552]
# [Epoch 227/1000] [Accuracy  : 0.746088]
# [Epoch 228/1000] [Train_Loss: 0.590773 /Valid_Loss: 0.578719]
# [Epoch 228/1000] [Accuracy  : 0.747888]
# [Epoch 229/1000] [Train_Loss: 0.567555 /Valid_Loss: 0.580836]
# [Epoch 229/1000] [Accuracy  : 0.747025]
# [Epoch 230/1000] [Train_Loss: 0.589747 /Valid_Loss: 0.579387]
# [Epoch 230/1000] [Accuracy  : 0.748038]
# [Epoch 231/1000] [Train_Loss: 0.573649 /Valid_Loss: 0.581312]
# [Epoch 231/1000] [Accuracy  : 0.747225]
# [Epoch 232/1000] [Train_Loss: 0.586711 /Valid_Loss: 0.579500]
# [Epoch 232/1000] [Accuracy  : 0.747537]
# [Epoch 233/1000] [Train_Loss: 0.569274 /Valid_Loss: 0.581460]
# [Epoch 233/1000] [Accuracy  : 0.746175]
# [Epoch 234/1000] [Train_Loss: 0.575134 /Valid_Loss: 0.584760]
# [Epoch 234/1000] [Accuracy  : 0.738237]
# [Epoch 235/1000] [Train_Loss: 0.589669 /Valid_Loss: 0.580303]
# [Epoch 235/1000] [Accuracy  : 0.746300]
# [Epoch 236/1000] [Train_Loss: 0.593162 /Valid_Loss: 0.584014]
# [Epoch 236/1000] [Accuracy  : 0.744900]
# [Epoch 237/1000] [Train_Loss: 0.597705 /Valid_Loss: 0.583337]
# [Epoch 237/1000] [Accuracy  : 0.744712]
# [Epoch 238/1000] [Train_Loss: 0.585076 /Valid_Loss: 0.578077]
# [Epoch 238/1000] [Accuracy  : 0.750350]
# [Epoch 239/1000] [Train_Loss: 0.569817 /Valid_Loss: 0.576513]
# [Epoch 239/1000] [Accuracy  : 0.749450]
# [Epoch 240/1000] [Train_Loss: 0.593238 /Valid_Loss: 0.583665]
# [Epoch 240/1000] [Accuracy  : 0.743263]
# [Epoch 241/1000] [Train_Loss: 0.596875 /Valid_Loss: 0.576946]
# [Epoch 241/1000] [Accuracy  : 0.749525]
# [Epoch 242/1000] [Train_Loss: 0.590184 /Valid_Loss: 0.579177]
# [Epoch 242/1000] [Accuracy  : 0.749375]
# [Epoch 243/1000] [Train_Loss: 0.566848 /Valid_Loss: 0.577495]
# [Epoch 243/1000] [Accuracy  : 0.750200]
# [Epoch 244/1000] [Train_Loss: 0.573536 /Valid_Loss: 0.577131]
# [Epoch 244/1000] [Accuracy  : 0.748088]
# [Epoch 245/1000] [Train_Loss: 0.590764 /Valid_Loss: 0.576965]
# [Epoch 245/1000] [Accuracy  : 0.748563]
# [Epoch 246/1000] [Train_Loss: 0.580673 /Valid_Loss: 0.583479]
# [Epoch 246/1000] [Accuracy  : 0.744413]
# [Epoch 247/1000] [Train_Loss: 0.581525 /Valid_Loss: 0.583864]
# [Epoch 247/1000] [Accuracy  : 0.743563]
# [Epoch 248/1000] [Train_Loss: 0.571495 /Valid_Loss: 0.576934]
# [Epoch 248/1000] [Accuracy  : 0.749600]
# [Epoch 249/1000] [Train_Loss: 0.574594 /Valid_Loss: 0.586047]
# [Epoch 249/1000] [Accuracy  : 0.741688]
# [Epoch 250/1000] [Train_Loss: 0.585613 /Valid_Loss: 0.581876]
# [Epoch 250/1000] [Accuracy  : 0.748775]
# [Epoch 251/1000] [Train_Loss: 0.581994 /Valid_Loss: 0.581779]
# [Epoch 251/1000] [Accuracy  : 0.748112]
# [Epoch 252/1000] [Train_Loss: 0.577274 /Valid_Loss: 0.579772]
# [Epoch 252/1000] [Accuracy  : 0.746162]
# [Epoch 253/1000] [Train_Loss: 0.561787 /Valid_Loss: 0.583165]
# [Epoch 253/1000] [Accuracy  : 0.745700]
# [Epoch 254/1000] [Train_Loss: 0.587364 /Valid_Loss: 0.579489]
# [Epoch 254/1000] [Accuracy  : 0.747012]
# [Epoch 255/1000] [Train_Loss: 0.579537 /Valid_Loss: 0.573675]
# [Epoch 255/1000] [Accuracy  : 0.749938]
# [Epoch 256/1000] [Train_Loss: 0.572180 /Valid_Loss: 0.576567]
# [Epoch 256/1000] [Accuracy  : 0.749238]
# [Epoch 257/1000] [Train_Loss: 0.587992 /Valid_Loss: 0.580473]
# [Epoch 257/1000] [Accuracy  : 0.745950]
# [Epoch 258/1000] [Train_Loss: 0.590878 /Valid_Loss: 0.583603]
# [Epoch 258/1000] [Accuracy  : 0.743162]
# [Epoch 259/1000] [Train_Loss: 0.596983 /Valid_Loss: 0.580843]
# [Epoch 259/1000] [Accuracy  : 0.747287]
# [Epoch 260/1000] [Train_Loss: 0.561844 /Valid_Loss: 0.581748]
# [Epoch 260/1000] [Accuracy  : 0.745500]
# [Epoch 261/1000] [Train_Loss: 0.569882 /Valid_Loss: 0.579794]
# [Epoch 261/1000] [Accuracy  : 0.748400]
# [Epoch 262/1000] [Train_Loss: 0.582164 /Valid_Loss: 0.579272]
# [Epoch 262/1000] [Accuracy  : 0.745325]
# [Epoch 263/1000] [Train_Loss: 0.582186 /Valid_Loss: 0.579398]
# [Epoch 263/1000] [Accuracy  : 0.745400]
# [Epoch 264/1000] [Train_Loss: 0.583193 /Valid_Loss: 0.581426]
# [Epoch 264/1000] [Accuracy  : 0.747675]
# [Epoch 265/1000] [Train_Loss: 0.589763 /Valid_Loss: 0.579264]
# [Epoch 265/1000] [Accuracy  : 0.745012]
# [Epoch 266/1000] [Train_Loss: 0.576842 /Valid_Loss: 0.581606]
# [Epoch 266/1000] [Accuracy  : 0.746125]
# [Epoch 267/1000] [Train_Loss: 0.585317 /Valid_Loss: 0.575460]
# [Epoch 267/1000] [Accuracy  : 0.748687]
# [Epoch 268/1000] [Train_Loss: 0.565494 /Valid_Loss: 0.583009]
# [Epoch 268/1000] [Accuracy  : 0.745075]
# [Epoch 269/1000] [Train_Loss: 0.579959 /Valid_Loss: 0.575593]
# [Epoch 269/1000] [Accuracy  : 0.749650]
# [Epoch 270/1000] [Train_Loss: 0.570295 /Valid_Loss: 0.576269]
# [Epoch 270/1000] [Accuracy  : 0.747950]
# [Epoch 271/1000] [Train_Loss: 0.582161 /Valid_Loss: 0.575713]
# [Epoch 271/1000] [Accuracy  : 0.749962]
# [Epoch 272/1000] [Train_Loss: 0.579061 /Valid_Loss: 0.579682]
# [Epoch 272/1000] [Accuracy  : 0.746950]
# [Epoch 273/1000] [Train_Loss: 0.573952 /Valid_Loss: 0.575108]
# [Epoch 273/1000] [Accuracy  : 0.750625]
# [Epoch 274/1000] [Train_Loss: 0.570446 /Valid_Loss: 0.578145]
# [Epoch 274/1000] [Accuracy  : 0.746788]
# [Epoch 275/1000] [Train_Loss: 0.580920 /Valid_Loss: 0.584382]
# [Epoch 275/1000] [Accuracy  : 0.744812]
# [Epoch 276/1000] [Train_Loss: 0.575285 /Valid_Loss: 0.573856]
# [Epoch 276/1000] [Accuracy  : 0.752287]
# [Epoch 277/1000] [Train_Loss: 0.564691 /Valid_Loss: 0.576728]
# [Epoch 277/1000] [Accuracy  : 0.748325]
# [Epoch 278/1000] [Train_Loss: 0.566534 /Valid_Loss: 0.579174]
# [Epoch 278/1000] [Accuracy  : 0.747838]
# [Epoch 279/1000] [Train_Loss: 0.566028 /Valid_Loss: 0.579431]
# [Epoch 279/1000] [Accuracy  : 0.746188]
# [Epoch 280/1000] [Train_Loss: 0.576340 /Valid_Loss: 0.579559]
# [Epoch 280/1000] [Accuracy  : 0.743000]
# [Epoch 281/1000] [Train_Loss: 0.599089 /Valid_Loss: 0.577499]
# [Epoch 281/1000] [Accuracy  : 0.750000]
# [Epoch 282/1000] [Train_Loss: 0.574412 /Valid_Loss: 0.580349]
# [Epoch 282/1000] [Accuracy  : 0.747812]
# [Epoch 283/1000] [Train_Loss: 0.584535 /Valid_Loss: 0.577581]
# [Epoch 283/1000] [Accuracy  : 0.745350]
# [Epoch 284/1000] [Train_Loss: 0.563678 /Valid_Loss: 0.581129]
# [Epoch 284/1000] [Accuracy  : 0.745275]
# [Epoch 285/1000] [Train_Loss: 0.572352 /Valid_Loss: 0.573878]
# [Epoch 285/1000] [Accuracy  : 0.751150]
# [Epoch 286/1000] [Train_Loss: 0.572622 /Valid_Loss: 0.577791]
# [Epoch 286/1000] [Accuracy  : 0.750125]
# [Epoch 287/1000] [Train_Loss: 0.585482 /Valid_Loss: 0.579066]
# [Epoch 287/1000] [Accuracy  : 0.745988]
# [Epoch 288/1000] [Train_Loss: 0.559979 /Valid_Loss: 0.577916]
# [Epoch 288/1000] [Accuracy  : 0.746663]
# [Epoch 289/1000] [Train_Loss: 0.580324 /Valid_Loss: 0.578411]
# [Epoch 289/1000] [Accuracy  : 0.745463]
# [Epoch 290/1000] [Train_Loss: 0.576345 /Valid_Loss: 0.574919]
# [Epoch 290/1000] [Accuracy  : 0.748088]
# [Epoch 291/1000] [Train_Loss: 0.584682 /Valid_Loss: 0.578840]
# [Epoch 291/1000] [Accuracy  : 0.746725]
# [Epoch 292/1000] [Train_Loss: 0.582407 /Valid_Loss: 0.581597]
# [Epoch 292/1000] [Accuracy  : 0.745950]
# [Epoch 293/1000] [Train_Loss: 0.577767 /Valid_Loss: 0.577435]
# [Epoch 293/1000] [Accuracy  : 0.748450]
# [Epoch 294/1000] [Train_Loss: 0.559193 /Valid_Loss: 0.578888]
# [Epoch 294/1000] [Accuracy  : 0.748038]
# [Epoch 295/1000] [Train_Loss: 0.589871 /Valid_Loss: 0.575642]
# [Epoch 295/1000] [Accuracy  : 0.749788]
# [Epoch 296/1000] [Train_Loss: 0.562472 /Valid_Loss: 0.577081]
# [Epoch 296/1000] [Accuracy  : 0.747375]
# [Epoch 297/1000] [Train_Loss: 0.569536 /Valid_Loss: 0.575860]
# [Epoch 297/1000] [Accuracy  : 0.749012]
# [Epoch 298/1000] [Train_Loss: 0.595076 /Valid_Loss: 0.578299]
# [Epoch 298/1000] [Accuracy  : 0.748637]
# [Epoch 299/1000] [Train_Loss: 0.575063 /Valid_Loss: 0.578957]
# [Epoch 299/1000] [Accuracy  : 0.745350]
# [Epoch 300/1000] [Train_Loss: 0.574487 /Valid_Loss: 0.577605]
# [Epoch 300/1000] [Accuracy  : 0.747225]
# [Epoch 301/1000] [Train_Loss: 0.558251 /Valid_Loss: 0.576258]
# [Epoch 301/1000] [Accuracy  : 0.748025]
# [Epoch 302/1000] [Train_Loss: 0.564334 /Valid_Loss: 0.573659]
# [Epoch 302/1000] [Accuracy  : 0.749700]
# [Epoch 303/1000] [Train_Loss: 0.587412 /Valid_Loss: 0.579726]
# [Epoch 303/1000] [Accuracy  : 0.744650]
# [Epoch 304/1000] [Train_Loss: 0.582568 /Valid_Loss: 0.578498]
# [Epoch 304/1000] [Accuracy  : 0.747075]
# [Epoch 305/1000] [Train_Loss: 0.568523 /Valid_Loss: 0.578244]
# [Epoch 305/1000] [Accuracy  : 0.747450]
# [Epoch 306/1000] [Train_Loss: 0.576608 /Valid_Loss: 0.574654]
# [Epoch 306/1000] [Accuracy  : 0.748125]
# [Epoch 307/1000] [Train_Loss: 0.590019 /Valid_Loss: 0.574114]
# [Epoch 307/1000] [Accuracy  : 0.749513]
# [Epoch 308/1000] [Train_Loss: 0.603209 /Valid_Loss: 0.572267]
# [Epoch 308/1000] [Accuracy  : 0.751062]
# [Epoch 309/1000] [Train_Loss: 0.565300 /Valid_Loss: 0.579011]
# [Epoch 309/1000] [Accuracy  : 0.748038]
# [Epoch 310/1000] [Train_Loss: 0.561896 /Valid_Loss: 0.577262]
# [Epoch 310/1000] [Accuracy  : 0.748663]
# [Epoch 311/1000] [Train_Loss: 0.566039 /Valid_Loss: 0.572811]
# [Epoch 311/1000] [Accuracy  : 0.750162]
# [Epoch 312/1000] [Train_Loss: 0.584302 /Valid_Loss: 0.577973]
# [Epoch 312/1000] [Accuracy  : 0.747162]
# [Epoch 313/1000] [Train_Loss: 0.565644 /Valid_Loss: 0.576504]
# [Epoch 313/1000] [Accuracy  : 0.747062]
# [Epoch 314/1000] [Train_Loss: 0.564899 /Valid_Loss: 0.575760]
# [Epoch 314/1000] [Accuracy  : 0.747487]
# [Epoch 315/1000] [Train_Loss: 0.572313 /Valid_Loss: 0.576675]
# [Epoch 315/1000] [Accuracy  : 0.748637]
# [Epoch 316/1000] [Train_Loss: 0.574860 /Valid_Loss: 0.579715]
# [Epoch 316/1000] [Accuracy  : 0.749150]
# [Epoch 317/1000] [Train_Loss: 0.578037 /Valid_Loss: 0.578666]
# [Epoch 317/1000] [Accuracy  : 0.747663]
# [Epoch 318/1000] [Train_Loss: 0.587598 /Valid_Loss: 0.572716]
# [Epoch 318/1000] [Accuracy  : 0.752437]
# [Epoch 319/1000] [Train_Loss: 0.578662 /Valid_Loss: 0.573666]
# [Epoch 319/1000] [Accuracy  : 0.751337]
# [Epoch 320/1000] [Train_Loss: 0.587982 /Valid_Loss: 0.581703]
# [Epoch 320/1000] [Accuracy  : 0.746962]
# [Epoch 321/1000] [Train_Loss: 0.579757 /Valid_Loss: 0.576320]
# [Epoch 321/1000] [Accuracy  : 0.749975]
# [Epoch 322/1000] [Train_Loss: 0.569978 /Valid_Loss: 0.580374]
# [Epoch 322/1000] [Accuracy  : 0.745962]
# [Epoch 323/1000] [Train_Loss: 0.583014 /Valid_Loss: 0.580986]
# [Epoch 323/1000] [Accuracy  : 0.747287]
# [Epoch 324/1000] [Train_Loss: 0.566446 /Valid_Loss: 0.575458]
# [Epoch 324/1000] [Accuracy  : 0.748975]
# [Epoch 325/1000] [Train_Loss: 0.582193 /Valid_Loss: 0.579620]
# [Epoch 325/1000] [Accuracy  : 0.747038]
# [Epoch 326/1000] [Train_Loss: 0.596303 /Valid_Loss: 0.576988]
# [Epoch 326/1000] [Accuracy  : 0.749212]
# [Epoch 327/1000] [Train_Loss: 0.577105 /Valid_Loss: 0.575156]
# [Epoch 327/1000] [Accuracy  : 0.750450]
# [Epoch 328/1000] [Train_Loss: 0.563646 /Valid_Loss: 0.578381]
# [Epoch 328/1000] [Accuracy  : 0.744912]
# [Epoch 329/1000] [Train_Loss: 0.600836 /Valid_Loss: 0.576403]
# [Epoch 329/1000] [Accuracy  : 0.749150]
# [Epoch 330/1000] [Train_Loss: 0.581053 /Valid_Loss: 0.572690]
# [Epoch 330/1000] [Accuracy  : 0.750950]
# [Epoch 331/1000] [Train_Loss: 0.583901 /Valid_Loss: 0.573353]
# [Epoch 331/1000] [Accuracy  : 0.751000]
# [Epoch 332/1000] [Train_Loss: 0.568534 /Valid_Loss: 0.574160]
# [Epoch 332/1000] [Accuracy  : 0.750125]
# [Epoch 333/1000] [Train_Loss: 0.575474 /Valid_Loss: 0.572534]
# [Epoch 333/1000] [Accuracy  : 0.750825]
# [Epoch 334/1000] [Train_Loss: 0.578355 /Valid_Loss: 0.570506]
# [Epoch 334/1000] [Accuracy  : 0.750737]
# [Epoch 335/1000] [Train_Loss: 0.558663 /Valid_Loss: 0.583100]
# [Epoch 335/1000] [Accuracy  : 0.744050]
# [Epoch 336/1000] [Train_Loss: 0.577517 /Valid_Loss: 0.575850]
# [Epoch 336/1000] [Accuracy  : 0.748025]
# [Epoch 337/1000] [Train_Loss: 0.575768 /Valid_Loss: 0.573156]
# [Epoch 337/1000] [Accuracy  : 0.748750]
# [Epoch 338/1000] [Train_Loss: 0.594619 /Valid_Loss: 0.573758]
# [Epoch 338/1000] [Accuracy  : 0.750250]
# [Epoch 339/1000] [Train_Loss: 0.577003 /Valid_Loss: 0.571858]
# [Epoch 339/1000] [Accuracy  : 0.747400]
# [Epoch 340/1000] [Train_Loss: 0.578034 /Valid_Loss: 0.577335]
# [Epoch 340/1000] [Accuracy  : 0.748300]
# [Epoch 341/1000] [Train_Loss: 0.579486 /Valid_Loss: 0.574165]
# [Epoch 341/1000] [Accuracy  : 0.749800]
# [Epoch 342/1000] [Train_Loss: 0.573714 /Valid_Loss: 0.573610]
# [Epoch 342/1000] [Accuracy  : 0.750962]
# [Epoch 343/1000] [Train_Loss: 0.567060 /Valid_Loss: 0.575583]
# [Epoch 343/1000] [Accuracy  : 0.748162]
# [Epoch 344/1000] [Train_Loss: 0.563389 /Valid_Loss: 0.578389]
# [Epoch 344/1000] [Accuracy  : 0.745888]
# [Epoch 345/1000] [Train_Loss: 0.580394 /Valid_Loss: 0.575128]
# [Epoch 345/1000] [Accuracy  : 0.748413]
# [Epoch 346/1000] [Train_Loss: 0.579225 /Valid_Loss: 0.580086]
# [Epoch 346/1000] [Accuracy  : 0.744750]
# [Epoch 347/1000] [Train_Loss: 0.585027 /Valid_Loss: 0.578299]
# [Epoch 347/1000] [Accuracy  : 0.745700]
# [Epoch 348/1000] [Train_Loss: 0.574764 /Valid_Loss: 0.573547]
# [Epoch 348/1000] [Accuracy  : 0.748225]
# [Epoch 349/1000] [Train_Loss: 0.573367 /Valid_Loss: 0.577333]
# [Epoch 349/1000] [Accuracy  : 0.746687]
# [Epoch 350/1000] [Train_Loss: 0.583824 /Valid_Loss: 0.573751]
# [Epoch 350/1000] [Accuracy  : 0.751275]
# [Epoch 351/1000] [Train_Loss: 0.578659 /Valid_Loss: 0.574673]
# [Epoch 351/1000] [Accuracy  : 0.749263]
# [Epoch 352/1000] [Train_Loss: 0.559722 /Valid_Loss: 0.577617]
# [Epoch 352/1000] [Accuracy  : 0.747075]
# [Epoch 353/1000] [Train_Loss: 0.595568 /Valid_Loss: 0.574944]
# [Epoch 353/1000] [Accuracy  : 0.750212]
# [Epoch 354/1000] [Train_Loss: 0.571948 /Valid_Loss: 0.576942]
# [Epoch 354/1000] [Accuracy  : 0.748100]
# [Epoch 355/1000] [Train_Loss: 0.577160 /Valid_Loss: 0.580676]
# [Epoch 355/1000] [Accuracy  : 0.746938]
# [Epoch 356/1000] [Train_Loss: 0.573135 /Valid_Loss: 0.572683]
# [Epoch 356/1000] [Accuracy  : 0.750437]
# [Epoch 357/1000] [Train_Loss: 0.581429 /Valid_Loss: 0.573796]
# [Epoch 357/1000] [Accuracy  : 0.747112]
# [Epoch 358/1000] [Train_Loss: 0.576180 /Valid_Loss: 0.580927]
# [Epoch 358/1000] [Accuracy  : 0.745513]
# [Epoch 359/1000] [Train_Loss: 0.562588 /Valid_Loss: 0.572505]
# [Epoch 359/1000] [Accuracy  : 0.751162]
# [Epoch 360/1000] [Train_Loss: 0.554859 /Valid_Loss: 0.572074]
# [Epoch 360/1000] [Accuracy  : 0.751713]
# [Epoch 361/1000] [Train_Loss: 0.579212 /Valid_Loss: 0.569698]
# [Epoch 361/1000] [Accuracy  : 0.752313]
# [Epoch 362/1000] [Train_Loss: 0.585521 /Valid_Loss: 0.571546]
# [Epoch 362/1000] [Accuracy  : 0.751500]
# [Epoch 363/1000] [Train_Loss: 0.577947 /Valid_Loss: 0.584975]
# [Epoch 363/1000] [Accuracy  : 0.743825]
# [Epoch 364/1000] [Train_Loss: 0.566389 /Valid_Loss: 0.582822]
# [Epoch 364/1000] [Accuracy  : 0.746375]
# [Epoch 365/1000] [Train_Loss: 0.559104 /Valid_Loss: 0.572042]
# [Epoch 365/1000] [Accuracy  : 0.752375]
# [Epoch 366/1000] [Train_Loss: 0.571213 /Valid_Loss: 0.576021]
# [Epoch 366/1000] [Accuracy  : 0.750350]
# [Epoch 367/1000] [Train_Loss: 0.581114 /Valid_Loss: 0.574079]
# [Epoch 367/1000] [Accuracy  : 0.748750]
# [Epoch 368/1000] [Train_Loss: 0.575707 /Valid_Loss: 0.575562]
# [Epoch 368/1000] [Accuracy  : 0.749437]
# [Epoch 369/1000] [Train_Loss: 0.584828 /Valid_Loss: 0.572925]
# [Epoch 369/1000] [Accuracy  : 0.750263]
# This is time to do early stopping
# 모델 저장: /content/gdrive/My Drive/Colab Notebooks/kamp/14. Dataset_Rotor/cnn_model.pt

# %% [markdown]
# #### (1) 모델 평가

# %%
PATH = dir+'cnn_'
test_model(CNN_model, PATH)
# Out:
# 0.7653875

# %% [markdown]
# #### (2) 혼동 행렬 (Confusion matrix)

# %%
draw_confusion_matrix(CNN_model, x_test, y_test, PATH)

# %% [markdown]
# #### (3) 손실(Loss) 그래프

# %%
plot_loss_graph(CNN_loss_values, CNN_loss_values_v)

# %% [markdown]
# ### 5-3. 순환신경망 (RNN) 모델  성능 평가

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

RNN_model = KAMP_RNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(RNN_model.parameters())
PATH = dir+'rnn_'

RNN_loss_values, RNN_loss_values_v = train_model(RNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

RNN_model = KAMP_RNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(RNN_model.parameters())
PATH = dir+'rnn_'

RNN_loss_values, RNN_loss_values_v = train_model(RNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)
# Out:
# [Epoch 1/1000] [Train_Loss: 1.386286 /Valid_Loss: 1.386296]
# [Epoch 1/1000] [Accuracy  : 0.250000]
# [Epoch 2/1000] [Train_Loss: 1.386283 /Valid_Loss: 1.386285]
# [Epoch 2/1000] [Accuracy  : 0.181188]
# [Epoch 3/1000] [Train_Loss: 1.385626 /Valid_Loss: 1.385616]
# [Epoch 3/1000] [Accuracy  : 0.254638]
# [Epoch 4/1000] [Train_Loss: 1.354522 /Valid_Loss: 1.350937]
# [Epoch 4/1000] [Accuracy  : 0.340250]
# [Epoch 5/1000] [Train_Loss: 1.101304 /Valid_Loss: 1.090884]
# [Epoch 5/1000] [Accuracy  : 0.435663]
# [Epoch 6/1000] [Train_Loss: 1.094972 /Valid_Loss: 1.086760]
# [Epoch 6/1000] [Accuracy  : 0.458225]
# [Epoch 7/1000] [Train_Loss: 1.082522 /Valid_Loss: 1.083255]
# [Epoch 7/1000] [Accuracy  : 0.448937]
# [Epoch 8/1000] [Train_Loss: 1.088694 /Valid_Loss: 1.080781]
# [Epoch 8/1000] [Accuracy  : 0.448462]
# [Epoch 9/1000] [Train_Loss: 1.091583 /Valid_Loss: 1.078531]
# [Epoch 9/1000] [Accuracy  : 0.435025]
# [Epoch 10/1000] [Train_Loss: 1.082412 /Valid_Loss: 1.076624]
# [Epoch 10/1000] [Accuracy  : 0.461012]
# [Epoch 11/1000] [Train_Loss: 1.083443 /Valid_Loss: 1.073031]
# [Epoch 11/1000] [Accuracy  : 0.455238]
# [Epoch 12/1000] [Train_Loss: 1.077560 /Valid_Loss: 1.069298]
# [Epoch 12/1000] [Accuracy  : 0.457700]
# [Epoch 13/1000] [Train_Loss: 1.069799 /Valid_Loss: 1.063424]
# [Epoch 13/1000] [Accuracy  : 0.450387]
# [Epoch 14/1000] [Train_Loss: 1.059820 /Valid_Loss: 1.053931]
# [Epoch 14/1000] [Accuracy  : 0.469900]
# [Epoch 15/1000] [Train_Loss: 1.050209 /Valid_Loss: 1.038547]
# [Epoch 15/1000] [Accuracy  : 0.487013]
# [Epoch 16/1000] [Train_Loss: 1.017868 /Valid_Loss: 1.009051]
# [Epoch 16/1000] [Accuracy  : 0.478950]
# [Epoch 17/1000] [Train_Loss: 0.986617 /Valid_Loss: 0.950741]
# [Epoch 17/1000] [Accuracy  : 0.517737]
# [Epoch 18/1000] [Train_Loss: 0.895552 /Valid_Loss: 0.868058]
# [Epoch 18/1000] [Accuracy  : 0.536100]
# [Epoch 19/1000] [Train_Loss: 0.858046 /Valid_Loss: 0.839604]
# [Epoch 19/1000] [Accuracy  : 0.541950]
# [Epoch 20/1000] [Train_Loss: 0.851634 /Valid_Loss: 0.833098]
# [Epoch 20/1000] [Accuracy  : 0.548350]
# [Epoch 21/1000] [Train_Loss: 0.840844 /Valid_Loss: 0.828127]
# [Epoch 21/1000] [Accuracy  : 0.538875]
# [Epoch 22/1000] [Train_Loss: 0.847913 /Valid_Loss: 0.825185]
# [Epoch 22/1000] [Accuracy  : 0.552713]
# [Epoch 23/1000] [Train_Loss: 0.846221 /Valid_Loss: 0.820809]
# [Epoch 23/1000] [Accuracy  : 0.550937]
# [Epoch 24/1000] [Train_Loss: 0.843734 /Valid_Loss: 0.818793]
# [Epoch 24/1000] [Accuracy  : 0.555975]
# [Epoch 25/1000] [Train_Loss: 0.815370 /Valid_Loss: 0.816484]
# [Epoch 25/1000] [Accuracy  : 0.560763]
# [Epoch 26/1000] [Train_Loss: 0.823363 /Valid_Loss: 0.811252]
# [Epoch 26/1000] [Accuracy  : 0.562488]
# [Epoch 27/1000] [Train_Loss: 0.845057 /Valid_Loss: 0.809860]
# [Epoch 27/1000] [Accuracy  : 0.559187]
# [Epoch 28/1000] [Train_Loss: 0.831600 /Valid_Loss: 0.806255]
# [Epoch 28/1000] [Accuracy  : 0.566825]
# [Epoch 29/1000] [Train_Loss: 0.838008 /Valid_Loss: 0.802280]
# [Epoch 29/1000] [Accuracy  : 0.566562]
# [Epoch 30/1000] [Train_Loss: 0.822287 /Valid_Loss: 0.801006]
# [Epoch 30/1000] [Accuracy  : 0.578025]
# [Epoch 31/1000] [Train_Loss: 0.832790 /Valid_Loss: 0.797303]
# [Epoch 31/1000] [Accuracy  : 0.578987]
# [Epoch 32/1000] [Train_Loss: 0.818372 /Valid_Loss: 0.796301]
# [Epoch 32/1000] [Accuracy  : 0.584250]
# [Epoch 33/1000] [Train_Loss: 0.814699 /Valid_Loss: 0.793741]
# [Epoch 33/1000] [Accuracy  : 0.584363]
# [Epoch 34/1000] [Train_Loss: 0.824342 /Valid_Loss: 0.788889]
# [Epoch 34/1000] [Accuracy  : 0.585488]
# [Epoch 35/1000] [Train_Loss: 0.815586 /Valid_Loss: 0.787781]
# [Epoch 35/1000] [Accuracy  : 0.596838]
# [Epoch 36/1000] [Train_Loss: 0.803093 /Valid_Loss: 0.784976]
# [Epoch 36/1000] [Accuracy  : 0.591150]
# [Epoch 37/1000] [Train_Loss: 0.806220 /Valid_Loss: 0.784438]
# [Epoch 37/1000] [Accuracy  : 0.597050]
# [Epoch 38/1000] [Train_Loss: 0.807510 /Valid_Loss: 0.779031]
# [Epoch 38/1000] [Accuracy  : 0.597450]
# [Epoch 39/1000] [Train_Loss: 0.800690 /Valid_Loss: 0.775824]
# [Epoch 39/1000] [Accuracy  : 0.597550]
# [Epoch 40/1000] [Train_Loss: 0.803323 /Valid_Loss: 0.774714]
# [Epoch 40/1000] [Accuracy  : 0.599025]
# [Epoch 41/1000] [Train_Loss: 0.795174 /Valid_Loss: 0.774737]
# [Epoch 41/1000] [Accuracy  : 0.608112]
# [Epoch 42/1000] [Train_Loss: 0.781987 /Valid_Loss: 0.770972]
# [Epoch 42/1000] [Accuracy  : 0.613000]
# [Epoch 43/1000] [Train_Loss: 0.789919 /Valid_Loss: 0.772378]
# [Epoch 43/1000] [Accuracy  : 0.613487]
# [Epoch 44/1000] [Train_Loss: 0.796210 /Valid_Loss: 0.767756]
# [Epoch 44/1000] [Accuracy  : 0.615387]
# [Epoch 45/1000] [Train_Loss: 0.787171 /Valid_Loss: 0.766062]
# [Epoch 45/1000] [Accuracy  : 0.615337]
# [Epoch 46/1000] [Train_Loss: 0.796022 /Valid_Loss: 0.766373]
# [Epoch 46/1000] [Accuracy  : 0.619275]
# [Epoch 47/1000] [Train_Loss: 0.789856 /Valid_Loss: 0.764315]
# [Epoch 47/1000] [Accuracy  : 0.617463]
# [Epoch 48/1000] [Train_Loss: 0.792825 /Valid_Loss: 0.762329]
# [Epoch 48/1000] [Accuracy  : 0.618775]
# [Epoch 49/1000] [Train_Loss: 0.766698 /Valid_Loss: 0.761264]
# [Epoch 49/1000] [Accuracy  : 0.617962]
# [Epoch 50/1000] [Train_Loss: 0.787885 /Valid_Loss: 0.760917]
# [Epoch 50/1000] [Accuracy  : 0.615038]
# [Epoch 51/1000] [Train_Loss: 0.786420 /Valid_Loss: 0.763469]
# [Epoch 51/1000] [Accuracy  : 0.619537]
# [Epoch 52/1000] [Train_Loss: 0.772813 /Valid_Loss: 0.761426]
# [Epoch 52/1000] [Accuracy  : 0.619575]
# [Epoch 53/1000] [Train_Loss: 0.770511 /Valid_Loss: 0.758355]
# [Epoch 53/1000] [Accuracy  : 0.623700]
# [Epoch 54/1000] [Train_Loss: 0.771655 /Valid_Loss: 0.760161]
# [Epoch 54/1000] [Accuracy  : 0.620625]
# [Epoch 55/1000] [Train_Loss: 0.786490 /Valid_Loss: 0.760511]
# [Epoch 55/1000] [Accuracy  : 0.622800]
# [Epoch 56/1000] [Train_Loss: 0.762981 /Valid_Loss: 0.760033]
# [Epoch 56/1000] [Accuracy  : 0.616750]
# [Epoch 57/1000] [Train_Loss: 0.769989 /Valid_Loss: 0.758282]
# [Epoch 57/1000] [Accuracy  : 0.623200]
# [Epoch 58/1000] [Train_Loss: 0.764709 /Valid_Loss: 0.756452]
# [Epoch 58/1000] [Accuracy  : 0.621200]
# [Epoch 59/1000] [Train_Loss: 0.786839 /Valid_Loss: 0.756994]
# [Epoch 59/1000] [Accuracy  : 0.624613]
# [Epoch 60/1000] [Train_Loss: 0.778527 /Valid_Loss: 0.756588]
# [Epoch 60/1000] [Accuracy  : 0.617213]
# [Epoch 61/1000] [Train_Loss: 0.755462 /Valid_Loss: 0.755334]
# [Epoch 61/1000] [Accuracy  : 0.621088]
# [Epoch 62/1000] [Train_Loss: 0.755625 /Valid_Loss: 0.756019]
# [Epoch 62/1000] [Accuracy  : 0.619712]
# [Epoch 63/1000] [Train_Loss: 0.767961 /Valid_Loss: 0.753007]
# [Epoch 63/1000] [Accuracy  : 0.619150]
# [Epoch 64/1000] [Train_Loss: 0.766894 /Valid_Loss: 0.754485]
# [Epoch 64/1000] [Accuracy  : 0.620800]
# [Epoch 65/1000] [Train_Loss: 0.757015 /Valid_Loss: 0.751747]
# [Epoch 65/1000] [Accuracy  : 0.624875]
# [Epoch 66/1000] [Train_Loss: 0.760496 /Valid_Loss: 0.753200]
# [Epoch 66/1000] [Accuracy  : 0.622450]
# [Epoch 67/1000] [Train_Loss: 0.757271 /Valid_Loss: 0.754590]
# [Epoch 67/1000] [Accuracy  : 0.622812]
# [Epoch 68/1000] [Train_Loss: 0.753051 /Valid_Loss: 0.754467]
# [Epoch 68/1000] [Accuracy  : 0.618513]
# [Epoch 69/1000] [Train_Loss: 0.769974 /Valid_Loss: 0.751777]
# [Epoch 69/1000] [Accuracy  : 0.617263]
# [Epoch 70/1000] [Train_Loss: 0.750925 /Valid_Loss: 0.753728]
# [Epoch 70/1000] [Accuracy  : 0.621463]
# [Epoch 71/1000] [Train_Loss: 0.762234 /Valid_Loss: 0.751059]
# [Epoch 71/1000] [Accuracy  : 0.617025]
# [Epoch 72/1000] [Train_Loss: 0.762364 /Valid_Loss: 0.749674]
# [Epoch 72/1000] [Accuracy  : 0.619275]
# [Epoch 73/1000] [Train_Loss: 0.755043 /Valid_Loss: 0.751985]
# [Epoch 73/1000] [Accuracy  : 0.622050]
# [Epoch 74/1000] [Train_Loss: 0.755989 /Valid_Loss: 0.750546]
# [Epoch 74/1000] [Accuracy  : 0.618825]
# [Epoch 75/1000] [Train_Loss: 0.757715 /Valid_Loss: 0.751172]
# [Epoch 75/1000] [Accuracy  : 0.618138]
# [Epoch 76/1000] [Train_Loss: 0.753747 /Valid_Loss: 0.751698]
# [Epoch 76/1000] [Accuracy  : 0.623663]
# [Epoch 77/1000] [Train_Loss: 0.754281 /Valid_Loss: 0.749048]
# [Epoch 77/1000] [Accuracy  : 0.616263]
# [Epoch 78/1000] [Train_Loss: 0.756363 /Valid_Loss: 0.748530]
# [Epoch 78/1000] [Accuracy  : 0.621888]
# [Epoch 79/1000] [Train_Loss: 0.733725 /Valid_Loss: 0.748849]
# [Epoch 79/1000] [Accuracy  : 0.618788]
# [Epoch 80/1000] [Train_Loss: 0.760685 /Valid_Loss: 0.746730]
# [Epoch 80/1000] [Accuracy  : 0.621387]
# [Epoch 81/1000] [Train_Loss: 0.755283 /Valid_Loss: 0.745465]
# [Epoch 81/1000] [Accuracy  : 0.620500]
# [Epoch 82/1000] [Train_Loss: 0.735434 /Valid_Loss: 0.749115]
# [Epoch 82/1000] [Accuracy  : 0.625188]
# [Epoch 83/1000] [Train_Loss: 0.735955 /Valid_Loss: 0.745952]
# [Epoch 83/1000] [Accuracy  : 0.622812]
# [Epoch 84/1000] [Train_Loss: 0.757884 /Valid_Loss: 0.745581]
# [Epoch 84/1000] [Accuracy  : 0.623675]
# [Epoch 85/1000] [Train_Loss: 0.752745 /Valid_Loss: 0.743416]
# [Epoch 85/1000] [Accuracy  : 0.621112]
# [Epoch 86/1000] [Train_Loss: 0.748642 /Valid_Loss: 0.744674]
# [Epoch 86/1000] [Accuracy  : 0.624487]
# [Epoch 87/1000] [Train_Loss: 0.744323 /Valid_Loss: 0.744391]
# [Epoch 87/1000] [Accuracy  : 0.617775]
# [Epoch 88/1000] [Train_Loss: 0.740056 /Valid_Loss: 0.743795]
# [Epoch 88/1000] [Accuracy  : 0.619275]
# [Epoch 89/1000] [Train_Loss: 0.752850 /Valid_Loss: 0.744731]
# [Epoch 89/1000] [Accuracy  : 0.622263]
# [Epoch 90/1000] [Train_Loss: 0.741172 /Valid_Loss: 0.744019]
# [Epoch 90/1000] [Accuracy  : 0.625025]
# [Epoch 91/1000] [Train_Loss: 0.725485 /Valid_Loss: 0.744616]
# [Epoch 91/1000] [Accuracy  : 0.632950]
# [Epoch 92/1000] [Train_Loss: 0.740782 /Valid_Loss: 0.740716]
# [Epoch 92/1000] [Accuracy  : 0.635513]
# [Epoch 93/1000] [Train_Loss: 0.729112 /Valid_Loss: 0.735904]
# [Epoch 93/1000] [Accuracy  : 0.637188]
# [Epoch 94/1000] [Train_Loss: 0.730400 /Valid_Loss: 0.733727]
# [Epoch 94/1000] [Accuracy  : 0.642950]
# [Epoch 95/1000] [Train_Loss: 0.724573 /Valid_Loss: 0.729165]
# [Epoch 95/1000] [Accuracy  : 0.648813]
# [Epoch 96/1000] [Train_Loss: 0.718744 /Valid_Loss: 0.723601]
# [Epoch 96/1000] [Accuracy  : 0.656438]
# [Epoch 97/1000] [Train_Loss: 0.720244 /Valid_Loss: 0.719121]
# [Epoch 97/1000] [Accuracy  : 0.667100]
# [Epoch 98/1000] [Train_Loss: 0.714279 /Valid_Loss: 0.710753]
# [Epoch 98/1000] [Accuracy  : 0.669963]
# [Epoch 99/1000] [Train_Loss: 0.705795 /Valid_Loss: 0.698716]
# [Epoch 99/1000] [Accuracy  : 0.677713]
# [Epoch 100/1000] [Train_Loss: 0.694226 /Valid_Loss: 0.688338]
# [Epoch 100/1000] [Accuracy  : 0.684288]
# [Epoch 101/1000] [Train_Loss: 0.677198 /Valid_Loss: 0.680400]
# [Epoch 101/1000] [Accuracy  : 0.686475]
# [Epoch 102/1000] [Train_Loss: 0.681346 /Valid_Loss: 0.674083]
# [Epoch 102/1000] [Accuracy  : 0.688612]
# [Epoch 103/1000] [Train_Loss: 0.658097 /Valid_Loss: 0.671091]
# [Epoch 103/1000] [Accuracy  : 0.685737]
# [Epoch 104/1000] [Train_Loss: 0.658548 /Valid_Loss: 0.665109]
# [Epoch 104/1000] [Accuracy  : 0.691512]
# [Epoch 105/1000] [Train_Loss: 0.648119 /Valid_Loss: 0.660555]
# [Epoch 105/1000] [Accuracy  : 0.696388]
# [Epoch 106/1000] [Train_Loss: 0.647230 /Valid_Loss: 0.657202]
# [Epoch 106/1000] [Accuracy  : 0.696887]
# [Epoch 107/1000] [Train_Loss: 0.644031 /Valid_Loss: 0.654340]
# [Epoch 107/1000] [Accuracy  : 0.697388]
# [Epoch 108/1000] [Train_Loss: 0.650490 /Valid_Loss: 0.652773]
# [Epoch 108/1000] [Accuracy  : 0.699213]
# [Epoch 109/1000] [Train_Loss: 0.630940 /Valid_Loss: 0.654747]
# [Epoch 109/1000] [Accuracy  : 0.693362]
# [Epoch 110/1000] [Train_Loss: 0.633682 /Valid_Loss: 0.649890]
# [Epoch 110/1000] [Accuracy  : 0.698125]
# [Epoch 111/1000] [Train_Loss: 0.644498 /Valid_Loss: 0.652494]
# [Epoch 111/1000] [Accuracy  : 0.696975]
# [Epoch 112/1000] [Train_Loss: 0.647685 /Valid_Loss: 0.651600]
# [Epoch 112/1000] [Accuracy  : 0.696700]
# [Epoch 113/1000] [Train_Loss: 0.631738 /Valid_Loss: 0.649188]
# [Epoch 113/1000] [Accuracy  : 0.699388]
# [Epoch 114/1000] [Train_Loss: 0.620167 /Valid_Loss: 0.644735]
# [Epoch 114/1000] [Accuracy  : 0.699350]
# [Epoch 115/1000] [Train_Loss: 0.628740 /Valid_Loss: 0.647329]
# [Epoch 115/1000] [Accuracy  : 0.697300]
# [Epoch 116/1000] [Train_Loss: 0.619031 /Valid_Loss: 0.647405]
# [Epoch 116/1000] [Accuracy  : 0.696225]
# [Epoch 117/1000] [Train_Loss: 0.616979 /Valid_Loss: 0.646595]
# [Epoch 117/1000] [Accuracy  : 0.699963]
# [Epoch 118/1000] [Train_Loss: 0.634234 /Valid_Loss: 0.645310]
# [Epoch 118/1000] [Accuracy  : 0.701550]
# [Epoch 119/1000] [Train_Loss: 0.618927 /Valid_Loss: 0.640397]
# [Epoch 119/1000] [Accuracy  : 0.700538]
# [Epoch 120/1000] [Train_Loss: 0.627786 /Valid_Loss: 0.638861]
# [Epoch 120/1000] [Accuracy  : 0.703688]
# [Epoch 121/1000] [Train_Loss: 0.630978 /Valid_Loss: 0.642034]
# [Epoch 121/1000] [Accuracy  : 0.702187]
# [Epoch 122/1000] [Train_Loss: 0.624001 /Valid_Loss: 0.640554]
# [Epoch 122/1000] [Accuracy  : 0.702538]
# [Epoch 123/1000] [Train_Loss: 0.624487 /Valid_Loss: 0.635286]
# [Epoch 123/1000] [Accuracy  : 0.706025]
# [Epoch 124/1000] [Train_Loss: 0.611068 /Valid_Loss: 0.637276]
# [Epoch 124/1000] [Accuracy  : 0.705488]
# [Epoch 125/1000] [Train_Loss: 0.601932 /Valid_Loss: 0.636385]
# [Epoch 125/1000] [Accuracy  : 0.705250]
# [Epoch 126/1000] [Train_Loss: 0.631479 /Valid_Loss: 0.634756]
# [Epoch 126/1000] [Accuracy  : 0.706412]
# [Epoch 127/1000] [Train_Loss: 0.623053 /Valid_Loss: 0.633128]
# [Epoch 127/1000] [Accuracy  : 0.707488]
# [Epoch 128/1000] [Train_Loss: 0.620526 /Valid_Loss: 0.632776]
# [Epoch 128/1000] [Accuracy  : 0.707725]
# [Epoch 129/1000] [Train_Loss: 0.598982 /Valid_Loss: 0.630604]
# [Epoch 129/1000] [Accuracy  : 0.710750]
# [Epoch 130/1000] [Train_Loss: 0.599292 /Valid_Loss: 0.630541]
# [Epoch 130/1000] [Accuracy  : 0.709987]
# [Epoch 131/1000] [Train_Loss: 0.607241 /Valid_Loss: 0.629751]
# [Epoch 131/1000] [Accuracy  : 0.708762]
# [Epoch 132/1000] [Train_Loss: 0.596091 /Valid_Loss: 0.629803]
# [Epoch 132/1000] [Accuracy  : 0.708013]
# [Epoch 133/1000] [Train_Loss: 0.595476 /Valid_Loss: 0.625173]
# [Epoch 133/1000] [Accuracy  : 0.712313]
# [Epoch 134/1000] [Train_Loss: 0.608019 /Valid_Loss: 0.625953]
# [Epoch 134/1000] [Accuracy  : 0.712688]
# [Epoch 135/1000] [Train_Loss: 0.601510 /Valid_Loss: 0.625910]
# [Epoch 135/1000] [Accuracy  : 0.712263]
# [Epoch 136/1000] [Train_Loss: 0.602499 /Valid_Loss: 0.624579]
# [Epoch 136/1000] [Accuracy  : 0.713550]
# [Epoch 137/1000] [Train_Loss: 0.611725 /Valid_Loss: 0.622529]
# [Epoch 137/1000] [Accuracy  : 0.714263]
# [Epoch 138/1000] [Train_Loss: 0.580305 /Valid_Loss: 0.620389]
# [Epoch 138/1000] [Accuracy  : 0.713975]
# [Epoch 139/1000] [Train_Loss: 0.604560 /Valid_Loss: 0.621847]
# [Epoch 139/1000] [Accuracy  : 0.715325]
# [Epoch 140/1000] [Train_Loss: 0.596457 /Valid_Loss: 0.618680]
# [Epoch 140/1000] [Accuracy  : 0.717063]
# [Epoch 141/1000] [Train_Loss: 0.598677 /Valid_Loss: 0.617808]
# [Epoch 141/1000] [Accuracy  : 0.718125]
# [Epoch 142/1000] [Train_Loss: 0.607488 /Valid_Loss: 0.615087]
# [Epoch 142/1000] [Accuracy  : 0.719113]
# [Epoch 143/1000] [Train_Loss: 0.581834 /Valid_Loss: 0.616563]
# [Epoch 143/1000] [Accuracy  : 0.719275]
# [Epoch 144/1000] [Train_Loss: 0.573301 /Valid_Loss: 0.616624]
# [Epoch 144/1000] [Accuracy  : 0.719700]
# [Epoch 145/1000] [Train_Loss: 0.576500 /Valid_Loss: 0.613497]
# [Epoch 145/1000] [Accuracy  : 0.721487]
# [Epoch 146/1000] [Train_Loss: 0.586683 /Valid_Loss: 0.615102]
# [Epoch 146/1000] [Accuracy  : 0.721375]
# [Epoch 147/1000] [Train_Loss: 0.581292 /Valid_Loss: 0.610390]
# [Epoch 147/1000] [Accuracy  : 0.724500]
# [Epoch 148/1000] [Train_Loss: 0.578249 /Valid_Loss: 0.611414]
# [Epoch 148/1000] [Accuracy  : 0.724050]
# [Epoch 149/1000] [Train_Loss: 0.589270 /Valid_Loss: 0.609582]
# [Epoch 149/1000] [Accuracy  : 0.724850]
# [Epoch 150/1000] [Train_Loss: 0.582209 /Valid_Loss: 0.613217]
# [Epoch 150/1000] [Accuracy  : 0.723662]
# [Epoch 151/1000] [Train_Loss: 0.574542 /Valid_Loss: 0.607820]
# [Epoch 151/1000] [Accuracy  : 0.725712]
# [Epoch 152/1000] [Train_Loss: 0.577836 /Valid_Loss: 0.609609]
# [Epoch 152/1000] [Accuracy  : 0.724838]
# [Epoch 153/1000] [Train_Loss: 0.574798 /Valid_Loss: 0.609218]
# [Epoch 153/1000] [Accuracy  : 0.725838]
# [Epoch 154/1000] [Train_Loss: 0.573663 /Valid_Loss: 0.608606]
# [Epoch 154/1000] [Accuracy  : 0.725125]
# [Epoch 155/1000] [Train_Loss: 0.573369 /Valid_Loss: 0.607438]
# [Epoch 155/1000] [Accuracy  : 0.725950]
# [Epoch 156/1000] [Train_Loss: 0.561148 /Valid_Loss: 0.607934]
# [Epoch 156/1000] [Accuracy  : 0.728287]
# [Epoch 157/1000] [Train_Loss: 0.580232 /Valid_Loss: 0.607125]
# [Epoch 157/1000] [Accuracy  : 0.726750]
# [Epoch 158/1000] [Train_Loss: 0.570869 /Valid_Loss: 0.604856]
# [Epoch 158/1000] [Accuracy  : 0.728200]
# [Epoch 159/1000] [Train_Loss: 0.574289 /Valid_Loss: 0.602882]
# [Epoch 159/1000] [Accuracy  : 0.729612]
# [Epoch 160/1000] [Train_Loss: 0.563610 /Valid_Loss: 0.602691]
# [Epoch 160/1000] [Accuracy  : 0.730513]
# [Epoch 161/1000] [Train_Loss: 0.561938 /Valid_Loss: 0.605511]
# [Epoch 161/1000] [Accuracy  : 0.728712]
# [Epoch 162/1000] [Train_Loss: 0.573911 /Valid_Loss: 0.600620]
# [Epoch 162/1000] [Accuracy  : 0.731300]
# [Epoch 163/1000] [Train_Loss: 0.575154 /Valid_Loss: 0.598731]
# [Epoch 163/1000] [Accuracy  : 0.732537]
# [Epoch 164/1000] [Train_Loss: 0.579796 /Valid_Loss: 0.601905]
# [Epoch 164/1000] [Accuracy  : 0.730175]
# [Epoch 165/1000] [Train_Loss: 0.567485 /Valid_Loss: 0.599310]
# [Epoch 165/1000] [Accuracy  : 0.731888]
# [Epoch 166/1000] [Train_Loss: 0.566678 /Valid_Loss: 0.603226]
# [Epoch 166/1000] [Accuracy  : 0.729762]
# [Epoch 167/1000] [Train_Loss: 0.558208 /Valid_Loss: 0.598135]
# [Epoch 167/1000] [Accuracy  : 0.732400]
# [Epoch 168/1000] [Train_Loss: 0.563720 /Valid_Loss: 0.597719]
# [Epoch 168/1000] [Accuracy  : 0.732612]
# [Epoch 169/1000] [Train_Loss: 0.563552 /Valid_Loss: 0.597664]
# [Epoch 169/1000] [Accuracy  : 0.732187]
# [Epoch 170/1000] [Train_Loss: 0.557826 /Valid_Loss: 0.595884]
# [Epoch 170/1000] [Accuracy  : 0.733975]
# [Epoch 171/1000] [Train_Loss: 0.578818 /Valid_Loss: 0.596728]
# [Epoch 171/1000] [Accuracy  : 0.734187]
# [Epoch 172/1000] [Train_Loss: 0.554699 /Valid_Loss: 0.596591]
# [Epoch 172/1000] [Accuracy  : 0.732525]
# [Epoch 173/1000] [Train_Loss: 0.551133 /Valid_Loss: 0.597752]
# [Epoch 173/1000] [Accuracy  : 0.734050]
# [Epoch 174/1000] [Train_Loss: 0.550288 /Valid_Loss: 0.592182]
# [Epoch 174/1000] [Accuracy  : 0.737150]
# [Epoch 175/1000] [Train_Loss: 0.556598 /Valid_Loss: 0.595454]
# [Epoch 175/1000] [Accuracy  : 0.733675]
# [Epoch 176/1000] [Train_Loss: 0.561997 /Valid_Loss: 0.594222]
# [Epoch 176/1000] [Accuracy  : 0.734563]
# [Epoch 177/1000] [Train_Loss: 0.555707 /Valid_Loss: 0.594787]
# [Epoch 177/1000] [Accuracy  : 0.734012]
# [Epoch 178/1000] [Train_Loss: 0.542099 /Valid_Loss: 0.595377]
# [Epoch 178/1000] [Accuracy  : 0.734137]
# [Epoch 179/1000] [Train_Loss: 0.545327 /Valid_Loss: 0.595447]
# [Epoch 179/1000] [Accuracy  : 0.735062]
# [Epoch 180/1000] [Train_Loss: 0.551559 /Valid_Loss: 0.593406]
# [Epoch 180/1000] [Accuracy  : 0.736225]
# [Epoch 181/1000] [Train_Loss: 0.563145 /Valid_Loss: 0.593111]
# [Epoch 181/1000] [Accuracy  : 0.736525]
# [Epoch 182/1000] [Train_Loss: 0.550671 /Valid_Loss: 0.594290]
# [Epoch 182/1000] [Accuracy  : 0.734125]
# [Epoch 183/1000] [Train_Loss: 0.552263 /Valid_Loss: 0.593427]
# [Epoch 183/1000] [Accuracy  : 0.736838]
# [Epoch 184/1000] [Train_Loss: 0.573661 /Valid_Loss: 0.593437]
# [Epoch 184/1000] [Accuracy  : 0.735788]
# [Epoch 185/1000] [Train_Loss: 0.543340 /Valid_Loss: 0.593472]
# [Epoch 185/1000] [Accuracy  : 0.735688]
# [Epoch 186/1000] [Train_Loss: 0.558109 /Valid_Loss: 0.596583]
# [Epoch 186/1000] [Accuracy  : 0.733513]
# [Epoch 187/1000] [Train_Loss: 0.557946 /Valid_Loss: 0.592857]
# [Epoch 187/1000] [Accuracy  : 0.736387]
# [Epoch 188/1000] [Train_Loss: 0.556144 /Valid_Loss: 0.592199]
# [Epoch 188/1000] [Accuracy  : 0.737912]
# [Epoch 189/1000] [Train_Loss: 0.568982 /Valid_Loss: 0.593984]
# [Epoch 189/1000] [Accuracy  : 0.735962]
# [Epoch 190/1000] [Train_Loss: 0.561853 /Valid_Loss: 0.591550]
# [Epoch 190/1000] [Accuracy  : 0.736375]
# [Epoch 191/1000] [Train_Loss: 0.531252 /Valid_Loss: 0.594123]
# [Epoch 191/1000] [Accuracy  : 0.735650]
# [Epoch 192/1000] [Train_Loss: 0.567870 /Valid_Loss: 0.590370]
# [Epoch 192/1000] [Accuracy  : 0.738125]
# [Epoch 193/1000] [Train_Loss: 0.563231 /Valid_Loss: 0.590799]
# [Epoch 193/1000] [Accuracy  : 0.737163]
# [Epoch 194/1000] [Train_Loss: 0.542095 /Valid_Loss: 0.593454]
# [Epoch 194/1000] [Accuracy  : 0.737175]
# [Epoch 195/1000] [Train_Loss: 0.545110 /Valid_Loss: 0.589680]
# [Epoch 195/1000] [Accuracy  : 0.739125]
# [Epoch 196/1000] [Train_Loss: 0.552320 /Valid_Loss: 0.592611]
# [Epoch 196/1000] [Accuracy  : 0.739675]
# [Epoch 197/1000] [Train_Loss: 0.572735 /Valid_Loss: 0.593004]
# [Epoch 197/1000] [Accuracy  : 0.736812]
# [Epoch 198/1000] [Train_Loss: 0.535148 /Valid_Loss: 0.588264]
# [Epoch 198/1000] [Accuracy  : 0.740613]
# [Epoch 199/1000] [Train_Loss: 0.558817 /Valid_Loss: 0.587250]
# [Epoch 199/1000] [Accuracy  : 0.740575]
# [Epoch 200/1000] [Train_Loss: 0.562814 /Valid_Loss: 0.588625]
# [Epoch 200/1000] [Accuracy  : 0.738625]
# [Epoch 201/1000] [Train_Loss: 0.542404 /Valid_Loss: 0.586998]
# [Epoch 201/1000] [Accuracy  : 0.741525]
# [Epoch 202/1000] [Train_Loss: 0.554774 /Valid_Loss: 0.596076]
# [Epoch 202/1000] [Accuracy  : 0.733600]
# [Epoch 203/1000] [Train_Loss: 0.545983 /Valid_Loss: 0.590653]
# [Epoch 203/1000] [Accuracy  : 0.738825]
# [Epoch 204/1000] [Train_Loss: 0.536916 /Valid_Loss: 0.587391]
# [Epoch 204/1000] [Accuracy  : 0.741575]
# [Epoch 205/1000] [Train_Loss: 0.565602 /Valid_Loss: 0.588594]
# [Epoch 205/1000] [Accuracy  : 0.740400]
# [Epoch 206/1000] [Train_Loss: 0.533850 /Valid_Loss: 0.590927]
# [Epoch 206/1000] [Accuracy  : 0.737912]
# [Epoch 207/1000] [Train_Loss: 0.547444 /Valid_Loss: 0.590350]
# [Epoch 207/1000] [Accuracy  : 0.738112]
# [Epoch 208/1000] [Train_Loss: 0.532352 /Valid_Loss: 0.588111]
# [Epoch 208/1000] [Accuracy  : 0.741075]
# [Epoch 209/1000] [Train_Loss: 0.554919 /Valid_Loss: 0.588845]
# [Epoch 209/1000] [Accuracy  : 0.739112]
# [Epoch 210/1000] [Train_Loss: 0.547328 /Valid_Loss: 0.588313]
# [Epoch 210/1000] [Accuracy  : 0.741200]
# [Epoch 211/1000] [Train_Loss: 0.527310 /Valid_Loss: 0.588998]
# [Epoch 211/1000] [Accuracy  : 0.740812]
# [Epoch 212/1000] [Train_Loss: 0.538417 /Valid_Loss: 0.589435]
# [Epoch 212/1000] [Accuracy  : 0.738613]
# [Epoch 213/1000] [Train_Loss: 0.537585 /Valid_Loss: 0.585898]
# [Epoch 213/1000] [Accuracy  : 0.742400]
# [Epoch 214/1000] [Train_Loss: 0.544873 /Valid_Loss: 0.587415]
# [Epoch 214/1000] [Accuracy  : 0.741550]
# [Epoch 215/1000] [Train_Loss: 0.550070 /Valid_Loss: 0.588605]
# [Epoch 215/1000] [Accuracy  : 0.741100]
# [Epoch 216/1000] [Train_Loss: 0.541926 /Valid_Loss: 0.586364]
# [Epoch 216/1000] [Accuracy  : 0.741888]
# [Epoch 217/1000] [Train_Loss: 0.555630 /Valid_Loss: 0.586251]
# [Epoch 217/1000] [Accuracy  : 0.742275]
# [Epoch 218/1000] [Train_Loss: 0.540609 /Valid_Loss: 0.587979]
# [Epoch 218/1000] [Accuracy  : 0.740775]
# [Epoch 219/1000] [Train_Loss: 0.548980 /Valid_Loss: 0.586718]
# [Epoch 219/1000] [Accuracy  : 0.741587]
# [Epoch 220/1000] [Train_Loss: 0.549133 /Valid_Loss: 0.587072]
# [Epoch 220/1000] [Accuracy  : 0.740750]
# [Epoch 221/1000] [Train_Loss: 0.559302 /Valid_Loss: 0.592600]
# [Epoch 221/1000] [Accuracy  : 0.737762]
# [Epoch 222/1000] [Train_Loss: 0.543269 /Valid_Loss: 0.589515]
# [Epoch 222/1000] [Accuracy  : 0.738175]
# [Epoch 223/1000] [Train_Loss: 0.546707 /Valid_Loss: 0.593696]
# [Epoch 223/1000] [Accuracy  : 0.737025]
# [Epoch 224/1000] [Train_Loss: 0.537086 /Valid_Loss: 0.585890]
# [Epoch 224/1000] [Accuracy  : 0.742600]
# [Epoch 225/1000] [Train_Loss: 0.537004 /Valid_Loss: 0.584180]
# [Epoch 225/1000] [Accuracy  : 0.743513]
# [Epoch 226/1000] [Train_Loss: 0.540161 /Valid_Loss: 0.591922]
# [Epoch 226/1000] [Accuracy  : 0.738637]
# [Epoch 227/1000] [Train_Loss: 0.547036 /Valid_Loss: 0.586828]
# [Epoch 227/1000] [Accuracy  : 0.741300]
# [Epoch 228/1000] [Train_Loss: 0.535122 /Valid_Loss: 0.587979]
# [Epoch 228/1000] [Accuracy  : 0.741100]
# [Epoch 229/1000] [Train_Loss: 0.534949 /Valid_Loss: 0.584550]
# [Epoch 229/1000] [Accuracy  : 0.743637]
# [Epoch 230/1000] [Train_Loss: 0.531285 /Valid_Loss: 0.587475]
# [Epoch 230/1000] [Accuracy  : 0.741550]
# [Epoch 231/1000] [Train_Loss: 0.553968 /Valid_Loss: 0.586711]
# [Epoch 231/1000] [Accuracy  : 0.742875]
# [Epoch 232/1000] [Train_Loss: 0.532120 /Valid_Loss: 0.590010]
# [Epoch 232/1000] [Accuracy  : 0.739400]
# [Epoch 233/1000] [Train_Loss: 0.530817 /Valid_Loss: 0.587315]
# [Epoch 233/1000] [Accuracy  : 0.739875]
# [Epoch 234/1000] [Train_Loss: 0.546712 /Valid_Loss: 0.585010]
# [Epoch 234/1000] [Accuracy  : 0.741200]
# [Epoch 235/1000] [Train_Loss: 0.543958 /Valid_Loss: 0.586842]
# [Epoch 235/1000] [Accuracy  : 0.741187]
# [Epoch 236/1000] [Train_Loss: 0.536141 /Valid_Loss: 0.588273]
# [Epoch 236/1000] [Accuracy  : 0.741012]
# [Epoch 237/1000] [Train_Loss: 0.535508 /Valid_Loss: 0.584279]
# [Epoch 237/1000] [Accuracy  : 0.742600]
# [Epoch 238/1000] [Train_Loss: 0.542865 /Valid_Loss: 0.590728]
# [Epoch 238/1000] [Accuracy  : 0.738962]
# [Epoch 239/1000] [Train_Loss: 0.552289 /Valid_Loss: 0.586548]
# [Epoch 239/1000] [Accuracy  : 0.741712]
# [Epoch 240/1000] [Train_Loss: 0.540920 /Valid_Loss: 0.584657]
# [Epoch 240/1000] [Accuracy  : 0.742413]
# [Epoch 241/1000] [Train_Loss: 0.531064 /Valid_Loss: 0.590669]
# [Epoch 241/1000] [Accuracy  : 0.739187]
# [Epoch 242/1000] [Train_Loss: 0.541006 /Valid_Loss: 0.585583]
# [Epoch 242/1000] [Accuracy  : 0.742675]
# [Epoch 243/1000] [Train_Loss: 0.547111 /Valid_Loss: 0.586565]
# [Epoch 243/1000] [Accuracy  : 0.742300]
# [Epoch 244/1000] [Train_Loss: 0.540400 /Valid_Loss: 0.590035]
# [Epoch 244/1000] [Accuracy  : 0.740637]
# [Epoch 245/1000] [Train_Loss: 0.541945 /Valid_Loss: 0.585341]
# [Epoch 245/1000] [Accuracy  : 0.742250]
# [Epoch 246/1000] [Train_Loss: 0.538152 /Valid_Loss: 0.584639]
# [Epoch 246/1000] [Accuracy  : 0.744138]
# [Epoch 247/1000] [Train_Loss: 0.540028 /Valid_Loss: 0.586488]
# [Epoch 247/1000] [Accuracy  : 0.742487]
# [Epoch 248/1000] [Train_Loss: 0.529834 /Valid_Loss: 0.585634]
# [Epoch 248/1000] [Accuracy  : 0.742738]
# [Epoch 249/1000] [Train_Loss: 0.547676 /Valid_Loss: 0.585329]
# [Epoch 249/1000] [Accuracy  : 0.742513]
# [Epoch 250/1000] [Train_Loss: 0.524720 /Valid_Loss: 0.586783]
# [Epoch 250/1000] [Accuracy  : 0.741950]
# [Epoch 251/1000] [Train_Loss: 0.540327 /Valid_Loss: 0.586744]
# [Epoch 251/1000] [Accuracy  : 0.741187]
# [Epoch 252/1000] [Train_Loss: 0.553421 /Valid_Loss: 0.586377]
# [Epoch 252/1000] [Accuracy  : 0.743162]
# [Epoch 253/1000] [Train_Loss: 0.521516 /Valid_Loss: 0.583718]
# [Epoch 253/1000] [Accuracy  : 0.743038]
# [Epoch 254/1000] [Train_Loss: 0.528748 /Valid_Loss: 0.588211]
# [Epoch 254/1000] [Accuracy  : 0.742700]
# [Epoch 255/1000] [Train_Loss: 0.549464 /Valid_Loss: 0.585835]
# [Epoch 255/1000] [Accuracy  : 0.741450]
# [Epoch 256/1000] [Train_Loss: 0.542558 /Valid_Loss: 0.585926]
# [Epoch 256/1000] [Accuracy  : 0.741525]
# [Epoch 257/1000] [Train_Loss: 0.513445 /Valid_Loss: 0.585318]
# [Epoch 257/1000] [Accuracy  : 0.742363]
# [Epoch 258/1000] [Train_Loss: 0.531467 /Valid_Loss: 0.584100]
# [Epoch 258/1000] [Accuracy  : 0.743125]
# [Epoch 259/1000] [Train_Loss: 0.536856 /Valid_Loss: 0.584404]
# [Epoch 259/1000] [Accuracy  : 0.743313]
# [Epoch 260/1000] [Train_Loss: 0.560149 /Valid_Loss: 0.586793]
# [Epoch 260/1000] [Accuracy  : 0.741175]
# [Epoch 261/1000] [Train_Loss: 0.532035 /Valid_Loss: 0.583038]
# [Epoch 261/1000] [Accuracy  : 0.744075]
# [Epoch 262/1000] [Train_Loss: 0.549963 /Valid_Loss: 0.588643]
# [Epoch 262/1000] [Accuracy  : 0.740025]
# [Epoch 263/1000] [Train_Loss: 0.524470 /Valid_Loss: 0.584431]
# [Epoch 263/1000] [Accuracy  : 0.742762]
# [Epoch 264/1000] [Train_Loss: 0.554794 /Valid_Loss: 0.583469]
# [Epoch 264/1000] [Accuracy  : 0.743938]
# [Epoch 265/1000] [Train_Loss: 0.527413 /Valid_Loss: 0.587738]
# [Epoch 265/1000] [Accuracy  : 0.740513]
# [Epoch 266/1000] [Train_Loss: 0.526292 /Valid_Loss: 0.582254]
# [Epoch 266/1000] [Accuracy  : 0.744062]
# [Epoch 267/1000] [Train_Loss: 0.534353 /Valid_Loss: 0.584432]
# [Epoch 267/1000] [Accuracy  : 0.742413]
# [Epoch 268/1000] [Train_Loss: 0.530141 /Valid_Loss: 0.585784]
# [Epoch 268/1000] [Accuracy  : 0.741900]
# [Epoch 269/1000] [Train_Loss: 0.526552 /Valid_Loss: 0.586676]
# [Epoch 269/1000] [Accuracy  : 0.742475]
# [Epoch 270/1000] [Train_Loss: 0.534879 /Valid_Loss: 0.587054]
# [Epoch 270/1000] [Accuracy  : 0.740788]
# [Epoch 271/1000] [Train_Loss: 0.533831 /Valid_Loss: 0.587446]
# [Epoch 271/1000] [Accuracy  : 0.741050]
# [Epoch 272/1000] [Train_Loss: 0.525658 /Valid_Loss: 0.584141]
# [Epoch 272/1000] [Accuracy  : 0.744600]
# [Epoch 273/1000] [Train_Loss: 0.543064 /Valid_Loss: 0.592414]
# [Epoch 273/1000] [Accuracy  : 0.740450]
# [Epoch 274/1000] [Train_Loss: 0.522142 /Valid_Loss: 0.583208]
# [Epoch 274/1000] [Accuracy  : 0.743463]
# [Epoch 275/1000] [Train_Loss: 0.521392 /Valid_Loss: 0.586539]
# [Epoch 275/1000] [Accuracy  : 0.743050]
# [Epoch 276/1000] [Train_Loss: 0.521528 /Valid_Loss: 0.583344]
# [Epoch 276/1000] [Accuracy  : 0.743587]
# [Epoch 277/1000] [Train_Loss: 0.510643 /Valid_Loss: 0.585939]
# [Epoch 277/1000] [Accuracy  : 0.744175]
# [Epoch 278/1000] [Train_Loss: 0.539815 /Valid_Loss: 0.584495]
# [Epoch 278/1000] [Accuracy  : 0.743450]
# [Epoch 279/1000] [Train_Loss: 0.530743 /Valid_Loss: 0.585498]
# [Epoch 279/1000] [Accuracy  : 0.742838]
# [Epoch 280/1000] [Train_Loss: 0.534998 /Valid_Loss: 0.583993]
# [Epoch 280/1000] [Accuracy  : 0.745387]
# [Epoch 281/1000] [Train_Loss: 0.526611 /Valid_Loss: 0.586477]
# [Epoch 281/1000] [Accuracy  : 0.741925]
# [Epoch 282/1000] [Train_Loss: 0.548443 /Valid_Loss: 0.584731]
# [Epoch 282/1000] [Accuracy  : 0.744550]
# [Epoch 283/1000] [Train_Loss: 0.525877 /Valid_Loss: 0.583899]
# [Epoch 283/1000] [Accuracy  : 0.744313]
# [Epoch 284/1000] [Train_Loss: 0.537484 /Valid_Loss: 0.586093]
# [Epoch 284/1000] [Accuracy  : 0.744062]
# [Epoch 285/1000] [Train_Loss: 0.537354 /Valid_Loss: 0.585555]
# [Epoch 285/1000] [Accuracy  : 0.743563]
# [Epoch 286/1000] [Train_Loss: 0.526986 /Valid_Loss: 0.584330]
# [Epoch 286/1000] [Accuracy  : 0.744025]
# [Epoch 287/1000] [Train_Loss: 0.540002 /Valid_Loss: 0.582406]
# [Epoch 287/1000] [Accuracy  : 0.745537]
# [Epoch 288/1000] [Train_Loss: 0.531136 /Valid_Loss: 0.585549]
# [Epoch 288/1000] [Accuracy  : 0.742250]
# [Epoch 289/1000] [Train_Loss: 0.516558 /Valid_Loss: 0.588412]
# [Epoch 289/1000] [Accuracy  : 0.741263]
# [Epoch 290/1000] [Train_Loss: 0.544887 /Valid_Loss: 0.583026]
# [Epoch 290/1000] [Accuracy  : 0.745600]
# [Epoch 291/1000] [Train_Loss: 0.544945 /Valid_Loss: 0.588179]
# [Epoch 291/1000] [Accuracy  : 0.740700]
# [Epoch 292/1000] [Train_Loss: 0.528325 /Valid_Loss: 0.585209]
# [Epoch 292/1000] [Accuracy  : 0.742012]
# [Epoch 293/1000] [Train_Loss: 0.527980 /Valid_Loss: 0.585488]
# [Epoch 293/1000] [Accuracy  : 0.744400]
# [Epoch 294/1000] [Train_Loss: 0.519332 /Valid_Loss: 0.582259]
# [Epoch 294/1000] [Accuracy  : 0.746375]
# [Epoch 295/1000] [Train_Loss: 0.514725 /Valid_Loss: 0.584581]
# [Epoch 295/1000] [Accuracy  : 0.742788]
# [Epoch 296/1000] [Train_Loss: 0.507994 /Valid_Loss: 0.584113]
# [Epoch 296/1000] [Accuracy  : 0.744175]
# [Epoch 297/1000] [Train_Loss: 0.548726 /Valid_Loss: 0.583012]
# [Epoch 297/1000] [Accuracy  : 0.744250]
# [Epoch 298/1000] [Train_Loss: 0.516831 /Valid_Loss: 0.584783]
# [Epoch 298/1000] [Accuracy  : 0.746062]
# [Epoch 299/1000] [Train_Loss: 0.530863 /Valid_Loss: 0.583001]
# [Epoch 299/1000] [Accuracy  : 0.745175]
# [Epoch 300/1000] [Train_Loss: 0.539074 /Valid_Loss: 0.583376]
# [Epoch 300/1000] [Accuracy  : 0.744012]
# [Epoch 301/1000] [Train_Loss: 0.526695 /Valid_Loss: 0.583969]
# [Epoch 301/1000] [Accuracy  : 0.745450]
# [Epoch 302/1000] [Train_Loss: 0.530709 /Valid_Loss: 0.588422]
# [Epoch 302/1000] [Accuracy  : 0.741088]
# [Epoch 303/1000] [Train_Loss: 0.532411 /Valid_Loss: 0.583241]
# [Epoch 303/1000] [Accuracy  : 0.744062]
# [Epoch 304/1000] [Train_Loss: 0.532572 /Valid_Loss: 0.588142]
# [Epoch 304/1000] [Accuracy  : 0.741125]
# [Epoch 305/1000] [Train_Loss: 0.543133 /Valid_Loss: 0.583745]
# [Epoch 305/1000] [Accuracy  : 0.743912]
# [Epoch 306/1000] [Train_Loss: 0.537490 /Valid_Loss: 0.583745]
# [Epoch 306/1000] [Accuracy  : 0.744625]
# [Epoch 307/1000] [Train_Loss: 0.529083 /Valid_Loss: 0.587519]
# [Epoch 307/1000] [Accuracy  : 0.742962]
# [Epoch 308/1000] [Train_Loss: 0.528027 /Valid_Loss: 0.587300]
# [Epoch 308/1000] [Accuracy  : 0.741100]
# [Epoch 309/1000] [Train_Loss: 0.518798 /Valid_Loss: 0.582947]
# [Epoch 309/1000] [Accuracy  : 0.745962]
# [Epoch 310/1000] [Train_Loss: 0.543106 /Valid_Loss: 0.585274]
# [Epoch 310/1000] [Accuracy  : 0.743762]
# [Epoch 311/1000] [Train_Loss: 0.526358 /Valid_Loss: 0.583082]
# [Epoch 311/1000] [Accuracy  : 0.744413]
# [Epoch 312/1000] [Train_Loss: 0.515022 /Valid_Loss: 0.584214]
# [Epoch 312/1000] [Accuracy  : 0.745475]
# [Epoch 313/1000] [Train_Loss: 0.525312 /Valid_Loss: 0.584221]
# [Epoch 313/1000] [Accuracy  : 0.743500]
# [Epoch 314/1000] [Train_Loss: 0.539226 /Valid_Loss: 0.583037]
# [Epoch 314/1000] [Accuracy  : 0.744762]
# [Epoch 315/1000] [Train_Loss: 0.538023 /Valid_Loss: 0.588543]
# [Epoch 315/1000] [Accuracy  : 0.741575]
# [Epoch 316/1000] [Train_Loss: 0.537254 /Valid_Loss: 0.585080]
# [Epoch 316/1000] [Accuracy  : 0.744625]
# [Epoch 317/1000] [Train_Loss: 0.524950 /Valid_Loss: 0.583738]
# [Epoch 317/1000] [Accuracy  : 0.744062]
# [Epoch 318/1000] [Train_Loss: 0.553740 /Valid_Loss: 0.581109]
# [Epoch 318/1000] [Accuracy  : 0.746900]
# [Epoch 319/1000] [Train_Loss: 0.534215 /Valid_Loss: 0.582520]
# [Epoch 319/1000] [Accuracy  : 0.746563]
# [Epoch 320/1000] [Train_Loss: 0.530203 /Valid_Loss: 0.584747]
# [Epoch 320/1000] [Accuracy  : 0.744263]
# [Epoch 321/1000] [Train_Loss: 0.515156 /Valid_Loss: 0.583688]
# [Epoch 321/1000] [Accuracy  : 0.744038]
# [Epoch 322/1000] [Train_Loss: 0.540837 /Valid_Loss: 0.587517]
# [Epoch 322/1000] [Accuracy  : 0.743463]
# [Epoch 323/1000] [Train_Loss: 0.516009 /Valid_Loss: 0.584089]
# [Epoch 323/1000] [Accuracy  : 0.744175]
# [Epoch 324/1000] [Train_Loss: 0.527281 /Valid_Loss: 0.588199]
# [Epoch 324/1000] [Accuracy  : 0.741112]
# [Epoch 325/1000] [Train_Loss: 0.527861 /Valid_Loss: 0.583322]
# [Epoch 325/1000] [Accuracy  : 0.744912]
# [Epoch 326/1000] [Train_Loss: 0.534271 /Valid_Loss: 0.584469]
# [Epoch 326/1000] [Accuracy  : 0.743875]
# [Epoch 327/1000] [Train_Loss: 0.516371 /Valid_Loss: 0.585695]
# [Epoch 327/1000] [Accuracy  : 0.742225]
# [Epoch 328/1000] [Train_Loss: 0.512302 /Valid_Loss: 0.584118]
# [Epoch 328/1000] [Accuracy  : 0.744725]
# [Epoch 329/1000] [Train_Loss: 0.529985 /Valid_Loss: 0.585062]
# [Epoch 329/1000] [Accuracy  : 0.744587]
# [Epoch 330/1000] [Train_Loss: 0.526700 /Valid_Loss: 0.585270]
# [Epoch 330/1000] [Accuracy  : 0.742788]
# [Epoch 331/1000] [Train_Loss: 0.518135 /Valid_Loss: 0.581750]
# [Epoch 331/1000] [Accuracy  : 0.746537]
# [Epoch 332/1000] [Train_Loss: 0.528448 /Valid_Loss: 0.583341]
# [Epoch 332/1000] [Accuracy  : 0.744938]
# [Epoch 333/1000] [Train_Loss: 0.517316 /Valid_Loss: 0.583799]
# [Epoch 333/1000] [Accuracy  : 0.745012]
# [Epoch 334/1000] [Train_Loss: 0.521650 /Valid_Loss: 0.586912]
# [Epoch 334/1000] [Accuracy  : 0.743775]
# [Epoch 335/1000] [Train_Loss: 0.526132 /Valid_Loss: 0.586576]
# [Epoch 335/1000] [Accuracy  : 0.743112]
# [Epoch 336/1000] [Train_Loss: 0.513482 /Valid_Loss: 0.583200]
# [Epoch 336/1000] [Accuracy  : 0.744513]
# [Epoch 337/1000] [Train_Loss: 0.531511 /Valid_Loss: 0.581723]
# [Epoch 337/1000] [Accuracy  : 0.745513]
# [Epoch 338/1000] [Train_Loss: 0.509678 /Valid_Loss: 0.587719]
# [Epoch 338/1000] [Accuracy  : 0.741788]
# [Epoch 339/1000] [Train_Loss: 0.525119 /Valid_Loss: 0.581410]
# [Epoch 339/1000] [Accuracy  : 0.745513]
# [Epoch 340/1000] [Train_Loss: 0.526965 /Valid_Loss: 0.582798]
# [Epoch 340/1000] [Accuracy  : 0.745350]
# [Epoch 341/1000] [Train_Loss: 0.527679 /Valid_Loss: 0.580644]
# [Epoch 341/1000] [Accuracy  : 0.746687]
# [Epoch 342/1000] [Train_Loss: 0.533422 /Valid_Loss: 0.587582]
# [Epoch 342/1000] [Accuracy  : 0.741675]
# [Epoch 343/1000] [Train_Loss: 0.523840 /Valid_Loss: 0.582051]
# [Epoch 343/1000] [Accuracy  : 0.745625]
# [Epoch 344/1000] [Train_Loss: 0.527249 /Valid_Loss: 0.584741]
# [Epoch 344/1000] [Accuracy  : 0.744850]
# [Epoch 345/1000] [Train_Loss: 0.515710 /Valid_Loss: 0.583406]
# [Epoch 345/1000] [Accuracy  : 0.746313]
# [Epoch 346/1000] [Train_Loss: 0.522025 /Valid_Loss: 0.587793]
# [Epoch 346/1000] [Accuracy  : 0.740725]
# [Epoch 347/1000] [Train_Loss: 0.526402 /Valid_Loss: 0.581290]
# [Epoch 347/1000] [Accuracy  : 0.747150]
# [Epoch 348/1000] [Train_Loss: 0.511959 /Valid_Loss: 0.583528]
# [Epoch 348/1000] [Accuracy  : 0.744762]
# [Epoch 349/1000] [Train_Loss: 0.535387 /Valid_Loss: 0.582533]
# [Epoch 349/1000] [Accuracy  : 0.745988]
# [Epoch 350/1000] [Train_Loss: 0.534312 /Valid_Loss: 0.584821]
# [Epoch 350/1000] [Accuracy  : 0.743812]
# [Epoch 351/1000] [Train_Loss: 0.516058 /Valid_Loss: 0.581601]
# [Epoch 351/1000] [Accuracy  : 0.745450]
# [Epoch 352/1000] [Train_Loss: 0.541273 /Valid_Loss: 0.583676]
# [Epoch 352/1000] [Accuracy  : 0.744188]
# [Epoch 353/1000] [Train_Loss: 0.520173 /Valid_Loss: 0.584856]
# [Epoch 353/1000] [Accuracy  : 0.744663]
# [Epoch 354/1000] [Train_Loss: 0.533530 /Valid_Loss: 0.584941]
# [Epoch 354/1000] [Accuracy  : 0.743075]
# [Epoch 355/1000] [Train_Loss: 0.523927 /Valid_Loss: 0.586136]
# [Epoch 355/1000] [Accuracy  : 0.744500]
# [Epoch 356/1000] [Train_Loss: 0.520853 /Valid_Loss: 0.583202]
# [Epoch 356/1000] [Accuracy  : 0.744925]
# [Epoch 357/1000] [Train_Loss: 0.526808 /Valid_Loss: 0.584549]
# [Epoch 357/1000] [Accuracy  : 0.744250]
# [Epoch 358/1000] [Train_Loss: 0.506994 /Valid_Loss: 0.585049]
# [Epoch 358/1000] [Accuracy  : 0.744100]
# [Epoch 359/1000] [Train_Loss: 0.527347 /Valid_Loss: 0.580342]
# [Epoch 359/1000] [Accuracy  : 0.746237]
# [Epoch 360/1000] [Train_Loss: 0.520164 /Valid_Loss: 0.584262]
# [Epoch 360/1000] [Accuracy  : 0.745637]
# [Epoch 361/1000] [Train_Loss: 0.510666 /Valid_Loss: 0.582569]
# [Epoch 361/1000] [Accuracy  : 0.746613]
# [Epoch 362/1000] [Train_Loss: 0.525700 /Valid_Loss: 0.581767]
# [Epoch 362/1000] [Accuracy  : 0.745762]
# [Epoch 363/1000] [Train_Loss: 0.530722 /Valid_Loss: 0.583597]
# [Epoch 363/1000] [Accuracy  : 0.744138]
# [Epoch 364/1000] [Train_Loss: 0.533701 /Valid_Loss: 0.587779]
# [Epoch 364/1000] [Accuracy  : 0.742337]
# [Epoch 365/1000] [Train_Loss: 0.515539 /Valid_Loss: 0.581985]
# [Epoch 365/1000] [Accuracy  : 0.745263]
# [Epoch 366/1000] [Train_Loss: 0.521662 /Valid_Loss: 0.582029]
# [Epoch 366/1000] [Accuracy  : 0.746400]
# [Epoch 367/1000] [Train_Loss: 0.536472 /Valid_Loss: 0.585811]
# [Epoch 367/1000] [Accuracy  : 0.742563]
# [Epoch 368/1000] [Train_Loss: 0.520118 /Valid_Loss: 0.584933]
# [Epoch 368/1000] [Accuracy  : 0.745275]
# [Epoch 369/1000] [Train_Loss: 0.541771 /Valid_Loss: 0.582213]
# [Epoch 369/1000] [Accuracy  : 0.746363]
# [Epoch 370/1000] [Train_Loss: 0.515922 /Valid_Loss: 0.581687]
# [Epoch 370/1000] [Accuracy  : 0.746587]
# [Epoch 371/1000] [Train_Loss: 0.512082 /Valid_Loss: 0.586336]
# [Epoch 371/1000] [Accuracy  : 0.743625]
# [Epoch 372/1000] [Train_Loss: 0.507101 /Valid_Loss: 0.580936]
# [Epoch 372/1000] [Accuracy  : 0.746463]
# [Epoch 373/1000] [Train_Loss: 0.547603 /Valid_Loss: 0.582073]
# [Epoch 373/1000] [Accuracy  : 0.747162]
# [Epoch 374/1000] [Train_Loss: 0.526546 /Valid_Loss: 0.585890]
# [Epoch 374/1000] [Accuracy  : 0.742775]
# [Epoch 375/1000] [Train_Loss: 0.523332 /Valid_Loss: 0.581368]
# [Epoch 375/1000] [Accuracy  : 0.746375]
# [Epoch 376/1000] [Train_Loss: 0.513462 /Valid_Loss: 0.579935]
# [Epoch 376/1000] [Accuracy  : 0.748150]
# [Epoch 377/1000] [Train_Loss: 0.509377 /Valid_Loss: 0.586842]
# [Epoch 377/1000] [Accuracy  : 0.743125]
# [Epoch 378/1000] [Train_Loss: 0.510807 /Valid_Loss: 0.584829]
# [Epoch 378/1000] [Accuracy  : 0.743287]
# [Epoch 379/1000] [Train_Loss: 0.526156 /Valid_Loss: 0.585827]
# [Epoch 379/1000] [Accuracy  : 0.743637]
# [Epoch 380/1000] [Train_Loss: 0.528950 /Valid_Loss: 0.581336]
# [Epoch 380/1000] [Accuracy  : 0.746263]
# [Epoch 381/1000] [Train_Loss: 0.519486 /Valid_Loss: 0.584816]
# [Epoch 381/1000] [Accuracy  : 0.744788]
# [Epoch 382/1000] [Train_Loss: 0.530250 /Valid_Loss: 0.581558]
# [Epoch 382/1000] [Accuracy  : 0.747450]
# [Epoch 383/1000] [Train_Loss: 0.542688 /Valid_Loss: 0.583121]
# [Epoch 383/1000] [Accuracy  : 0.746038]
# [Epoch 384/1000] [Train_Loss: 0.523832 /Valid_Loss: 0.583471]
# [Epoch 384/1000] [Accuracy  : 0.745300]
# [Epoch 385/1000] [Train_Loss: 0.529245 /Valid_Loss: 0.580254]
# [Epoch 385/1000] [Accuracy  : 0.746862]
# [Epoch 386/1000] [Train_Loss: 0.520369 /Valid_Loss: 0.579785]
# [Epoch 386/1000] [Accuracy  : 0.747012]
# [Epoch 387/1000] [Train_Loss: 0.538363 /Valid_Loss: 0.581058]
# [Epoch 387/1000] [Accuracy  : 0.747088]
# [Epoch 388/1000] [Train_Loss: 0.522642 /Valid_Loss: 0.580284]
# [Epoch 388/1000] [Accuracy  : 0.747463]
# [Epoch 389/1000] [Train_Loss: 0.504452 /Valid_Loss: 0.584552]
# [Epoch 389/1000] [Accuracy  : 0.745088]
# [Epoch 390/1000] [Train_Loss: 0.516629 /Valid_Loss: 0.582145]
# [Epoch 390/1000] [Accuracy  : 0.746713]
# [Epoch 391/1000] [Train_Loss: 0.527466 /Valid_Loss: 0.583638]
# [Epoch 391/1000] [Accuracy  : 0.746387]
# [Epoch 392/1000] [Train_Loss: 0.515434 /Valid_Loss: 0.582459]
# [Epoch 392/1000] [Accuracy  : 0.746600]
# [Epoch 393/1000] [Train_Loss: 0.525214 /Valid_Loss: 0.581292]
# [Epoch 393/1000] [Accuracy  : 0.745237]
# [Epoch 394/1000] [Train_Loss: 0.521877 /Valid_Loss: 0.582833]
# [Epoch 394/1000] [Accuracy  : 0.746962]
# [Epoch 395/1000] [Train_Loss: 0.507903 /Valid_Loss: 0.583075]
# [Epoch 395/1000] [Accuracy  : 0.745175]
# [Epoch 396/1000] [Train_Loss: 0.541220 /Valid_Loss: 0.582929]
# [Epoch 396/1000] [Accuracy  : 0.746600]
# [Epoch 397/1000] [Train_Loss: 0.530837 /Valid_Loss: 0.580329]
# [Epoch 397/1000] [Accuracy  : 0.747400]
# [Epoch 398/1000] [Train_Loss: 0.538224 /Valid_Loss: 0.588308]
# [Epoch 398/1000] [Accuracy  : 0.741363]
# [Epoch 399/1000] [Train_Loss: 0.538942 /Valid_Loss: 0.582590]
# [Epoch 399/1000] [Accuracy  : 0.745563]
# [Epoch 400/1000] [Train_Loss: 0.513362 /Valid_Loss: 0.586186]
# [Epoch 400/1000] [Accuracy  : 0.742637]
# [Epoch 401/1000] [Train_Loss: 0.517903 /Valid_Loss: 0.582178]
# [Epoch 401/1000] [Accuracy  : 0.745587]
# [Epoch 402/1000] [Train_Loss: 0.536957 /Valid_Loss: 0.581649]
# [Epoch 402/1000] [Accuracy  : 0.746475]
# [Epoch 403/1000] [Train_Loss: 0.556956 /Valid_Loss: 0.581957]
# [Epoch 403/1000] [Accuracy  : 0.745900]
# [Epoch 404/1000] [Train_Loss: 0.531792 /Valid_Loss: 0.580586]
# [Epoch 404/1000] [Accuracy  : 0.747000]
# [Epoch 405/1000] [Train_Loss: 0.529451 /Valid_Loss: 0.580443]
# [Epoch 405/1000] [Accuracy  : 0.746988]
# [Epoch 406/1000] [Train_Loss: 0.499825 /Valid_Loss: 0.583870]
# [Epoch 406/1000] [Accuracy  : 0.744587]
# [Epoch 407/1000] [Train_Loss: 0.524963 /Valid_Loss: 0.581710]
# [Epoch 407/1000] [Accuracy  : 0.745450]
# [Epoch 408/1000] [Train_Loss: 0.542491 /Valid_Loss: 0.581709]
# [Epoch 408/1000] [Accuracy  : 0.746938]
# [Epoch 409/1000] [Train_Loss: 0.512048 /Valid_Loss: 0.581932]
# [Epoch 409/1000] [Accuracy  : 0.746713]
# [Epoch 410/1000] [Train_Loss: 0.532867 /Valid_Loss: 0.582389]
# [Epoch 410/1000] [Accuracy  : 0.745275]
# [Epoch 411/1000] [Train_Loss: 0.533223 /Valid_Loss: 0.580747]
# [Epoch 411/1000] [Accuracy  : 0.747200]
# [Epoch 412/1000] [Train_Loss: 0.517856 /Valid_Loss: 0.580721]
# [Epoch 412/1000] [Accuracy  : 0.747112]
# [Epoch 413/1000] [Train_Loss: 0.506783 /Valid_Loss: 0.581975]
# [Epoch 413/1000] [Accuracy  : 0.745600]
# [Epoch 414/1000] [Train_Loss: 0.524820 /Valid_Loss: 0.581207]
# [Epoch 414/1000] [Accuracy  : 0.747350]
# [Epoch 415/1000] [Train_Loss: 0.524317 /Valid_Loss: 0.586959]
# [Epoch 415/1000] [Accuracy  : 0.742838]
# [Epoch 416/1000] [Train_Loss: 0.532977 /Valid_Loss: 0.586375]
# [Epoch 416/1000] [Accuracy  : 0.743687]
# [Epoch 417/1000] [Train_Loss: 0.517173 /Valid_Loss: 0.585064]
# [Epoch 417/1000] [Accuracy  : 0.744300]
# [Epoch 418/1000] [Train_Loss: 0.525499 /Valid_Loss: 0.580092]
# [Epoch 418/1000] [Accuracy  : 0.747600]
# [Epoch 419/1000] [Train_Loss: 0.531688 /Valid_Loss: 0.581921]
# [Epoch 419/1000] [Accuracy  : 0.746862]
# [Epoch 420/1000] [Train_Loss: 0.525642 /Valid_Loss: 0.584272]
# [Epoch 420/1000] [Accuracy  : 0.745500]
# [Epoch 421/1000] [Train_Loss: 0.518520 /Valid_Loss: 0.581089]
# [Epoch 421/1000] [Accuracy  : 0.746225]
# [Epoch 422/1000] [Train_Loss: 0.518644 /Valid_Loss: 0.582272]
# [Epoch 422/1000] [Accuracy  : 0.746375]
# [Epoch 423/1000] [Train_Loss: 0.530765 /Valid_Loss: 0.586305]
# [Epoch 423/1000] [Accuracy  : 0.742463]
# [Epoch 424/1000] [Train_Loss: 0.504307 /Valid_Loss: 0.583694]
# [Epoch 424/1000] [Accuracy  : 0.745088]
# [Epoch 425/1000] [Train_Loss: 0.511954 /Valid_Loss: 0.582207]
# [Epoch 425/1000] [Accuracy  : 0.745287]
# [Epoch 426/1000] [Train_Loss: 0.525891 /Valid_Loss: 0.581002]
# [Epoch 426/1000] [Accuracy  : 0.746637]
# [Epoch 427/1000] [Train_Loss: 0.514054 /Valid_Loss: 0.583159]
# [Epoch 427/1000] [Accuracy  : 0.745413]
# This is time to do early stopping
# 모델 저장: /content/gdrive/My Drive/Colab Notebooks/kamp/14. Dataset_Rotor/rnn_model.pt

# %% [markdown]
# #### (1) 모델 평가

# %%
PATH = dir+'rnn_'
test_model(RNN_model, PATH)
# Out:
# 0.7669875

# %% [markdown]
# #### (2) 혼동 행렬 (Confusion matrix)

# %%
draw_confusion_matrix(RNN_model, x_test, y_test, PATH)

# %% [markdown]
# #### (3) 손실(Loss) 그래프

# %%
plot_loss_graph(RNN_loss_values, RNN_loss_values_v)

# %% [markdown]
# ### 4-1. 심층신경망 (DNN) 모델 학습

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

DNN_model = KAMP_DNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(DNN_model.parameters())
PATH = dir+'dnn_'

DNN_loss_values, DNN_loss_values_v = train_model(DNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)
# Out:
# [Epoch 1/1000] [Train_Loss: 1.191477 /Valid_Loss: 1.145718]
# [Epoch 1/1000] [Accuracy  : 0.434075]
# [Epoch 2/1000] [Train_Loss: 0.945126 /Valid_Loss: 0.899004]
# [Epoch 2/1000] [Accuracy  : 0.489912]
# [Epoch 3/1000] [Train_Loss: 0.889309 /Valid_Loss: 0.850821]
# [Epoch 3/1000] [Accuracy  : 0.493900]
# [Epoch 4/1000] [Train_Loss: 0.869215 /Valid_Loss: 0.840918]
# [Epoch 4/1000] [Accuracy  : 0.510062]
# [Epoch 5/1000] [Train_Loss: 0.861877 /Valid_Loss: 0.830266]
# [Epoch 5/1000] [Accuracy  : 0.518288]
# [Epoch 6/1000] [Train_Loss: 0.838445 /Valid_Loss: 0.826400]
# [Epoch 6/1000] [Accuracy  : 0.521487]
# [Epoch 7/1000] [Train_Loss: 0.842657 /Valid_Loss: 0.813215]
# [Epoch 7/1000] [Accuracy  : 0.534350]
# [Epoch 8/1000] [Train_Loss: 0.826020 /Valid_Loss: 0.800785]
# [Epoch 8/1000] [Accuracy  : 0.548963]
# [Epoch 9/1000] [Train_Loss: 0.812838 /Valid_Loss: 0.778214]
# [Epoch 9/1000] [Accuracy  : 0.587250]
# [Epoch 10/1000] [Train_Loss: 0.775512 /Valid_Loss: 0.753990]
# [Epoch 10/1000] [Accuracy  : 0.613675]
# [Epoch 11/1000] [Train_Loss: 0.754323 /Valid_Loss: 0.726191]
# [Epoch 11/1000] [Accuracy  : 0.641162]
# [Epoch 12/1000] [Train_Loss: 0.741508 /Valid_Loss: 0.707221]
# [Epoch 12/1000] [Accuracy  : 0.653238]
# [Epoch 13/1000] [Train_Loss: 0.719569 /Valid_Loss: 0.697536]
# [Epoch 13/1000] [Accuracy  : 0.660775]
# [Epoch 14/1000] [Train_Loss: 0.723404 /Valid_Loss: 0.691307]
# [Epoch 14/1000] [Accuracy  : 0.663500]
# [Epoch 15/1000] [Train_Loss: 0.710732 /Valid_Loss: 0.679054]
# [Epoch 15/1000] [Accuracy  : 0.668500]
# [Epoch 16/1000] [Train_Loss: 0.691991 /Valid_Loss: 0.671455]
# [Epoch 16/1000] [Accuracy  : 0.675175]
# [Epoch 17/1000] [Train_Loss: 0.668922 /Valid_Loss: 0.668827]
# [Epoch 17/1000] [Accuracy  : 0.675288]
# [Epoch 18/1000] [Train_Loss: 0.677465 /Valid_Loss: 0.661683]
# [Epoch 18/1000] [Accuracy  : 0.680187]
# [Epoch 19/1000] [Train_Loss: 0.684159 /Valid_Loss: 0.657863]
# [Epoch 19/1000] [Accuracy  : 0.684875]
# [Epoch 20/1000] [Train_Loss: 0.667350 /Valid_Loss: 0.653789]
# [Epoch 20/1000] [Accuracy  : 0.685275]
# [Epoch 21/1000] [Train_Loss: 0.660991 /Valid_Loss: 0.652441]
# [Epoch 21/1000] [Accuracy  : 0.687937]
# [Epoch 22/1000] [Train_Loss: 0.646980 /Valid_Loss: 0.648497]
# [Epoch 22/1000] [Accuracy  : 0.696450]
# [Epoch 23/1000] [Train_Loss: 0.638674 /Valid_Loss: 0.645341]
# [Epoch 23/1000] [Accuracy  : 0.699625]
# [Epoch 24/1000] [Train_Loss: 0.643079 /Valid_Loss: 0.644439]
# [Epoch 24/1000] [Accuracy  : 0.700125]
# [Epoch 25/1000] [Train_Loss: 0.640775 /Valid_Loss: 0.640988]
# [Epoch 25/1000] [Accuracy  : 0.706575]
# [Epoch 26/1000] [Train_Loss: 0.631381 /Valid_Loss: 0.638057]
# [Epoch 26/1000] [Accuracy  : 0.707488]
# [Epoch 27/1000] [Train_Loss: 0.628585 /Valid_Loss: 0.638434]
# [Epoch 27/1000] [Accuracy  : 0.704862]
# [Epoch 28/1000] [Train_Loss: 0.627901 /Valid_Loss: 0.631600]
# [Epoch 28/1000] [Accuracy  : 0.711150]
# [Epoch 29/1000] [Train_Loss: 0.633308 /Valid_Loss: 0.631086]
# [Epoch 29/1000] [Accuracy  : 0.711287]
# [Epoch 30/1000] [Train_Loss: 0.619072 /Valid_Loss: 0.625033]
# [Epoch 30/1000] [Accuracy  : 0.715750]
# [Epoch 31/1000] [Train_Loss: 0.641246 /Valid_Loss: 0.628592]
# [Epoch 31/1000] [Accuracy  : 0.712650]
# [Epoch 32/1000] [Train_Loss: 0.623281 /Valid_Loss: 0.625234]
# [Epoch 32/1000] [Accuracy  : 0.712512]
# [Epoch 33/1000] [Train_Loss: 0.614090 /Valid_Loss: 0.619896]
# [Epoch 33/1000] [Accuracy  : 0.717487]
# [Epoch 34/1000] [Train_Loss: 0.606469 /Valid_Loss: 0.621591]
# [Epoch 34/1000] [Accuracy  : 0.715812]
# [Epoch 35/1000] [Train_Loss: 0.616159 /Valid_Loss: 0.619081]
# [Epoch 35/1000] [Accuracy  : 0.717025]
# [Epoch 36/1000] [Train_Loss: 0.613843 /Valid_Loss: 0.619689]
# [Epoch 36/1000] [Accuracy  : 0.715762]
# [Epoch 37/1000] [Train_Loss: 0.607394 /Valid_Loss: 0.617304]
# [Epoch 37/1000] [Accuracy  : 0.718487]
# [Epoch 38/1000] [Train_Loss: 0.617877 /Valid_Loss: 0.621134]
# [Epoch 38/1000] [Accuracy  : 0.714175]
# [Epoch 39/1000] [Train_Loss: 0.599264 /Valid_Loss: 0.618908]
# [Epoch 39/1000] [Accuracy  : 0.717562]
# [Epoch 40/1000] [Train_Loss: 0.604345 /Valid_Loss: 0.617848]
# [Epoch 40/1000] [Accuracy  : 0.713638]
# [Epoch 41/1000] [Train_Loss: 0.588195 /Valid_Loss: 0.617194]
# [Epoch 41/1000] [Accuracy  : 0.718313]
# [Epoch 42/1000] [Train_Loss: 0.595413 /Valid_Loss: 0.612555]
# [Epoch 42/1000] [Accuracy  : 0.719237]
# [Epoch 43/1000] [Train_Loss: 0.598706 /Valid_Loss: 0.612158]
# [Epoch 43/1000] [Accuracy  : 0.720063]
# [Epoch 44/1000] [Train_Loss: 0.598480 /Valid_Loss: 0.611374]
# [Epoch 44/1000] [Accuracy  : 0.720850]
# [Epoch 45/1000] [Train_Loss: 0.580985 /Valid_Loss: 0.612155]
# [Epoch 45/1000] [Accuracy  : 0.721337]
# [Epoch 46/1000] [Train_Loss: 0.590169 /Valid_Loss: 0.610767]
# [Epoch 46/1000] [Accuracy  : 0.720838]
# [Epoch 47/1000] [Train_Loss: 0.589884 /Valid_Loss: 0.605495]
# [Epoch 47/1000] [Accuracy  : 0.723525]
# [Epoch 48/1000] [Train_Loss: 0.583384 /Valid_Loss: 0.610539]
# [Epoch 48/1000] [Accuracy  : 0.720700]
# [Epoch 49/1000] [Train_Loss: 0.599789 /Valid_Loss: 0.610954]
# [Epoch 49/1000] [Accuracy  : 0.720337]
# [Epoch 50/1000] [Train_Loss: 0.584413 /Valid_Loss: 0.605029]
# [Epoch 50/1000] [Accuracy  : 0.725788]
# [Epoch 51/1000] [Train_Loss: 0.581803 /Valid_Loss: 0.606781]
# [Epoch 51/1000] [Accuracy  : 0.726625]
# [Epoch 52/1000] [Train_Loss: 0.578802 /Valid_Loss: 0.614175]
# [Epoch 52/1000] [Accuracy  : 0.718988]
# [Epoch 53/1000] [Train_Loss: 0.588140 /Valid_Loss: 0.608772]
# [Epoch 53/1000] [Accuracy  : 0.722200]
# [Epoch 54/1000] [Train_Loss: 0.579849 /Valid_Loss: 0.607290]
# [Epoch 54/1000] [Accuracy  : 0.727475]
# [Epoch 55/1000] [Train_Loss: 0.592256 /Valid_Loss: 0.603832]
# [Epoch 55/1000] [Accuracy  : 0.727738]
# [Epoch 56/1000] [Train_Loss: 0.575254 /Valid_Loss: 0.604933]
# [Epoch 56/1000] [Accuracy  : 0.726588]
# [Epoch 57/1000] [Train_Loss: 0.579091 /Valid_Loss: 0.603608]
# [Epoch 57/1000] [Accuracy  : 0.729275]
# [Epoch 58/1000] [Train_Loss: 0.578443 /Valid_Loss: 0.602736]
# [Epoch 58/1000] [Accuracy  : 0.730625]
# [Epoch 59/1000] [Train_Loss: 0.587908 /Valid_Loss: 0.607701]
# [Epoch 59/1000] [Accuracy  : 0.724175]
# [Epoch 60/1000] [Train_Loss: 0.579302 /Valid_Loss: 0.600211]
# [Epoch 60/1000] [Accuracy  : 0.733550]
# [Epoch 61/1000] [Train_Loss: 0.606975 /Valid_Loss: 0.599402]
# [Epoch 61/1000] [Accuracy  : 0.733725]
# [Epoch 62/1000] [Train_Loss: 0.572851 /Valid_Loss: 0.604133]
# [Epoch 62/1000] [Accuracy  : 0.730888]
# [Epoch 63/1000] [Train_Loss: 0.574567 /Valid_Loss: 0.599709]
# [Epoch 63/1000] [Accuracy  : 0.732950]
# [Epoch 64/1000] [Train_Loss: 0.578944 /Valid_Loss: 0.603486]
# [Epoch 64/1000] [Accuracy  : 0.729363]
# [Epoch 65/1000] [Train_Loss: 0.569832 /Valid_Loss: 0.602332]
# [Epoch 65/1000] [Accuracy  : 0.730463]
# [Epoch 66/1000] [Train_Loss: 0.572486 /Valid_Loss: 0.611711]
# [Epoch 66/1000] [Accuracy  : 0.721487]
# [Epoch 67/1000] [Train_Loss: 0.567593 /Valid_Loss: 0.611104]
# [Epoch 67/1000] [Accuracy  : 0.721588]
# [Epoch 68/1000] [Train_Loss: 0.590766 /Valid_Loss: 0.599046]
# [Epoch 68/1000] [Accuracy  : 0.731825]
# [Epoch 69/1000] [Train_Loss: 0.556536 /Valid_Loss: 0.598185]
# [Epoch 69/1000] [Accuracy  : 0.730850]
# [Epoch 70/1000] [Train_Loss: 0.572551 /Valid_Loss: 0.602932]
# [Epoch 70/1000] [Accuracy  : 0.729213]
# [Epoch 71/1000] [Train_Loss: 0.564889 /Valid_Loss: 0.606773]
# [Epoch 71/1000] [Accuracy  : 0.726450]
# [Epoch 72/1000] [Train_Loss: 0.558820 /Valid_Loss: 0.597840]
# [Epoch 72/1000] [Accuracy  : 0.730363]
# [Epoch 73/1000] [Train_Loss: 0.576584 /Valid_Loss: 0.598257]
# [Epoch 73/1000] [Accuracy  : 0.729788]
# [Epoch 74/1000] [Train_Loss: 0.568727 /Valid_Loss: 0.601302]
# [Epoch 74/1000] [Accuracy  : 0.732788]
# [Epoch 75/1000] [Train_Loss: 0.576323 /Valid_Loss: 0.597504]
# [Epoch 75/1000] [Accuracy  : 0.734112]
# [Epoch 76/1000] [Train_Loss: 0.562208 /Valid_Loss: 0.600144]
# [Epoch 76/1000] [Accuracy  : 0.730738]
# [Epoch 77/1000] [Train_Loss: 0.567127 /Valid_Loss: 0.592441]
# [Epoch 77/1000] [Accuracy  : 0.732862]
# [Epoch 78/1000] [Train_Loss: 0.576868 /Valid_Loss: 0.592369]
# [Epoch 78/1000] [Accuracy  : 0.736988]
# [Epoch 79/1000] [Train_Loss: 0.564061 /Valid_Loss: 0.598930]
# [Epoch 79/1000] [Accuracy  : 0.731337]
# [Epoch 80/1000] [Train_Loss: 0.567820 /Valid_Loss: 0.596422]
# [Epoch 80/1000] [Accuracy  : 0.729575]
# [Epoch 81/1000] [Train_Loss: 0.556584 /Valid_Loss: 0.596125]
# [Epoch 81/1000] [Accuracy  : 0.734150]
# [Epoch 82/1000] [Train_Loss: 0.572174 /Valid_Loss: 0.603277]
# [Epoch 82/1000] [Accuracy  : 0.731062]
# [Epoch 83/1000] [Train_Loss: 0.547034 /Valid_Loss: 0.594937]
# [Epoch 83/1000] [Accuracy  : 0.732925]
# [Epoch 84/1000] [Train_Loss: 0.572240 /Valid_Loss: 0.604462]
# [Epoch 84/1000] [Accuracy  : 0.728275]
# [Epoch 85/1000] [Train_Loss: 0.560869 /Valid_Loss: 0.595891]
# [Epoch 85/1000] [Accuracy  : 0.734000]
# [Epoch 86/1000] [Train_Loss: 0.575822 /Valid_Loss: 0.597641]
# [Epoch 86/1000] [Accuracy  : 0.731825]
# [Epoch 87/1000] [Train_Loss: 0.571480 /Valid_Loss: 0.594842]
# [Epoch 87/1000] [Accuracy  : 0.736138]
# [Epoch 88/1000] [Train_Loss: 0.556397 /Valid_Loss: 0.588123]
# [Epoch 88/1000] [Accuracy  : 0.738975]
# [Epoch 89/1000] [Train_Loss: 0.567152 /Valid_Loss: 0.594917]
# [Epoch 89/1000] [Accuracy  : 0.735738]
# [Epoch 90/1000] [Train_Loss: 0.550893 /Valid_Loss: 0.596643]
# [Epoch 90/1000] [Accuracy  : 0.733900]
# [Epoch 91/1000] [Train_Loss: 0.563624 /Valid_Loss: 0.601121]
# [Epoch 91/1000] [Accuracy  : 0.727912]
# [Epoch 92/1000] [Train_Loss: 0.550174 /Valid_Loss: 0.596035]
# [Epoch 92/1000] [Accuracy  : 0.734838]
# [Epoch 93/1000] [Train_Loss: 0.555735 /Valid_Loss: 0.595922]
# [Epoch 93/1000] [Accuracy  : 0.734475]
# [Epoch 94/1000] [Train_Loss: 0.558895 /Valid_Loss: 0.599563]
# [Epoch 94/1000] [Accuracy  : 0.730988]
# [Epoch 95/1000] [Train_Loss: 0.569310 /Valid_Loss: 0.592147]
# [Epoch 95/1000] [Accuracy  : 0.735475]
# [Epoch 96/1000] [Train_Loss: 0.567669 /Valid_Loss: 0.588299]
# [Epoch 96/1000] [Accuracy  : 0.741275]
# [Epoch 97/1000] [Train_Loss: 0.563756 /Valid_Loss: 0.595694]
# [Epoch 97/1000] [Accuracy  : 0.730912]
# [Epoch 98/1000] [Train_Loss: 0.548450 /Valid_Loss: 0.592729]
# [Epoch 98/1000] [Accuracy  : 0.734800]
# [Epoch 99/1000] [Train_Loss: 0.549715 /Valid_Loss: 0.593676]
# [Epoch 99/1000] [Accuracy  : 0.735800]
# [Epoch 100/1000] [Train_Loss: 0.554084 /Valid_Loss: 0.594599]
# [Epoch 100/1000] [Accuracy  : 0.734225]
# [Epoch 101/1000] [Train_Loss: 0.562596 /Valid_Loss: 0.589070]
# [Epoch 101/1000] [Accuracy  : 0.739475]
# [Epoch 102/1000] [Train_Loss: 0.548664 /Valid_Loss: 0.603571]
# [Epoch 102/1000] [Accuracy  : 0.728062]
# [Epoch 103/1000] [Train_Loss: 0.554120 /Valid_Loss: 0.595324]
# [Epoch 103/1000] [Accuracy  : 0.735012]
# [Epoch 104/1000] [Train_Loss: 0.554991 /Valid_Loss: 0.595969]
# [Epoch 104/1000] [Accuracy  : 0.734075]
# [Epoch 105/1000] [Train_Loss: 0.542256 /Valid_Loss: 0.592726]
# [Epoch 105/1000] [Accuracy  : 0.736163]
# [Epoch 106/1000] [Train_Loss: 0.567090 /Valid_Loss: 0.598308]
# [Epoch 106/1000] [Accuracy  : 0.732088]
# [Epoch 107/1000] [Train_Loss: 0.561681 /Valid_Loss: 0.598091]
# [Epoch 107/1000] [Accuracy  : 0.734962]
# [Epoch 108/1000] [Train_Loss: 0.568689 /Valid_Loss: 0.595031]
# [Epoch 108/1000] [Accuracy  : 0.734725]
# [Epoch 109/1000] [Train_Loss: 0.575191 /Valid_Loss: 0.591404]
# [Epoch 109/1000] [Accuracy  : 0.735712]
# [Epoch 110/1000] [Train_Loss: 0.551699 /Valid_Loss: 0.592728]
# [Epoch 110/1000] [Accuracy  : 0.735112]
# [Epoch 111/1000] [Train_Loss: 0.564134 /Valid_Loss: 0.592423]
# [Epoch 111/1000] [Accuracy  : 0.735425]
# [Epoch 112/1000] [Train_Loss: 0.559655 /Valid_Loss: 0.595947]
# [Epoch 112/1000] [Accuracy  : 0.731975]
# [Epoch 113/1000] [Train_Loss: 0.585667 /Valid_Loss: 0.592463]
# [Epoch 113/1000] [Accuracy  : 0.737525]
# [Epoch 114/1000] [Train_Loss: 0.542100 /Valid_Loss: 0.589369]
# [Epoch 114/1000] [Accuracy  : 0.739088]
# [Epoch 115/1000] [Train_Loss: 0.546373 /Valid_Loss: 0.591241]
# [Epoch 115/1000] [Accuracy  : 0.737988]
# [Epoch 116/1000] [Train_Loss: 0.553919 /Valid_Loss: 0.596511]
# [Epoch 116/1000] [Accuracy  : 0.733938]
# [Epoch 117/1000] [Train_Loss: 0.539429 /Valid_Loss: 0.597243]
# [Epoch 117/1000] [Accuracy  : 0.731838]
# [Epoch 118/1000] [Train_Loss: 0.559837 /Valid_Loss: 0.594541]
# [Epoch 118/1000] [Accuracy  : 0.735375]
# [Epoch 119/1000] [Train_Loss: 0.563623 /Valid_Loss: 0.591243]
# [Epoch 119/1000] [Accuracy  : 0.736038]
# [Epoch 120/1000] [Train_Loss: 0.557492 /Valid_Loss: 0.591646]
# [Epoch 120/1000] [Accuracy  : 0.737125]
# [Epoch 121/1000] [Train_Loss: 0.551075 /Valid_Loss: 0.592662]
# [Epoch 121/1000] [Accuracy  : 0.735500]
# [Epoch 122/1000] [Train_Loss: 0.552566 /Valid_Loss: 0.591994]
# [Epoch 122/1000] [Accuracy  : 0.734675]
# [Epoch 123/1000] [Train_Loss: 0.555595 /Valid_Loss: 0.592638]
# [Epoch 123/1000] [Accuracy  : 0.735875]
# [Epoch 124/1000] [Train_Loss: 0.536491 /Valid_Loss: 0.593038]
# [Epoch 124/1000] [Accuracy  : 0.735363]
# [Epoch 125/1000] [Train_Loss: 0.544551 /Valid_Loss: 0.592919]
# [Epoch 125/1000] [Accuracy  : 0.735675]
# [Epoch 126/1000] [Train_Loss: 0.542195 /Valid_Loss: 0.600472]
# [Epoch 126/1000] [Accuracy  : 0.729788]
# [Epoch 127/1000] [Train_Loss: 0.529608 /Valid_Loss: 0.592468]
# [Epoch 127/1000] [Accuracy  : 0.738363]
# [Epoch 128/1000] [Train_Loss: 0.557308 /Valid_Loss: 0.593619]
# [Epoch 128/1000] [Accuracy  : 0.732475]
# [Epoch 129/1000] [Train_Loss: 0.529034 /Valid_Loss: 0.598431]
# [Epoch 129/1000] [Accuracy  : 0.732762]
# [Epoch 130/1000] [Train_Loss: 0.544939 /Valid_Loss: 0.588897]
# [Epoch 130/1000] [Accuracy  : 0.736850]
# [Epoch 131/1000] [Train_Loss: 0.543935 /Valid_Loss: 0.595288]
# [Epoch 131/1000] [Accuracy  : 0.734387]
# [Epoch 132/1000] [Train_Loss: 0.538376 /Valid_Loss: 0.599891]
# [Epoch 132/1000] [Accuracy  : 0.730550]
# [Epoch 133/1000] [Train_Loss: 0.553586 /Valid_Loss: 0.594970]
# [Epoch 133/1000] [Accuracy  : 0.733700]
# [Epoch 134/1000] [Train_Loss: 0.543733 /Valid_Loss: 0.597460]
# [Epoch 134/1000] [Accuracy  : 0.731463]
# [Epoch 135/1000] [Train_Loss: 0.552901 /Valid_Loss: 0.599677]
# [Epoch 135/1000] [Accuracy  : 0.728387]
# [Epoch 136/1000] [Train_Loss: 0.559004 /Valid_Loss: 0.595965]
# [Epoch 136/1000] [Accuracy  : 0.732350]
# [Epoch 137/1000] [Train_Loss: 0.532015 /Valid_Loss: 0.599137]
# [Epoch 137/1000] [Accuracy  : 0.731850]
# [Epoch 138/1000] [Train_Loss: 0.561424 /Valid_Loss: 0.589300]
# [Epoch 138/1000] [Accuracy  : 0.738613]
# [Epoch 139/1000] [Train_Loss: 0.547967 /Valid_Loss: 0.593265]
# [Epoch 139/1000] [Accuracy  : 0.735537]
# [Epoch 140/1000] [Train_Loss: 0.557905 /Valid_Loss: 0.591666]
# [Epoch 140/1000] [Accuracy  : 0.735537]
# [Epoch 141/1000] [Train_Loss: 0.548080 /Valid_Loss: 0.596910]
# [Epoch 141/1000] [Accuracy  : 0.732450]
# [Epoch 142/1000] [Train_Loss: 0.541213 /Valid_Loss: 0.597002]
# [Epoch 142/1000] [Accuracy  : 0.733187]
# [Epoch 143/1000] [Train_Loss: 0.545924 /Valid_Loss: 0.597104]
# [Epoch 143/1000] [Accuracy  : 0.733400]
# [Epoch 144/1000] [Train_Loss: 0.544677 /Valid_Loss: 0.594314]
# [Epoch 144/1000] [Accuracy  : 0.736088]
# [Epoch 145/1000] [Train_Loss: 0.539675 /Valid_Loss: 0.588991]
# [Epoch 145/1000] [Accuracy  : 0.738225]
# [Epoch 146/1000] [Train_Loss: 0.548899 /Valid_Loss: 0.597820]
# [Epoch 146/1000] [Accuracy  : 0.730838]
# [Epoch 147/1000] [Train_Loss: 0.551035 /Valid_Loss: 0.599956]
# [Epoch 147/1000] [Accuracy  : 0.731413]
# This is time to do early stopping
# 모델 저장: /content/gdrive/My Drive/Colab Notebooks/kamp/14. Dataset_Rotor/dnn_model.pt

# %% [markdown]
# ### 4-2. 합성곱신경망 (CNN) 모델 학습

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

CNN_model = KAMP_CNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(CNN_model.parameters())
PATH = dir+'cnn_'

CNN_loss_values, CNN_loss_values_v = train_model(CNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py:303: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ../aten/src/ATen/native/Convolution.cpp:882.)
#   return F.conv1d(input, weight, bias, self.stride,
# [Epoch 1/1000] [Train_Loss: 1.297222 /Valid_Loss: 1.363497]
# [Epoch 1/1000] [Accuracy  : 0.249963]
# [Epoch 2/1000] [Train_Loss: 1.234386 /Valid_Loss: 1.222897]
# [Epoch 2/1000] [Accuracy  : 0.438987]
# [Epoch 3/1000] [Train_Loss: 1.166199 /Valid_Loss: 1.157878]
# [Epoch 3/1000] [Accuracy  : 0.492525]
# [Epoch 4/1000] [Train_Loss: 1.113933 /Valid_Loss: 1.104968]
# [Epoch 4/1000] [Accuracy  : 0.484613]
# [Epoch 5/1000] [Train_Loss: 1.065624 /Valid_Loss: 1.052055]
# [Epoch 5/1000] [Accuracy  : 0.553825]
# [Epoch 6/1000] [Train_Loss: 1.019922 /Valid_Loss: 1.011376]
# [Epoch 6/1000] [Accuracy  : 0.555850]
# [Epoch 7/1000] [Train_Loss: 0.984519 /Valid_Loss: 0.968190]
# [Epoch 7/1000] [Accuracy  : 0.612100]
# [Epoch 8/1000] [Train_Loss: 0.946996 /Valid_Loss: 0.939522]
# [Epoch 8/1000] [Accuracy  : 0.637650]
# [Epoch 9/1000] [Train_Loss: 0.923010 /Valid_Loss: 0.906228]
# [Epoch 9/1000] [Accuracy  : 0.631938]
# [Epoch 10/1000] [Train_Loss: 0.901956 /Valid_Loss: 0.889841]
# [Epoch 10/1000] [Accuracy  : 0.629000]
# [Epoch 11/1000] [Train_Loss: 0.871019 /Valid_Loss: 0.865377]
# [Epoch 11/1000] [Accuracy  : 0.639362]
# [Epoch 12/1000] [Train_Loss: 0.858181 /Valid_Loss: 0.849070]
# [Epoch 12/1000] [Accuracy  : 0.647275]
# [Epoch 13/1000] [Train_Loss: 0.832232 /Valid_Loss: 0.830333]
# [Epoch 13/1000] [Accuracy  : 0.635450]
# [Epoch 14/1000] [Train_Loss: 0.822464 /Valid_Loss: 0.811000]
# [Epoch 14/1000] [Accuracy  : 0.650075]
# [Epoch 15/1000] [Train_Loss: 0.816798 /Valid_Loss: 0.795740]
# [Epoch 15/1000] [Accuracy  : 0.660500]
# [Epoch 16/1000] [Train_Loss: 0.807814 /Valid_Loss: 0.785082]
# [Epoch 16/1000] [Accuracy  : 0.654250]
# [Epoch 17/1000] [Train_Loss: 0.807512 /Valid_Loss: 0.774473]
# [Epoch 17/1000] [Accuracy  : 0.650825]
# [Epoch 18/1000] [Train_Loss: 0.782647 /Valid_Loss: 0.764813]
# [Epoch 18/1000] [Accuracy  : 0.652900]
# [Epoch 19/1000] [Train_Loss: 0.771836 /Valid_Loss: 0.757230]
# [Epoch 19/1000] [Accuracy  : 0.660737]
# [Epoch 20/1000] [Train_Loss: 0.768196 /Valid_Loss: 0.752656]
# [Epoch 20/1000] [Accuracy  : 0.667763]
# [Epoch 21/1000] [Train_Loss: 0.763381 /Valid_Loss: 0.741802]
# [Epoch 21/1000] [Accuracy  : 0.659238]
# [Epoch 22/1000] [Train_Loss: 0.748994 /Valid_Loss: 0.735529]
# [Epoch 22/1000] [Accuracy  : 0.667013]
# [Epoch 23/1000] [Train_Loss: 0.733756 /Valid_Loss: 0.725420]
# [Epoch 23/1000] [Accuracy  : 0.667750]
# [Epoch 24/1000] [Train_Loss: 0.714663 /Valid_Loss: 0.714310]
# [Epoch 24/1000] [Accuracy  : 0.682288]
# [Epoch 25/1000] [Train_Loss: 0.725464 /Valid_Loss: 0.721310]
# [Epoch 25/1000] [Accuracy  : 0.675687]
# [Epoch 26/1000] [Train_Loss: 0.721184 /Valid_Loss: 0.696312]
# [Epoch 26/1000] [Accuracy  : 0.670850]
# [Epoch 27/1000] [Train_Loss: 0.707938 /Valid_Loss: 0.689945]
# [Epoch 27/1000] [Accuracy  : 0.689638]
# [Epoch 28/1000] [Train_Loss: 0.697639 /Valid_Loss: 0.681668]
# [Epoch 28/1000] [Accuracy  : 0.689388]
# [Epoch 29/1000] [Train_Loss: 0.687078 /Valid_Loss: 0.681093]
# [Epoch 29/1000] [Accuracy  : 0.682013]
# [Epoch 30/1000] [Train_Loss: 0.685919 /Valid_Loss: 0.685137]
# [Epoch 30/1000] [Accuracy  : 0.684262]
# [Epoch 31/1000] [Train_Loss: 0.675250 /Valid_Loss: 0.673882]
# [Epoch 31/1000] [Accuracy  : 0.685875]
# [Epoch 32/1000] [Train_Loss: 0.683316 /Valid_Loss: 0.665864]
# [Epoch 32/1000] [Accuracy  : 0.698300]
# [Epoch 33/1000] [Train_Loss: 0.677495 /Valid_Loss: 0.665984]
# [Epoch 33/1000] [Accuracy  : 0.693975]
# [Epoch 34/1000] [Train_Loss: 0.655591 /Valid_Loss: 0.665724]
# [Epoch 34/1000] [Accuracy  : 0.701063]
# [Epoch 35/1000] [Train_Loss: 0.666257 /Valid_Loss: 0.663581]
# [Epoch 35/1000] [Accuracy  : 0.691113]
# [Epoch 36/1000] [Train_Loss: 0.670066 /Valid_Loss: 0.664265]
# [Epoch 36/1000] [Accuracy  : 0.696550]
# [Epoch 37/1000] [Train_Loss: 0.658233 /Valid_Loss: 0.651961]
# [Epoch 37/1000] [Accuracy  : 0.699075]
# [Epoch 38/1000] [Train_Loss: 0.665616 /Valid_Loss: 0.662583]
# [Epoch 38/1000] [Accuracy  : 0.700712]
# [Epoch 39/1000] [Train_Loss: 0.638950 /Valid_Loss: 0.646552]
# [Epoch 39/1000] [Accuracy  : 0.704313]
# [Epoch 40/1000] [Train_Loss: 0.649954 /Valid_Loss: 0.642337]
# [Epoch 40/1000] [Accuracy  : 0.703738]
# [Epoch 41/1000] [Train_Loss: 0.654940 /Valid_Loss: 0.650558]
# [Epoch 41/1000] [Accuracy  : 0.694175]
# [Epoch 42/1000] [Train_Loss: 0.646391 /Valid_Loss: 0.643063]
# [Epoch 42/1000] [Accuracy  : 0.710263]
# [Epoch 43/1000] [Train_Loss: 0.667009 /Valid_Loss: 0.639920]
# [Epoch 43/1000] [Accuracy  : 0.701488]
# [Epoch 44/1000] [Train_Loss: 0.653989 /Valid_Loss: 0.641667]
# [Epoch 44/1000] [Accuracy  : 0.709963]
# [Epoch 45/1000] [Train_Loss: 0.662239 /Valid_Loss: 0.644064]
# [Epoch 45/1000] [Accuracy  : 0.707450]
# [Epoch 46/1000] [Train_Loss: 0.655077 /Valid_Loss: 0.638677]
# [Epoch 46/1000] [Accuracy  : 0.708225]
# [Epoch 47/1000] [Train_Loss: 0.637437 /Valid_Loss: 0.638962]
# [Epoch 47/1000] [Accuracy  : 0.705950]
# [Epoch 48/1000] [Train_Loss: 0.630836 /Valid_Loss: 0.640167]
# [Epoch 48/1000] [Accuracy  : 0.707638]
# [Epoch 49/1000] [Train_Loss: 0.635161 /Valid_Loss: 0.631637]
# [Epoch 49/1000] [Accuracy  : 0.710050]
# [Epoch 50/1000] [Train_Loss: 0.653409 /Valid_Loss: 0.634551]
# [Epoch 50/1000] [Accuracy  : 0.712075]
# [Epoch 51/1000] [Train_Loss: 0.645418 /Valid_Loss: 0.638736]
# [Epoch 51/1000] [Accuracy  : 0.705000]
# [Epoch 52/1000] [Train_Loss: 0.645796 /Valid_Loss: 0.636554]
# [Epoch 52/1000] [Accuracy  : 0.711000]
# [Epoch 53/1000] [Train_Loss: 0.638972 /Valid_Loss: 0.630290]
# [Epoch 53/1000] [Accuracy  : 0.712950]
# [Epoch 54/1000] [Train_Loss: 0.633870 /Valid_Loss: 0.625174]
# [Epoch 54/1000] [Accuracy  : 0.721125]
# [Epoch 55/1000] [Train_Loss: 0.640947 /Valid_Loss: 0.625032]
# [Epoch 55/1000] [Accuracy  : 0.717087]
# [Epoch 56/1000] [Train_Loss: 0.632861 /Valid_Loss: 0.630761]
# [Epoch 56/1000] [Accuracy  : 0.710325]
# [Epoch 57/1000] [Train_Loss: 0.639352 /Valid_Loss: 0.622821]
# [Epoch 57/1000] [Accuracy  : 0.720325]
# [Epoch 58/1000] [Train_Loss: 0.633694 /Valid_Loss: 0.644004]
# [Epoch 58/1000] [Accuracy  : 0.713325]
# [Epoch 59/1000] [Train_Loss: 0.628112 /Valid_Loss: 0.624867]
# [Epoch 59/1000] [Accuracy  : 0.716612]
# [Epoch 60/1000] [Train_Loss: 0.647296 /Valid_Loss: 0.622123]
# [Epoch 60/1000] [Accuracy  : 0.722237]
# [Epoch 61/1000] [Train_Loss: 0.628030 /Valid_Loss: 0.615555]
# [Epoch 61/1000] [Accuracy  : 0.721912]
# [Epoch 62/1000] [Train_Loss: 0.626086 /Valid_Loss: 0.618781]
# [Epoch 62/1000] [Accuracy  : 0.719463]
# [Epoch 63/1000] [Train_Loss: 0.615797 /Valid_Loss: 0.624368]
# [Epoch 63/1000] [Accuracy  : 0.721988]
# [Epoch 64/1000] [Train_Loss: 0.622667 /Valid_Loss: 0.617619]
# [Epoch 64/1000] [Accuracy  : 0.722000]
# [Epoch 65/1000] [Train_Loss: 0.624855 /Valid_Loss: 0.616095]
# [Epoch 65/1000] [Accuracy  : 0.719900]
# [Epoch 66/1000] [Train_Loss: 0.616978 /Valid_Loss: 0.612774]
# [Epoch 66/1000] [Accuracy  : 0.722350]
# [Epoch 67/1000] [Train_Loss: 0.622629 /Valid_Loss: 0.613648]
# [Epoch 67/1000] [Accuracy  : 0.725838]
# [Epoch 68/1000] [Train_Loss: 0.610090 /Valid_Loss: 0.611121]
# [Epoch 68/1000] [Accuracy  : 0.724662]
# [Epoch 69/1000] [Train_Loss: 0.615653 /Valid_Loss: 0.610309]
# [Epoch 69/1000] [Accuracy  : 0.724800]
# [Epoch 70/1000] [Train_Loss: 0.612021 /Valid_Loss: 0.619464]
# [Epoch 70/1000] [Accuracy  : 0.718700]
# [Epoch 71/1000] [Train_Loss: 0.604260 /Valid_Loss: 0.611964]
# [Epoch 71/1000] [Accuracy  : 0.729838]
# [Epoch 72/1000] [Train_Loss: 0.606092 /Valid_Loss: 0.614917]
# [Epoch 72/1000] [Accuracy  : 0.727537]
# [Epoch 73/1000] [Train_Loss: 0.619141 /Valid_Loss: 0.611763]
# [Epoch 73/1000] [Accuracy  : 0.726387]
# [Epoch 74/1000] [Train_Loss: 0.617716 /Valid_Loss: 0.604181]
# [Epoch 74/1000] [Accuracy  : 0.726437]
# [Epoch 75/1000] [Train_Loss: 0.612009 /Valid_Loss: 0.615739]
# [Epoch 75/1000] [Accuracy  : 0.719788]
# [Epoch 76/1000] [Train_Loss: 0.620510 /Valid_Loss: 0.606600]
# [Epoch 76/1000] [Accuracy  : 0.731688]
# [Epoch 77/1000] [Train_Loss: 0.620799 /Valid_Loss: 0.605122]
# [Epoch 77/1000] [Accuracy  : 0.732875]
# [Epoch 78/1000] [Train_Loss: 0.636346 /Valid_Loss: 0.611403]
# [Epoch 78/1000] [Accuracy  : 0.725962]
# [Epoch 79/1000] [Train_Loss: 0.607913 /Valid_Loss: 0.605145]
# [Epoch 79/1000] [Accuracy  : 0.733487]
# [Epoch 80/1000] [Train_Loss: 0.612475 /Valid_Loss: 0.613672]
# [Epoch 80/1000] [Accuracy  : 0.720688]
# [Epoch 81/1000] [Train_Loss: 0.610038 /Valid_Loss: 0.602319]
# [Epoch 81/1000] [Accuracy  : 0.727775]
# [Epoch 82/1000] [Train_Loss: 0.604136 /Valid_Loss: 0.606014]
# [Epoch 82/1000] [Accuracy  : 0.730700]
# [Epoch 83/1000] [Train_Loss: 0.603476 /Valid_Loss: 0.602676]
# [Epoch 83/1000] [Accuracy  : 0.737862]
# [Epoch 84/1000] [Train_Loss: 0.605268 /Valid_Loss: 0.604236]
# [Epoch 84/1000] [Accuracy  : 0.731125]
# [Epoch 85/1000] [Train_Loss: 0.611998 /Valid_Loss: 0.604161]
# [Epoch 85/1000] [Accuracy  : 0.730700]
# [Epoch 86/1000] [Train_Loss: 0.614911 /Valid_Loss: 0.601017]
# [Epoch 86/1000] [Accuracy  : 0.736563]
# [Epoch 87/1000] [Train_Loss: 0.620516 /Valid_Loss: 0.602960]
# [Epoch 87/1000] [Accuracy  : 0.730650]
# [Epoch 88/1000] [Train_Loss: 0.604583 /Valid_Loss: 0.602140]
# [Epoch 88/1000] [Accuracy  : 0.737738]
# [Epoch 89/1000] [Train_Loss: 0.608165 /Valid_Loss: 0.605938]
# [Epoch 89/1000] [Accuracy  : 0.724437]
# [Epoch 90/1000] [Train_Loss: 0.607203 /Valid_Loss: 0.598277]
# [Epoch 90/1000] [Accuracy  : 0.733825]
# [Epoch 91/1000] [Train_Loss: 0.597097 /Valid_Loss: 0.599845]
# [Epoch 91/1000] [Accuracy  : 0.738187]
# [Epoch 92/1000] [Train_Loss: 0.627985 /Valid_Loss: 0.599063]
# [Epoch 92/1000] [Accuracy  : 0.732962]
# [Epoch 93/1000] [Train_Loss: 0.595146 /Valid_Loss: 0.597669]
# [Epoch 93/1000] [Accuracy  : 0.737125]
# [Epoch 94/1000] [Train_Loss: 0.607170 /Valid_Loss: 0.598037]
# [Epoch 94/1000] [Accuracy  : 0.734100]
# [Epoch 95/1000] [Train_Loss: 0.597465 /Valid_Loss: 0.601554]
# [Epoch 95/1000] [Accuracy  : 0.731575]
# [Epoch 96/1000] [Train_Loss: 0.596658 /Valid_Loss: 0.600980]
# [Epoch 96/1000] [Accuracy  : 0.737912]
# [Epoch 97/1000] [Train_Loss: 0.603903 /Valid_Loss: 0.604632]
# [Epoch 97/1000] [Accuracy  : 0.733850]
# [Epoch 98/1000] [Train_Loss: 0.619272 /Valid_Loss: 0.594198]
# [Epoch 98/1000] [Accuracy  : 0.738775]
# [Epoch 99/1000] [Train_Loss: 0.602315 /Valid_Loss: 0.599146]
# [Epoch 99/1000] [Accuracy  : 0.737138]
# [Epoch 100/1000] [Train_Loss: 0.608141 /Valid_Loss: 0.598466]
# [Epoch 100/1000] [Accuracy  : 0.734563]
# [Epoch 101/1000] [Train_Loss: 0.604897 /Valid_Loss: 0.596686]
# [Epoch 101/1000] [Accuracy  : 0.739700]
# [Epoch 102/1000] [Train_Loss: 0.598131 /Valid_Loss: 0.593159]
# [Epoch 102/1000] [Accuracy  : 0.738975]
# [Epoch 103/1000] [Train_Loss: 0.601032 /Valid_Loss: 0.594163]
# [Epoch 103/1000] [Accuracy  : 0.743663]
# [Epoch 104/1000] [Train_Loss: 0.609929 /Valid_Loss: 0.597053]
# [Epoch 104/1000] [Accuracy  : 0.740237]
# [Epoch 105/1000] [Train_Loss: 0.598364 /Valid_Loss: 0.600479]
# [Epoch 105/1000] [Accuracy  : 0.735725]
# [Epoch 106/1000] [Train_Loss: 0.577277 /Valid_Loss: 0.597001]
# [Epoch 106/1000] [Accuracy  : 0.737475]
# [Epoch 107/1000] [Train_Loss: 0.600795 /Valid_Loss: 0.596036]
# [Epoch 107/1000] [Accuracy  : 0.740250]
# [Epoch 108/1000] [Train_Loss: 0.604262 /Valid_Loss: 0.593305]
# [Epoch 108/1000] [Accuracy  : 0.741150]
# [Epoch 109/1000] [Train_Loss: 0.607031 /Valid_Loss: 0.589992]
# [Epoch 109/1000] [Accuracy  : 0.742050]
# [Epoch 110/1000] [Train_Loss: 0.608929 /Valid_Loss: 0.590279]
# [Epoch 110/1000] [Accuracy  : 0.743938]
# [Epoch 111/1000] [Train_Loss: 0.601918 /Valid_Loss: 0.592900]
# [Epoch 111/1000] [Accuracy  : 0.737537]
# [Epoch 112/1000] [Train_Loss: 0.591398 /Valid_Loss: 0.593590]
# [Epoch 112/1000] [Accuracy  : 0.742000]
# [Epoch 113/1000] [Train_Loss: 0.610644 /Valid_Loss: 0.600372]
# [Epoch 113/1000] [Accuracy  : 0.733750]
# [Epoch 114/1000] [Train_Loss: 0.590774 /Valid_Loss: 0.592045]
# [Epoch 114/1000] [Accuracy  : 0.741613]
# [Epoch 115/1000] [Train_Loss: 0.578425 /Valid_Loss: 0.595141]
# [Epoch 115/1000] [Accuracy  : 0.741175]
# [Epoch 116/1000] [Train_Loss: 0.598892 /Valid_Loss: 0.595285]
# [Epoch 116/1000] [Accuracy  : 0.739675]
# [Epoch 117/1000] [Train_Loss: 0.606101 /Valid_Loss: 0.597504]
# [Epoch 117/1000] [Accuracy  : 0.735550]
# [Epoch 118/1000] [Train_Loss: 0.592205 /Valid_Loss: 0.594917]
# [Epoch 118/1000] [Accuracy  : 0.735862]
# [Epoch 119/1000] [Train_Loss: 0.599343 /Valid_Loss: 0.592452]
# [Epoch 119/1000] [Accuracy  : 0.743975]
# [Epoch 120/1000] [Train_Loss: 0.589032 /Valid_Loss: 0.593420]
# [Epoch 120/1000] [Accuracy  : 0.736988]
# [Epoch 121/1000] [Train_Loss: 0.606252 /Valid_Loss: 0.588732]
# [Epoch 121/1000] [Accuracy  : 0.743500]
# [Epoch 122/1000] [Train_Loss: 0.594841 /Valid_Loss: 0.592052]
# [Epoch 122/1000] [Accuracy  : 0.741950]
# [Epoch 123/1000] [Train_Loss: 0.609654 /Valid_Loss: 0.600336]
# [Epoch 123/1000] [Accuracy  : 0.738537]
# [Epoch 124/1000] [Train_Loss: 0.586670 /Valid_Loss: 0.598274]
# [Epoch 124/1000] [Accuracy  : 0.735688]
# [Epoch 125/1000] [Train_Loss: 0.598276 /Valid_Loss: 0.590962]
# [Epoch 125/1000] [Accuracy  : 0.741775]
# [Epoch 126/1000] [Train_Loss: 0.595647 /Valid_Loss: 0.591921]
# [Epoch 126/1000] [Accuracy  : 0.742400]
# [Epoch 127/1000] [Train_Loss: 0.598396 /Valid_Loss: 0.588732]
# [Epoch 127/1000] [Accuracy  : 0.743225]
# [Epoch 128/1000] [Train_Loss: 0.590613 /Valid_Loss: 0.588787]
# [Epoch 128/1000] [Accuracy  : 0.740862]
# [Epoch 129/1000] [Train_Loss: 0.598784 /Valid_Loss: 0.590100]
# [Epoch 129/1000] [Accuracy  : 0.740650]
# [Epoch 130/1000] [Train_Loss: 0.595012 /Valid_Loss: 0.593974]
# [Epoch 130/1000] [Accuracy  : 0.743050]
# [Epoch 131/1000] [Train_Loss: 0.603653 /Valid_Loss: 0.590504]
# [Epoch 131/1000] [Accuracy  : 0.739275]
# [Epoch 132/1000] [Train_Loss: 0.588714 /Valid_Loss: 0.588351]
# [Epoch 132/1000] [Accuracy  : 0.744112]
# [Epoch 133/1000] [Train_Loss: 0.585118 /Valid_Loss: 0.588682]
# [Epoch 133/1000] [Accuracy  : 0.743950]
# [Epoch 134/1000] [Train_Loss: 0.593210 /Valid_Loss: 0.591036]
# [Epoch 134/1000] [Accuracy  : 0.740650]
# [Epoch 135/1000] [Train_Loss: 0.578587 /Valid_Loss: 0.587504]
# [Epoch 135/1000] [Accuracy  : 0.745575]
# [Epoch 136/1000] [Train_Loss: 0.588217 /Valid_Loss: 0.588327]
# [Epoch 136/1000] [Accuracy  : 0.743675]
# [Epoch 137/1000] [Train_Loss: 0.589162 /Valid_Loss: 0.589563]
# [Epoch 137/1000] [Accuracy  : 0.741812]
# [Epoch 138/1000] [Train_Loss: 0.590887 /Valid_Loss: 0.592954]
# [Epoch 138/1000] [Accuracy  : 0.742425]
# [Epoch 139/1000] [Train_Loss: 0.581604 /Valid_Loss: 0.586061]
# [Epoch 139/1000] [Accuracy  : 0.745400]
# [Epoch 140/1000] [Train_Loss: 0.581265 /Valid_Loss: 0.587882]
# [Epoch 140/1000] [Accuracy  : 0.740375]
# [Epoch 141/1000] [Train_Loss: 0.585431 /Valid_Loss: 0.586217]
# [Epoch 141/1000] [Accuracy  : 0.746825]
# [Epoch 142/1000] [Train_Loss: 0.611555 /Valid_Loss: 0.592166]
# [Epoch 142/1000] [Accuracy  : 0.742012]
# [Epoch 143/1000] [Train_Loss: 0.583524 /Valid_Loss: 0.583816]
# [Epoch 143/1000] [Accuracy  : 0.747300]
# [Epoch 144/1000] [Train_Loss: 0.599380 /Valid_Loss: 0.589364]
# [Epoch 144/1000] [Accuracy  : 0.741988]
# [Epoch 145/1000] [Train_Loss: 0.589850 /Valid_Loss: 0.589016]
# [Epoch 145/1000] [Accuracy  : 0.742263]
# [Epoch 146/1000] [Train_Loss: 0.584421 /Valid_Loss: 0.587331]
# [Epoch 146/1000] [Accuracy  : 0.745325]
# [Epoch 147/1000] [Train_Loss: 0.591432 /Valid_Loss: 0.587921]
# [Epoch 147/1000] [Accuracy  : 0.739350]
# [Epoch 148/1000] [Train_Loss: 0.593378 /Valid_Loss: 0.588932]
# [Epoch 148/1000] [Accuracy  : 0.742687]
# [Epoch 149/1000] [Train_Loss: 0.602691 /Valid_Loss: 0.585428]
# [Epoch 149/1000] [Accuracy  : 0.745213]
# [Epoch 150/1000] [Train_Loss: 0.596373 /Valid_Loss: 0.597230]
# [Epoch 150/1000] [Accuracy  : 0.737500]
# [Epoch 151/1000] [Train_Loss: 0.576746 /Valid_Loss: 0.585324]
# [Epoch 151/1000] [Accuracy  : 0.743812]
# [Epoch 152/1000] [Train_Loss: 0.569663 /Valid_Loss: 0.588951]
# [Epoch 152/1000] [Accuracy  : 0.742475]
# [Epoch 153/1000] [Train_Loss: 0.585814 /Valid_Loss: 0.583585]
# [Epoch 153/1000] [Accuracy  : 0.743550]
# [Epoch 154/1000] [Train_Loss: 0.596667 /Valid_Loss: 0.588057]
# [Epoch 154/1000] [Accuracy  : 0.740287]
# [Epoch 155/1000] [Train_Loss: 0.573112 /Valid_Loss: 0.587226]
# [Epoch 155/1000] [Accuracy  : 0.742888]
# [Epoch 156/1000] [Train_Loss: 0.583099 /Valid_Loss: 0.584611]
# [Epoch 156/1000] [Accuracy  : 0.745600]
# [Epoch 157/1000] [Train_Loss: 0.575029 /Valid_Loss: 0.583583]
# [Epoch 157/1000] [Accuracy  : 0.744650]
# [Epoch 158/1000] [Train_Loss: 0.587165 /Valid_Loss: 0.583757]
# [Epoch 158/1000] [Accuracy  : 0.744625]
# [Epoch 159/1000] [Train_Loss: 0.598838 /Valid_Loss: 0.583717]
# [Epoch 159/1000] [Accuracy  : 0.746425]
# [Epoch 160/1000] [Train_Loss: 0.577974 /Valid_Loss: 0.587732]
# [Epoch 160/1000] [Accuracy  : 0.743712]
# [Epoch 161/1000] [Train_Loss: 0.584645 /Valid_Loss: 0.586165]
# [Epoch 161/1000] [Accuracy  : 0.744000]
# [Epoch 162/1000] [Train_Loss: 0.596031 /Valid_Loss: 0.583559]
# [Epoch 162/1000] [Accuracy  : 0.742062]
# [Epoch 163/1000] [Train_Loss: 0.600146 /Valid_Loss: 0.586710]
# [Epoch 163/1000] [Accuracy  : 0.744437]
# [Epoch 164/1000] [Train_Loss: 0.577843 /Valid_Loss: 0.582064]
# [Epoch 164/1000] [Accuracy  : 0.748212]
# [Epoch 165/1000] [Train_Loss: 0.596653 /Valid_Loss: 0.583939]
# [Epoch 165/1000] [Accuracy  : 0.745550]
# [Epoch 166/1000] [Train_Loss: 0.597536 /Valid_Loss: 0.586369]
# [Epoch 166/1000] [Accuracy  : 0.742862]
# [Epoch 167/1000] [Train_Loss: 0.577062 /Valid_Loss: 0.587943]
# [Epoch 167/1000] [Accuracy  : 0.743437]
# [Epoch 168/1000] [Train_Loss: 0.585679 /Valid_Loss: 0.582597]
# [Epoch 168/1000] [Accuracy  : 0.747337]
# [Epoch 169/1000] [Train_Loss: 0.581842 /Valid_Loss: 0.583476]
# [Epoch 169/1000] [Accuracy  : 0.745525]
# [Epoch 170/1000] [Train_Loss: 0.580362 /Valid_Loss: 0.585953]
# [Epoch 170/1000] [Accuracy  : 0.746363]
# [Epoch 171/1000] [Train_Loss: 0.583405 /Valid_Loss: 0.586297]
# [Epoch 171/1000] [Accuracy  : 0.744487]
# [Epoch 172/1000] [Train_Loss: 0.581132 /Valid_Loss: 0.589170]
# [Epoch 172/1000] [Accuracy  : 0.741475]
# [Epoch 173/1000] [Train_Loss: 0.590758 /Valid_Loss: 0.583256]
# [Epoch 173/1000] [Accuracy  : 0.742550]
# [Epoch 174/1000] [Train_Loss: 0.584203 /Valid_Loss: 0.584374]
# [Epoch 174/1000] [Accuracy  : 0.744413]
# [Epoch 175/1000] [Train_Loss: 0.583404 /Valid_Loss: 0.584653]
# [Epoch 175/1000] [Accuracy  : 0.744450]
# [Epoch 176/1000] [Train_Loss: 0.591645 /Valid_Loss: 0.579455]
# [Epoch 176/1000] [Accuracy  : 0.748387]
# [Epoch 177/1000] [Train_Loss: 0.587492 /Valid_Loss: 0.582301]
# [Epoch 177/1000] [Accuracy  : 0.744850]
# [Epoch 178/1000] [Train_Loss: 0.579357 /Valid_Loss: 0.581399]
# [Epoch 178/1000] [Accuracy  : 0.746563]
# [Epoch 179/1000] [Train_Loss: 0.587750 /Valid_Loss: 0.582753]
# [Epoch 179/1000] [Accuracy  : 0.747062]
# [Epoch 180/1000] [Train_Loss: 0.579257 /Valid_Loss: 0.579907]
# [Epoch 180/1000] [Accuracy  : 0.746525]
# [Epoch 181/1000] [Train_Loss: 0.586112 /Valid_Loss: 0.586108]
# [Epoch 181/1000] [Accuracy  : 0.742150]
# [Epoch 182/1000] [Train_Loss: 0.579233 /Valid_Loss: 0.583603]
# [Epoch 182/1000] [Accuracy  : 0.745750]
# [Epoch 183/1000] [Train_Loss: 0.581684 /Valid_Loss: 0.583438]
# [Epoch 183/1000] [Accuracy  : 0.746100]
# [Epoch 184/1000] [Train_Loss: 0.592676 /Valid_Loss: 0.580570]
# [Epoch 184/1000] [Accuracy  : 0.747587]
# [Epoch 185/1000] [Train_Loss: 0.583930 /Valid_Loss: 0.583054]
# [Epoch 185/1000] [Accuracy  : 0.745912]
# [Epoch 186/1000] [Train_Loss: 0.584539 /Valid_Loss: 0.583718]
# [Epoch 186/1000] [Accuracy  : 0.744775]
# [Epoch 187/1000] [Train_Loss: 0.575784 /Valid_Loss: 0.584796]
# [Epoch 187/1000] [Accuracy  : 0.744563]
# [Epoch 188/1000] [Train_Loss: 0.585984 /Valid_Loss: 0.579660]
# [Epoch 188/1000] [Accuracy  : 0.748637]
# [Epoch 189/1000] [Train_Loss: 0.593605 /Valid_Loss: 0.579948]
# [Epoch 189/1000] [Accuracy  : 0.748050]
# [Epoch 190/1000] [Train_Loss: 0.588083 /Valid_Loss: 0.588021]
# [Epoch 190/1000] [Accuracy  : 0.745600]
# [Epoch 191/1000] [Train_Loss: 0.590355 /Valid_Loss: 0.582675]
# [Epoch 191/1000] [Accuracy  : 0.745363]
# [Epoch 192/1000] [Train_Loss: 0.588713 /Valid_Loss: 0.586078]
# [Epoch 192/1000] [Accuracy  : 0.741850]
# [Epoch 193/1000] [Train_Loss: 0.568753 /Valid_Loss: 0.580047]
# [Epoch 193/1000] [Accuracy  : 0.748263]
# [Epoch 194/1000] [Train_Loss: 0.586581 /Valid_Loss: 0.584615]
# [Epoch 194/1000] [Accuracy  : 0.745475]
# [Epoch 195/1000] [Train_Loss: 0.588208 /Valid_Loss: 0.584623]
# [Epoch 195/1000] [Accuracy  : 0.743025]
# [Epoch 196/1000] [Train_Loss: 0.577491 /Valid_Loss: 0.587334]
# [Epoch 196/1000] [Accuracy  : 0.741962]
# [Epoch 197/1000] [Train_Loss: 0.579055 /Valid_Loss: 0.587246]
# [Epoch 197/1000] [Accuracy  : 0.743025]
# [Epoch 198/1000] [Train_Loss: 0.588511 /Valid_Loss: 0.580022]
# [Epoch 198/1000] [Accuracy  : 0.745888]
# [Epoch 199/1000] [Train_Loss: 0.588305 /Valid_Loss: 0.580131]
# [Epoch 199/1000] [Accuracy  : 0.746950]
# [Epoch 200/1000] [Train_Loss: 0.593347 /Valid_Loss: 0.580835]
# [Epoch 200/1000] [Accuracy  : 0.748525]
# [Epoch 201/1000] [Train_Loss: 0.577205 /Valid_Loss: 0.584012]
# [Epoch 201/1000] [Accuracy  : 0.741637]
# [Epoch 202/1000] [Train_Loss: 0.583527 /Valid_Loss: 0.585683]
# [Epoch 202/1000] [Accuracy  : 0.741900]
# [Epoch 203/1000] [Train_Loss: 0.578440 /Valid_Loss: 0.583239]
# [Epoch 203/1000] [Accuracy  : 0.743325]
# [Epoch 204/1000] [Train_Loss: 0.582855 /Valid_Loss: 0.578984]
# [Epoch 204/1000] [Accuracy  : 0.749225]
# [Epoch 205/1000] [Train_Loss: 0.583385 /Valid_Loss: 0.580546]
# [Epoch 205/1000] [Accuracy  : 0.746938]
# [Epoch 206/1000] [Train_Loss: 0.593503 /Valid_Loss: 0.581622]
# [Epoch 206/1000] [Accuracy  : 0.745537]
# [Epoch 207/1000] [Train_Loss: 0.596284 /Valid_Loss: 0.579734]
# [Epoch 207/1000] [Accuracy  : 0.748838]
# [Epoch 208/1000] [Train_Loss: 0.585491 /Valid_Loss: 0.588026]
# [Epoch 208/1000] [Accuracy  : 0.738350]
# [Epoch 209/1000] [Train_Loss: 0.585499 /Valid_Loss: 0.579942]
# [Epoch 209/1000] [Accuracy  : 0.748750]
# [Epoch 210/1000] [Train_Loss: 0.571529 /Valid_Loss: 0.581745]
# [Epoch 210/1000] [Accuracy  : 0.745175]
# [Epoch 211/1000] [Train_Loss: 0.591836 /Valid_Loss: 0.580333]
# [Epoch 211/1000] [Accuracy  : 0.746912]
# [Epoch 212/1000] [Train_Loss: 0.599099 /Valid_Loss: 0.579323]
# [Epoch 212/1000] [Accuracy  : 0.746700]
# [Epoch 213/1000] [Train_Loss: 0.578255 /Valid_Loss: 0.582036]
# [Epoch 213/1000] [Accuracy  : 0.746188]
# [Epoch 214/1000] [Train_Loss: 0.579053 /Valid_Loss: 0.582912]
# [Epoch 214/1000] [Accuracy  : 0.746237]
# [Epoch 215/1000] [Train_Loss: 0.572853 /Valid_Loss: 0.579845]
# [Epoch 215/1000] [Accuracy  : 0.747237]
# [Epoch 216/1000] [Train_Loss: 0.561059 /Valid_Loss: 0.583982]
# [Epoch 216/1000] [Accuracy  : 0.746175]
# [Epoch 217/1000] [Train_Loss: 0.586158 /Valid_Loss: 0.586812]
# [Epoch 217/1000] [Accuracy  : 0.744613]
# [Epoch 218/1000] [Train_Loss: 0.572169 /Valid_Loss: 0.586696]
# [Epoch 218/1000] [Accuracy  : 0.741962]
# [Epoch 219/1000] [Train_Loss: 0.587637 /Valid_Loss: 0.583254]
# [Epoch 219/1000] [Accuracy  : 0.745950]
# [Epoch 220/1000] [Train_Loss: 0.588414 /Valid_Loss: 0.580739]
# [Epoch 220/1000] [Accuracy  : 0.744838]
# [Epoch 221/1000] [Train_Loss: 0.580415 /Valid_Loss: 0.582005]
# [Epoch 221/1000] [Accuracy  : 0.743550]
# [Epoch 222/1000] [Train_Loss: 0.600634 /Valid_Loss: 0.586587]
# [Epoch 222/1000] [Accuracy  : 0.743387]
# [Epoch 223/1000] [Train_Loss: 0.589229 /Valid_Loss: 0.578004]
# [Epoch 223/1000] [Accuracy  : 0.747012]
# [Epoch 224/1000] [Train_Loss: 0.586693 /Valid_Loss: 0.580627]
# [Epoch 224/1000] [Accuracy  : 0.747550]
# [Epoch 225/1000] [Train_Loss: 0.583194 /Valid_Loss: 0.579995]
# [Epoch 225/1000] [Accuracy  : 0.745850]
# [Epoch 226/1000] [Train_Loss: 0.599633 /Valid_Loss: 0.587143]
# [Epoch 226/1000] [Accuracy  : 0.740575]
# [Epoch 227/1000] [Train_Loss: 0.592075 /Valid_Loss: 0.579552]
# [Epoch 227/1000] [Accuracy  : 0.746088]
# [Epoch 228/1000] [Train_Loss: 0.590773 /Valid_Loss: 0.578719]
# [Epoch 228/1000] [Accuracy  : 0.747888]
# [Epoch 229/1000] [Train_Loss: 0.567555 /Valid_Loss: 0.580836]
# [Epoch 229/1000] [Accuracy  : 0.747025]
# [Epoch 230/1000] [Train_Loss: 0.589747 /Valid_Loss: 0.579387]
# [Epoch 230/1000] [Accuracy  : 0.748038]
# [Epoch 231/1000] [Train_Loss: 0.573649 /Valid_Loss: 0.581312]
# [Epoch 231/1000] [Accuracy  : 0.747225]
# [Epoch 232/1000] [Train_Loss: 0.586711 /Valid_Loss: 0.579500]
# [Epoch 232/1000] [Accuracy  : 0.747537]
# [Epoch 233/1000] [Train_Loss: 0.569274 /Valid_Loss: 0.581460]
# [Epoch 233/1000] [Accuracy  : 0.746175]
# [Epoch 234/1000] [Train_Loss: 0.575134 /Valid_Loss: 0.584760]
# [Epoch 234/1000] [Accuracy  : 0.738237]
# [Epoch 235/1000] [Train_Loss: 0.589669 /Valid_Loss: 0.580303]
# [Epoch 235/1000] [Accuracy  : 0.746300]
# [Epoch 236/1000] [Train_Loss: 0.593162 /Valid_Loss: 0.584014]
# [Epoch 236/1000] [Accuracy  : 0.744900]
# [Epoch 237/1000] [Train_Loss: 0.597705 /Valid_Loss: 0.583337]
# [Epoch 237/1000] [Accuracy  : 0.744712]
# [Epoch 238/1000] [Train_Loss: 0.585076 /Valid_Loss: 0.578077]
# [Epoch 238/1000] [Accuracy  : 0.750350]
# [Epoch 239/1000] [Train_Loss: 0.569817 /Valid_Loss: 0.576513]
# [Epoch 239/1000] [Accuracy  : 0.749450]
# [Epoch 240/1000] [Train_Loss: 0.593238 /Valid_Loss: 0.583665]
# [Epoch 240/1000] [Accuracy  : 0.743263]
# [Epoch 241/1000] [Train_Loss: 0.596875 /Valid_Loss: 0.576946]
# [Epoch 241/1000] [Accuracy  : 0.749525]
# [Epoch 242/1000] [Train_Loss: 0.590184 /Valid_Loss: 0.579177]
# [Epoch 242/1000] [Accuracy  : 0.749375]
# [Epoch 243/1000] [Train_Loss: 0.566848 /Valid_Loss: 0.577495]
# [Epoch 243/1000] [Accuracy  : 0.750200]
# [Epoch 244/1000] [Train_Loss: 0.573536 /Valid_Loss: 0.577131]
# [Epoch 244/1000] [Accuracy  : 0.748088]
# [Epoch 245/1000] [Train_Loss: 0.590764 /Valid_Loss: 0.576965]
# [Epoch 245/1000] [Accuracy  : 0.748563]
# [Epoch 246/1000] [Train_Loss: 0.580673 /Valid_Loss: 0.583479]
# [Epoch 246/1000] [Accuracy  : 0.744413]
# [Epoch 247/1000] [Train_Loss: 0.581525 /Valid_Loss: 0.583864]
# [Epoch 247/1000] [Accuracy  : 0.743563]
# [Epoch 248/1000] [Train_Loss: 0.571495 /Valid_Loss: 0.576934]
# [Epoch 248/1000] [Accuracy  : 0.749600]
# [Epoch 249/1000] [Train_Loss: 0.574594 /Valid_Loss: 0.586047]
# [Epoch 249/1000] [Accuracy  : 0.741688]
# [Epoch 250/1000] [Train_Loss: 0.585613 /Valid_Loss: 0.581876]
# [Epoch 250/1000] [Accuracy  : 0.748775]
# [Epoch 251/1000] [Train_Loss: 0.581994 /Valid_Loss: 0.581779]
# [Epoch 251/1000] [Accuracy  : 0.748112]
# [Epoch 252/1000] [Train_Loss: 0.577274 /Valid_Loss: 0.579772]
# [Epoch 252/1000] [Accuracy  : 0.746162]
# [Epoch 253/1000] [Train_Loss: 0.561787 /Valid_Loss: 0.583165]
# [Epoch 253/1000] [Accuracy  : 0.745700]
# [Epoch 254/1000] [Train_Loss: 0.587364 /Valid_Loss: 0.579489]
# [Epoch 254/1000] [Accuracy  : 0.747012]
# [Epoch 255/1000] [Train_Loss: 0.579537 /Valid_Loss: 0.573675]
# [Epoch 255/1000] [Accuracy  : 0.749938]
# [Epoch 256/1000] [Train_Loss: 0.572180 /Valid_Loss: 0.576567]
# [Epoch 256/1000] [Accuracy  : 0.749238]
# [Epoch 257/1000] [Train_Loss: 0.587992 /Valid_Loss: 0.580473]
# [Epoch 257/1000] [Accuracy  : 0.745950]
# [Epoch 258/1000] [Train_Loss: 0.590878 /Valid_Loss: 0.583603]
# [Epoch 258/1000] [Accuracy  : 0.743162]
# [Epoch 259/1000] [Train_Loss: 0.596983 /Valid_Loss: 0.580843]
# [Epoch 259/1000] [Accuracy  : 0.747287]
# [Epoch 260/1000] [Train_Loss: 0.561844 /Valid_Loss: 0.581748]
# [Epoch 260/1000] [Accuracy  : 0.745500]
# [Epoch 261/1000] [Train_Loss: 0.569882 /Valid_Loss: 0.579794]
# [Epoch 261/1000] [Accuracy  : 0.748400]
# [Epoch 262/1000] [Train_Loss: 0.582164 /Valid_Loss: 0.579272]
# [Epoch 262/1000] [Accuracy  : 0.745325]
# [Epoch 263/1000] [Train_Loss: 0.582186 /Valid_Loss: 0.579398]
# [Epoch 263/1000] [Accuracy  : 0.745400]
# [Epoch 264/1000] [Train_Loss: 0.583193 /Valid_Loss: 0.581426]
# [Epoch 264/1000] [Accuracy  : 0.747675]
# [Epoch 265/1000] [Train_Loss: 0.589763 /Valid_Loss: 0.579264]
# [Epoch 265/1000] [Accuracy  : 0.745012]
# [Epoch 266/1000] [Train_Loss: 0.576842 /Valid_Loss: 0.581606]
# [Epoch 266/1000] [Accuracy  : 0.746125]
# [Epoch 267/1000] [Train_Loss: 0.585317 /Valid_Loss: 0.575460]
# [Epoch 267/1000] [Accuracy  : 0.748687]
# [Epoch 268/1000] [Train_Loss: 0.565494 /Valid_Loss: 0.583009]
# [Epoch 268/1000] [Accuracy  : 0.745075]
# [Epoch 269/1000] [Train_Loss: 0.579959 /Valid_Loss: 0.575593]
# [Epoch 269/1000] [Accuracy  : 0.749650]
# [Epoch 270/1000] [Train_Loss: 0.570295 /Valid_Loss: 0.576269]
# [Epoch 270/1000] [Accuracy  : 0.747950]
# [Epoch 271/1000] [Train_Loss: 0.582161 /Valid_Loss: 0.575713]
# [Epoch 271/1000] [Accuracy  : 0.749962]
# [Epoch 272/1000] [Train_Loss: 0.579061 /Valid_Loss: 0.579682]
# [Epoch 272/1000] [Accuracy  : 0.746950]
# [Epoch 273/1000] [Train_Loss: 0.573952 /Valid_Loss: 0.575108]
# [Epoch 273/1000] [Accuracy  : 0.750625]
# [Epoch 274/1000] [Train_Loss: 0.570446 /Valid_Loss: 0.578145]
# [Epoch 274/1000] [Accuracy  : 0.746788]
# [Epoch 275/1000] [Train_Loss: 0.580920 /Valid_Loss: 0.584382]
# [Epoch 275/1000] [Accuracy  : 0.744812]
# [Epoch 276/1000] [Train_Loss: 0.575285 /Valid_Loss: 0.573856]
# [Epoch 276/1000] [Accuracy  : 0.752287]
# [Epoch 277/1000] [Train_Loss: 0.564691 /Valid_Loss: 0.576728]
# [Epoch 277/1000] [Accuracy  : 0.748325]
# [Epoch 278/1000] [Train_Loss: 0.566534 /Valid_Loss: 0.579174]
# [Epoch 278/1000] [Accuracy  : 0.747838]
# [Epoch 279/1000] [Train_Loss: 0.566028 /Valid_Loss: 0.579431]
# [Epoch 279/1000] [Accuracy  : 0.746188]
# [Epoch 280/1000] [Train_Loss: 0.576340 /Valid_Loss: 0.579559]
# [Epoch 280/1000] [Accuracy  : 0.743000]
# [Epoch 281/1000] [Train_Loss: 0.599089 /Valid_Loss: 0.577499]
# [Epoch 281/1000] [Accuracy  : 0.750000]
# [Epoch 282/1000] [Train_Loss: 0.574412 /Valid_Loss: 0.580349]
# [Epoch 282/1000] [Accuracy  : 0.747812]
# [Epoch 283/1000] [Train_Loss: 0.584535 /Valid_Loss: 0.577581]
# [Epoch 283/1000] [Accuracy  : 0.745350]
# [Epoch 284/1000] [Train_Loss: 0.563678 /Valid_Loss: 0.581129]
# [Epoch 284/1000] [Accuracy  : 0.745275]
# [Epoch 285/1000] [Train_Loss: 0.572352 /Valid_Loss: 0.573878]
# [Epoch 285/1000] [Accuracy  : 0.751150]
# [Epoch 286/1000] [Train_Loss: 0.572622 /Valid_Loss: 0.577791]
# [Epoch 286/1000] [Accuracy  : 0.750125]
# [Epoch 287/1000] [Train_Loss: 0.585482 /Valid_Loss: 0.579066]
# [Epoch 287/1000] [Accuracy  : 0.745988]
# [Epoch 288/1000] [Train_Loss: 0.559979 /Valid_Loss: 0.577916]
# [Epoch 288/1000] [Accuracy  : 0.746663]
# [Epoch 289/1000] [Train_Loss: 0.580324 /Valid_Loss: 0.578411]
# [Epoch 289/1000] [Accuracy  : 0.745463]
# [Epoch 290/1000] [Train_Loss: 0.576345 /Valid_Loss: 0.574919]
# [Epoch 290/1000] [Accuracy  : 0.748088]
# [Epoch 291/1000] [Train_Loss: 0.584682 /Valid_Loss: 0.578840]
# [Epoch 291/1000] [Accuracy  : 0.746725]
# [Epoch 292/1000] [Train_Loss: 0.582407 /Valid_Loss: 0.581597]
# [Epoch 292/1000] [Accuracy  : 0.745950]
# [Epoch 293/1000] [Train_Loss: 0.577767 /Valid_Loss: 0.577435]
# [Epoch 293/1000] [Accuracy  : 0.748450]
# [Epoch 294/1000] [Train_Loss: 0.559193 /Valid_Loss: 0.578888]
# [Epoch 294/1000] [Accuracy  : 0.748038]
# [Epoch 295/1000] [Train_Loss: 0.589871 /Valid_Loss: 0.575642]
# [Epoch 295/1000] [Accuracy  : 0.749788]
# [Epoch 296/1000] [Train_Loss: 0.562472 /Valid_Loss: 0.577081]
# [Epoch 296/1000] [Accuracy  : 0.747375]
# [Epoch 297/1000] [Train_Loss: 0.569536 /Valid_Loss: 0.575860]
# [Epoch 297/1000] [Accuracy  : 0.749012]
# [Epoch 298/1000] [Train_Loss: 0.595076 /Valid_Loss: 0.578299]
# [Epoch 298/1000] [Accuracy  : 0.748637]
# [Epoch 299/1000] [Train_Loss: 0.575063 /Valid_Loss: 0.578957]
# [Epoch 299/1000] [Accuracy  : 0.745350]
# [Epoch 300/1000] [Train_Loss: 0.574487 /Valid_Loss: 0.577605]
# [Epoch 300/1000] [Accuracy  : 0.747225]
# [Epoch 301/1000] [Train_Loss: 0.558251 /Valid_Loss: 0.576258]
# [Epoch 301/1000] [Accuracy  : 0.748025]
# [Epoch 302/1000] [Train_Loss: 0.564334 /Valid_Loss: 0.573659]
# [Epoch 302/1000] [Accuracy  : 0.749700]
# [Epoch 303/1000] [Train_Loss: 0.587412 /Valid_Loss: 0.579726]
# [Epoch 303/1000] [Accuracy  : 0.744650]
# [Epoch 304/1000] [Train_Loss: 0.582568 /Valid_Loss: 0.578498]
# [Epoch 304/1000] [Accuracy  : 0.747075]
# [Epoch 305/1000] [Train_Loss: 0.568523 /Valid_Loss: 0.578244]
# [Epoch 305/1000] [Accuracy  : 0.747450]
# [Epoch 306/1000] [Train_Loss: 0.576608 /Valid_Loss: 0.574654]
# [Epoch 306/1000] [Accuracy  : 0.748125]
# [Epoch 307/1000] [Train_Loss: 0.590019 /Valid_Loss: 0.574114]
# [Epoch 307/1000] [Accuracy  : 0.749513]
# [Epoch 308/1000] [Train_Loss: 0.603209 /Valid_Loss: 0.572267]
# [Epoch 308/1000] [Accuracy  : 0.751062]
# [Epoch 309/1000] [Train_Loss: 0.565300 /Valid_Loss: 0.579011]
# [Epoch 309/1000] [Accuracy  : 0.748038]
# [Epoch 310/1000] [Train_Loss: 0.561896 /Valid_Loss: 0.577262]
# [Epoch 310/1000] [Accuracy  : 0.748663]
# [Epoch 311/1000] [Train_Loss: 0.566039 /Valid_Loss: 0.572811]
# [Epoch 311/1000] [Accuracy  : 0.750162]
# [Epoch 312/1000] [Train_Loss: 0.584302 /Valid_Loss: 0.577973]
# [Epoch 312/1000] [Accuracy  : 0.747162]
# [Epoch 313/1000] [Train_Loss: 0.565644 /Valid_Loss: 0.576504]
# [Epoch 313/1000] [Accuracy  : 0.747062]
# [Epoch 314/1000] [Train_Loss: 0.564899 /Valid_Loss: 0.575760]
# [Epoch 314/1000] [Accuracy  : 0.747487]
# [Epoch 315/1000] [Train_Loss: 0.572313 /Valid_Loss: 0.576675]
# [Epoch 315/1000] [Accuracy  : 0.748637]
# [Epoch 316/1000] [Train_Loss: 0.574860 /Valid_Loss: 0.579715]
# [Epoch 316/1000] [Accuracy  : 0.749150]
# [Epoch 317/1000] [Train_Loss: 0.578037 /Valid_Loss: 0.578666]
# [Epoch 317/1000] [Accuracy  : 0.747663]
# [Epoch 318/1000] [Train_Loss: 0.587598 /Valid_Loss: 0.572716]
# [Epoch 318/1000] [Accuracy  : 0.752437]
# [Epoch 319/1000] [Train_Loss: 0.578662 /Valid_Loss: 0.573666]
# [Epoch 319/1000] [Accuracy  : 0.751337]
# [Epoch 320/1000] [Train_Loss: 0.587982 /Valid_Loss: 0.581703]
# [Epoch 320/1000] [Accuracy  : 0.746962]
# [Epoch 321/1000] [Train_Loss: 0.579757 /Valid_Loss: 0.576320]
# [Epoch 321/1000] [Accuracy  : 0.749975]
# [Epoch 322/1000] [Train_Loss: 0.569978 /Valid_Loss: 0.580374]
# [Epoch 322/1000] [Accuracy  : 0.745962]
# [Epoch 323/1000] [Train_Loss: 0.583014 /Valid_Loss: 0.580986]
# [Epoch 323/1000] [Accuracy  : 0.747287]
# [Epoch 324/1000] [Train_Loss: 0.566446 /Valid_Loss: 0.575458]
# [Epoch 324/1000] [Accuracy  : 0.748975]
# [Epoch 325/1000] [Train_Loss: 0.582193 /Valid_Loss: 0.579620]
# [Epoch 325/1000] [Accuracy  : 0.747038]
# [Epoch 326/1000] [Train_Loss: 0.596303 /Valid_Loss: 0.576988]
# [Epoch 326/1000] [Accuracy  : 0.749212]
# [Epoch 327/1000] [Train_Loss: 0.577105 /Valid_Loss: 0.575156]
# [Epoch 327/1000] [Accuracy  : 0.750450]
# [Epoch 328/1000] [Train_Loss: 0.563646 /Valid_Loss: 0.578381]
# [Epoch 328/1000] [Accuracy  : 0.744912]
# [Epoch 329/1000] [Train_Loss: 0.600836 /Valid_Loss: 0.576403]
# [Epoch 329/1000] [Accuracy  : 0.749150]
# [Epoch 330/1000] [Train_Loss: 0.581053 /Valid_Loss: 0.572690]
# [Epoch 330/1000] [Accuracy  : 0.750950]
# [Epoch 331/1000] [Train_Loss: 0.583901 /Valid_Loss: 0.573353]
# [Epoch 331/1000] [Accuracy  : 0.751000]
# [Epoch 332/1000] [Train_Loss: 0.568534 /Valid_Loss: 0.574160]
# [Epoch 332/1000] [Accuracy  : 0.750125]
# [Epoch 333/1000] [Train_Loss: 0.575474 /Valid_Loss: 0.572534]
# [Epoch 333/1000] [Accuracy  : 0.750825]
# [Epoch 334/1000] [Train_Loss: 0.578355 /Valid_Loss: 0.570506]
# [Epoch 334/1000] [Accuracy  : 0.750737]
# [Epoch 335/1000] [Train_Loss: 0.558663 /Valid_Loss: 0.583100]
# [Epoch 335/1000] [Accuracy  : 0.744050]
# [Epoch 336/1000] [Train_Loss: 0.577517 /Valid_Loss: 0.575850]
# [Epoch 336/1000] [Accuracy  : 0.748025]
# [Epoch 337/1000] [Train_Loss: 0.575768 /Valid_Loss: 0.573156]
# [Epoch 337/1000] [Accuracy  : 0.748750]
# [Epoch 338/1000] [Train_Loss: 0.594619 /Valid_Loss: 0.573758]
# [Epoch 338/1000] [Accuracy  : 0.750250]
# [Epoch 339/1000] [Train_Loss: 0.577003 /Valid_Loss: 0.571858]
# [Epoch 339/1000] [Accuracy  : 0.747400]
# [Epoch 340/1000] [Train_Loss: 0.578034 /Valid_Loss: 0.577335]
# [Epoch 340/1000] [Accuracy  : 0.748300]
# [Epoch 341/1000] [Train_Loss: 0.579486 /Valid_Loss: 0.574165]
# [Epoch 341/1000] [Accuracy  : 0.749800]
# [Epoch 342/1000] [Train_Loss: 0.573714 /Valid_Loss: 0.573610]
# [Epoch 342/1000] [Accuracy  : 0.750962]
# [Epoch 343/1000] [Train_Loss: 0.567060 /Valid_Loss: 0.575583]
# [Epoch 343/1000] [Accuracy  : 0.748162]
# [Epoch 344/1000] [Train_Loss: 0.563389 /Valid_Loss: 0.578389]
# [Epoch 344/1000] [Accuracy  : 0.745888]
# [Epoch 345/1000] [Train_Loss: 0.580394 /Valid_Loss: 0.575128]
# [Epoch 345/1000] [Accuracy  : 0.748413]
# [Epoch 346/1000] [Train_Loss: 0.579225 /Valid_Loss: 0.580086]
# [Epoch 346/1000] [Accuracy  : 0.744750]
# [Epoch 347/1000] [Train_Loss: 0.585027 /Valid_Loss: 0.578299]
# [Epoch 347/1000] [Accuracy  : 0.745700]
# [Epoch 348/1000] [Train_Loss: 0.574764 /Valid_Loss: 0.573547]
# [Epoch 348/1000] [Accuracy  : 0.748225]
# [Epoch 349/1000] [Train_Loss: 0.573367 /Valid_Loss: 0.577333]
# [Epoch 349/1000] [Accuracy  : 0.746687]
# [Epoch 350/1000] [Train_Loss: 0.583824 /Valid_Loss: 0.573751]
# [Epoch 350/1000] [Accuracy  : 0.751275]
# [Epoch 351/1000] [Train_Loss: 0.578659 /Valid_Loss: 0.574673]
# [Epoch 351/1000] [Accuracy  : 0.749263]
# [Epoch 352/1000] [Train_Loss: 0.559722 /Valid_Loss: 0.577617]
# [Epoch 352/1000] [Accuracy  : 0.747075]
# [Epoch 353/1000] [Train_Loss: 0.595568 /Valid_Loss: 0.574944]
# [Epoch 353/1000] [Accuracy  : 0.750212]
# [Epoch 354/1000] [Train_Loss: 0.571948 /Valid_Loss: 0.576942]
# [Epoch 354/1000] [Accuracy  : 0.748100]
# [Epoch 355/1000] [Train_Loss: 0.577160 /Valid_Loss: 0.580676]
# [Epoch 355/1000] [Accuracy  : 0.746938]
# [Epoch 356/1000] [Train_Loss: 0.573135 /Valid_Loss: 0.572683]
# [Epoch 356/1000] [Accuracy  : 0.750437]
# [Epoch 357/1000] [Train_Loss: 0.581429 /Valid_Loss: 0.573796]
# [Epoch 357/1000] [Accuracy  : 0.747112]
# [Epoch 358/1000] [Train_Loss: 0.576180 /Valid_Loss: 0.580927]
# [Epoch 358/1000] [Accuracy  : 0.745513]
# [Epoch 359/1000] [Train_Loss: 0.562588 /Valid_Loss: 0.572505]
# [Epoch 359/1000] [Accuracy  : 0.751162]
# [Epoch 360/1000] [Train_Loss: 0.554859 /Valid_Loss: 0.572074]
# [Epoch 360/1000] [Accuracy  : 0.751713]
# [Epoch 361/1000] [Train_Loss: 0.579212 /Valid_Loss: 0.569698]
# [Epoch 361/1000] [Accuracy  : 0.752313]
# [Epoch 362/1000] [Train_Loss: 0.585521 /Valid_Loss: 0.571546]
# [Epoch 362/1000] [Accuracy  : 0.751500]
# [Epoch 363/1000] [Train_Loss: 0.577947 /Valid_Loss: 0.584975]
# [Epoch 363/1000] [Accuracy  : 0.743825]
# [Epoch 364/1000] [Train_Loss: 0.566389 /Valid_Loss: 0.582822]
# [Epoch 364/1000] [Accuracy  : 0.746375]
# [Epoch 365/1000] [Train_Loss: 0.559104 /Valid_Loss: 0.572042]
# [Epoch 365/1000] [Accuracy  : 0.752375]
# [Epoch 366/1000] [Train_Loss: 0.571213 /Valid_Loss: 0.576021]
# [Epoch 366/1000] [Accuracy  : 0.750350]
# [Epoch 367/1000] [Train_Loss: 0.581114 /Valid_Loss: 0.574079]
# [Epoch 367/1000] [Accuracy  : 0.748750]
# [Epoch 368/1000] [Train_Loss: 0.575707 /Valid_Loss: 0.575562]
# [Epoch 368/1000] [Accuracy  : 0.749437]
# [Epoch 369/1000] [Train_Loss: 0.584828 /Valid_Loss: 0.572925]
# [Epoch 369/1000] [Accuracy  : 0.750263]
# This is time to do early stopping
# 모델 저장: /content/gdrive/My Drive/Colab Notebooks/kamp/14. Dataset_Rotor/cnn_model.pt

# %% [markdown]
# ### 4-3. 순환신경망 (RNN) 모델 학습

# %%
# pytorch version : 1.9.0 (버전에 따라 아래 코드가 실행되지 않을 수 있으니 requirement.txt의 버전대로 설치해주세요)

RNN_model = KAMP_RNN()
num_epochs = 1000
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(RNN_model.parameters())
PATH = dir+'rnn_'

RNN_loss_values, RNN_loss_values_v = train_model(RNN_model, criterion, optimizer, num_epochs, train_dataloader, PATH)
# Out:
# [Epoch 1/1000] [Train_Loss: 1.386286 /Valid_Loss: 1.386296]
# [Epoch 1/1000] [Accuracy  : 0.250000]
# [Epoch 2/1000] [Train_Loss: 1.386283 /Valid_Loss: 1.386285]
# [Epoch 2/1000] [Accuracy  : 0.181188]
# [Epoch 3/1000] [Train_Loss: 1.385626 /Valid_Loss: 1.385616]
# [Epoch 3/1000] [Accuracy  : 0.254638]
# [Epoch 4/1000] [Train_Loss: 1.354522 /Valid_Loss: 1.350937]
# [Epoch 4/1000] [Accuracy  : 0.340250]
# [Epoch 5/1000] [Train_Loss: 1.101304 /Valid_Loss: 1.090884]
# [Epoch 5/1000] [Accuracy  : 0.435663]
# [Epoch 6/1000] [Train_Loss: 1.094972 /Valid_Loss: 1.086760]
# [Epoch 6/1000] [Accuracy  : 0.458225]
# [Epoch 7/1000] [Train_Loss: 1.082522 /Valid_Loss: 1.083255]
# [Epoch 7/1000] [Accuracy  : 0.448937]
# [Epoch 8/1000] [Train_Loss: 1.088694 /Valid_Loss: 1.080781]
# [Epoch 8/1000] [Accuracy  : 0.448462]
# [Epoch 9/1000] [Train_Loss: 1.091583 /Valid_Loss: 1.078531]
# [Epoch 9/1000] [Accuracy  : 0.435025]
# [Epoch 10/1000] [Train_Loss: 1.082412 /Valid_Loss: 1.076624]
# [Epoch 10/1000] [Accuracy  : 0.461012]
# [Epoch 11/1000] [Train_Loss: 1.083443 /Valid_Loss: 1.073031]
# [Epoch 11/1000] [Accuracy  : 0.455238]
# [Epoch 12/1000] [Train_Loss: 1.077560 /Valid_Loss: 1.069298]
# [Epoch 12/1000] [Accuracy  : 0.457700]
# [Epoch 13/1000] [Train_Loss: 1.069799 /Valid_Loss: 1.063424]
# [Epoch 13/1000] [Accuracy  : 0.450387]
# [Epoch 14/1000] [Train_Loss: 1.059820 /Valid_Loss: 1.053931]
# [Epoch 14/1000] [Accuracy  : 0.469900]
# [Epoch 15/1000] [Train_Loss: 1.050209 /Valid_Loss: 1.038547]
# [Epoch 15/1000] [Accuracy  : 0.487013]
# [Epoch 16/1000] [Train_Loss: 1.017868 /Valid_Loss: 1.009051]
# [Epoch 16/1000] [Accuracy  : 0.478950]
# [Epoch 17/1000] [Train_Loss: 0.986617 /Valid_Loss: 0.950741]
# [Epoch 17/1000] [Accuracy  : 0.517737]
# [Epoch 18/1000] [Train_Loss: 0.895552 /Valid_Loss: 0.868058]
# [Epoch 18/1000] [Accuracy  : 0.536100]
# [Epoch 19/1000] [Train_Loss: 0.858046 /Valid_Loss: 0.839604]
# [Epoch 19/1000] [Accuracy  : 0.541950]
# [Epoch 20/1000] [Train_Loss: 0.851634 /Valid_Loss: 0.833098]
# [Epoch 20/1000] [Accuracy  : 0.548350]
# [Epoch 21/1000] [Train_Loss: 0.840844 /Valid_Loss: 0.828127]
# [Epoch 21/1000] [Accuracy  : 0.538875]
# [Epoch 22/1000] [Train_Loss: 0.847913 /Valid_Loss: 0.825185]
# [Epoch 22/1000] [Accuracy  : 0.552713]
# [Epoch 23/1000] [Train_Loss: 0.846221 /Valid_Loss: 0.820809]
# [Epoch 23/1000] [Accuracy  : 0.550937]
# [Epoch 24/1000] [Train_Loss: 0.843734 /Valid_Loss: 0.818793]
# [Epoch 24/1000] [Accuracy  : 0.555975]
# [Epoch 25/1000] [Train_Loss: 0.815370 /Valid_Loss: 0.816484]
# [Epoch 25/1000] [Accuracy  : 0.560763]
# [Epoch 26/1000] [Train_Loss: 0.823363 /Valid_Loss: 0.811252]
# [Epoch 26/1000] [Accuracy  : 0.562488]
# [Epoch 27/1000] [Train_Loss: 0.845057 /Valid_Loss: 0.809860]
# [Epoch 27/1000] [Accuracy  : 0.559187]
# [Epoch 28/1000] [Train_Loss: 0.831600 /Valid_Loss: 0.806255]
# [Epoch 28/1000] [Accuracy  : 0.566825]
# [Epoch 29/1000] [Train_Loss: 0.838008 /Valid_Loss: 0.802280]
# [Epoch 29/1000] [Accuracy  : 0.566562]
# [Epoch 30/1000] [Train_Loss: 0.822287 /Valid_Loss: 0.801006]
# [Epoch 30/1000] [Accuracy  : 0.578025]
# [Epoch 31/1000] [Train_Loss: 0.832790 /Valid_Loss: 0.797303]
# [Epoch 31/1000] [Accuracy  : 0.578987]
# [Epoch 32/1000] [Train_Loss: 0.818372 /Valid_Loss: 0.796301]
# [Epoch 32/1000] [Accuracy  : 0.584250]
# [Epoch 33/1000] [Train_Loss: 0.814699 /Valid_Loss: 0.793741]
# [Epoch 33/1000] [Accuracy  : 0.584363]
# [Epoch 34/1000] [Train_Loss: 0.824342 /Valid_Loss: 0.788889]
# [Epoch 34/1000] [Accuracy  : 0.585488]
# [Epoch 35/1000] [Train_Loss: 0.815586 /Valid_Loss: 0.787781]
# [Epoch 35/1000] [Accuracy  : 0.596838]
# [Epoch 36/1000] [Train_Loss: 0.803093 /Valid_Loss: 0.784976]
# [Epoch 36/1000] [Accuracy  : 0.591150]
# [Epoch 37/1000] [Train_Loss: 0.806220 /Valid_Loss: 0.784438]
# [Epoch 37/1000] [Accuracy  : 0.597050]
# [Epoch 38/1000] [Train_Loss: 0.807510 /Valid_Loss: 0.779031]
# [Epoch 38/1000] [Accuracy  : 0.597450]
# [Epoch 39/1000] [Train_Loss: 0.800690 /Valid_Loss: 0.775824]
# [Epoch 39/1000] [Accuracy  : 0.597550]
# [Epoch 40/1000] [Train_Loss: 0.803323 /Valid_Loss: 0.774714]
# [Epoch 40/1000] [Accuracy  : 0.599025]
# [Epoch 41/1000] [Train_Loss: 0.795174 /Valid_Loss: 0.774737]
# [Epoch 41/1000] [Accuracy  : 0.608112]
# [Epoch 42/1000] [Train_Loss: 0.781987 /Valid_Loss: 0.770972]
# [Epoch 42/1000] [Accuracy  : 0.613000]
# [Epoch 43/1000] [Train_Loss: 0.789919 /Valid_Loss: 0.772378]
# [Epoch 43/1000] [Accuracy  : 0.613487]
# [Epoch 44/1000] [Train_Loss: 0.796210 /Valid_Loss: 0.767756]
# [Epoch 44/1000] [Accuracy  : 0.615387]
# [Epoch 45/1000] [Train_Loss: 0.787171 /Valid_Loss: 0.766062]
# [Epoch 45/1000] [Accuracy  : 0.615337]
# [Epoch 46/1000] [Train_Loss: 0.796022 /Valid_Loss: 0.766373]
# [Epoch 46/1000] [Accuracy  : 0.619275]
# [Epoch 47/1000] [Train_Loss: 0.789856 /Valid_Loss: 0.764315]
# [Epoch 47/1000] [Accuracy  : 0.617463]
# [Epoch 48/1000] [Train_Loss: 0.792825 /Valid_Loss: 0.762329]
# [Epoch 48/1000] [Accuracy  : 0.618775]
# [Epoch 49/1000] [Train_Loss: 0.766698 /Valid_Loss: 0.761264]
# [Epoch 49/1000] [Accuracy  : 0.617962]
# [Epoch 50/1000] [Train_Loss: 0.787885 /Valid_Loss: 0.760917]
# [Epoch 50/1000] [Accuracy  : 0.615038]
# [Epoch 51/1000] [Train_Loss: 0.786420 /Valid_Loss: 0.763469]
# [Epoch 51/1000] [Accuracy  : 0.619537]
# [Epoch 52/1000] [Train_Loss: 0.772813 /Valid_Loss: 0.761426]
# [Epoch 52/1000] [Accuracy  : 0.619575]
# [Epoch 53/1000] [Train_Loss: 0.770511 /Valid_Loss: 0.758355]
# [Epoch 53/1000] [Accuracy  : 0.623700]
# [Epoch 54/1000] [Train_Loss: 0.771655 /Valid_Loss: 0.760161]
# [Epoch 54/1000] [Accuracy  : 0.620625]
# [Epoch 55/1000] [Train_Loss: 0.786490 /Valid_Loss: 0.760511]
# [Epoch 55/1000] [Accuracy  : 0.622800]
# [Epoch 56/1000] [Train_Loss: 0.762981 /Valid_Loss: 0.760033]
# [Epoch 56/1000] [Accuracy  : 0.616750]
# [Epoch 57/1000] [Train_Loss: 0.769989 /Valid_Loss: 0.758282]
# [Epoch 57/1000] [Accuracy  : 0.623200]
# [Epoch 58/1000] [Train_Loss: 0.764709 /Valid_Loss: 0.756452]
# [Epoch 58/1000] [Accuracy  : 0.621200]
# [Epoch 59/1000] [Train_Loss: 0.786839 /Valid_Loss: 0.756994]
# [Epoch 59/1000] [Accuracy  : 0.624613]
# [Epoch 60/1000] [Train_Loss: 0.778527 /Valid_Loss: 0.756588]
# [Epoch 60/1000] [Accuracy  : 0.617213]
# [Epoch 61/1000] [Train_Loss: 0.755462 /Valid_Loss: 0.755334]
# [Epoch 61/1000] [Accuracy  : 0.621088]
# [Epoch 62/1000] [Train_Loss: 0.755625 /Valid_Loss: 0.756019]
# [Epoch 62/1000] [Accuracy  : 0.619712]
# [Epoch 63/1000] [Train_Loss: 0.767961 /Valid_Loss: 0.753007]
# [Epoch 63/1000] [Accuracy  : 0.619150]
# [Epoch 64/1000] [Train_Loss: 0.766894 /Valid_Loss: 0.754485]
# [Epoch 64/1000] [Accuracy  : 0.620800]
# [Epoch 65/1000] [Train_Loss: 0.757015 /Valid_Loss: 0.751747]
# [Epoch 65/1000] [Accuracy  : 0.624875]
# [Epoch 66/1000] [Train_Loss: 0.760496 /Valid_Loss: 0.753200]
# [Epoch 66/1000] [Accuracy  : 0.622450]
# [Epoch 67/1000] [Train_Loss: 0.757271 /Valid_Loss: 0.754590]
# [Epoch 67/1000] [Accuracy  : 0.622812]
# [Epoch 68/1000] [Train_Loss: 0.753051 /Valid_Loss: 0.754467]
# [Epoch 68/1000] [Accuracy  : 0.618513]
# [Epoch 69/1000] [Train_Loss: 0.769974 /Valid_Loss: 0.751777]
# [Epoch 69/1000] [Accuracy  : 0.617263]
# [Epoch 70/1000] [Train_Loss: 0.750925 /Valid_Loss: 0.753728]
# [Epoch 70/1000] [Accuracy  : 0.621463]
# [Epoch 71/1000] [Train_Loss: 0.762234 /Valid_Loss: 0.751059]
# [Epoch 71/1000] [Accuracy  : 0.617025]
# [Epoch 72/1000] [Train_Loss: 0.762364 /Valid_Loss: 0.749674]
# [Epoch 72/1000] [Accuracy  : 0.619275]
# [Epoch 73/1000] [Train_Loss: 0.755043 /Valid_Loss: 0.751985]
# [Epoch 73/1000] [Accuracy  : 0.622050]
# [Epoch 74/1000] [Train_Loss: 0.755989 /Valid_Loss: 0.750546]
# [Epoch 74/1000] [Accuracy  : 0.618825]
# [Epoch 75/1000] [Train_Loss: 0.757715 /Valid_Loss: 0.751172]
# [Epoch 75/1000] [Accuracy  : 0.618138]
# [Epoch 76/1000] [Train_Loss: 0.753747 /Valid_Loss: 0.751698]
# [Epoch 76/1000] [Accuracy  : 0.623663]
# [Epoch 77/1000] [Train_Loss: 0.754281 /Valid_Loss: 0.749048]
# [Epoch 77/1000] [Accuracy  : 0.616263]
# [Epoch 78/1000] [Train_Loss: 0.756363 /Valid_Loss: 0.748530]
# [Epoch 78/1000] [Accuracy  : 0.621888]
# [Epoch 79/1000] [Train_Loss: 0.733725 /Valid_Loss: 0.748849]
# [Epoch 79/1000] [Accuracy  : 0.618788]
# [Epoch 80/1000] [Train_Loss: 0.760685 /Valid_Loss: 0.746730]
# [Epoch 80/1000] [Accuracy  : 0.621387]
# [Epoch 81/1000] [Train_Loss: 0.755283 /Valid_Loss: 0.745465]
# [Epoch 81/1000] [Accuracy  : 0.620500]
# [Epoch 82/1000] [Train_Loss: 0.735434 /Valid_Loss: 0.749115]
# [Epoch 82/1000] [Accuracy  : 0.625188]
# [Epoch 83/1000] [Train_Loss: 0.735955 /Valid_Loss: 0.745952]
# [Epoch 83/1000] [Accuracy  : 0.622812]
# [Epoch 84/1000] [Train_Loss: 0.757884 /Valid_Loss: 0.745581]
# [Epoch 84/1000] [Accuracy  : 0.623675]
# [Epoch 85/1000] [Train_Loss: 0.752745 /Valid_Loss: 0.743416]
# [Epoch 85/1000] [Accuracy  : 0.621112]
# [Epoch 86/1000] [Train_Loss: 0.748642 /Valid_Loss: 0.744674]
# [Epoch 86/1000] [Accuracy  : 0.624487]
# [Epoch 87/1000] [Train_Loss: 0.744323 /Valid_Loss: 0.744391]
# [Epoch 87/1000] [Accuracy  : 0.617775]
# [Epoch 88/1000] [Train_Loss: 0.740056 /Valid_Loss: 0.743795]
# [Epoch 88/1000] [Accuracy  : 0.619275]
# [Epoch 89/1000] [Train_Loss: 0.752850 /Valid_Loss: 0.744731]
# [Epoch 89/1000] [Accuracy  : 0.622263]
# [Epoch 90/1000] [Train_Loss: 0.741172 /Valid_Loss: 0.744019]
# [Epoch 90/1000] [Accuracy  : 0.625025]
# [Epoch 91/1000] [Train_Loss: 0.725485 /Valid_Loss: 0.744616]
# [Epoch 91/1000] [Accuracy  : 0.632950]
# [Epoch 92/1000] [Train_Loss: 0.740782 /Valid_Loss: 0.740716]
# [Epoch 92/1000] [Accuracy  : 0.635513]
# [Epoch 93/1000] [Train_Loss: 0.729112 /Valid_Loss: 0.735904]
# [Epoch 93/1000] [Accuracy  : 0.637188]
# [Epoch 94/1000] [Train_Loss: 0.730400 /Valid_Loss: 0.733727]
# [Epoch 94/1000] [Accuracy  : 0.642950]
# [Epoch 95/1000] [Train_Loss: 0.724573 /Valid_Loss: 0.729165]
# [Epoch 95/1000] [Accuracy  : 0.648813]
# [Epoch 96/1000] [Train_Loss: 0.718744 /Valid_Loss: 0.723601]
# [Epoch 96/1000] [Accuracy  : 0.656438]
# [Epoch 97/1000] [Train_Loss: 0.720244 /Valid_Loss: 0.719121]
# [Epoch 97/1000] [Accuracy  : 0.667100]
# [Epoch 98/1000] [Train_Loss: 0.714279 /Valid_Loss: 0.710753]
# [Epoch 98/1000] [Accuracy  : 0.669963]
# [Epoch 99/1000] [Train_Loss: 0.705795 /Valid_Loss: 0.698716]
# [Epoch 99/1000] [Accuracy  : 0.677713]
# [Epoch 100/1000] [Train_Loss: 0.694226 /Valid_Loss: 0.688338]
# [Epoch 100/1000] [Accuracy  : 0.684288]
# [Epoch 101/1000] [Train_Loss: 0.677198 /Valid_Loss: 0.680400]
# [Epoch 101/1000] [Accuracy  : 0.686475]
# [Epoch 102/1000] [Train_Loss: 0.681346 /Valid_Loss: 0.674083]
# [Epoch 102/1000] [Accuracy  : 0.688612]
# [Epoch 103/1000] [Train_Loss: 0.658097 /Valid_Loss: 0.671091]
# [Epoch 103/1000] [Accuracy  : 0.685737]
# [Epoch 104/1000] [Train_Loss: 0.658548 /Valid_Loss: 0.665109]
# [Epoch 104/1000] [Accuracy  : 0.691512]
# [Epoch 105/1000] [Train_Loss: 0.648119 /Valid_Loss: 0.660555]
# [Epoch 105/1000] [Accuracy  : 0.696388]
# [Epoch 106/1000] [Train_Loss: 0.647230 /Valid_Loss: 0.657202]
# [Epoch 106/1000] [Accuracy  : 0.696887]
# [Epoch 107/1000] [Train_Loss: 0.644031 /Valid_Loss: 0.654340]
# [Epoch 107/1000] [Accuracy  : 0.697388]
# [Epoch 108/1000] [Train_Loss: 0.650490 /Valid_Loss: 0.652773]
# [Epoch 108/1000] [Accuracy  : 0.699213]
# [Epoch 109/1000] [Train_Loss: 0.630940 /Valid_Loss: 0.654747]
# [Epoch 109/1000] [Accuracy  : 0.693362]
# [Epoch 110/1000] [Train_Loss: 0.633682 /Valid_Loss: 0.649890]
# [Epoch 110/1000] [Accuracy  : 0.698125]
# [Epoch 111/1000] [Train_Loss: 0.644498 /Valid_Loss: 0.652494]
# [Epoch 111/1000] [Accuracy  : 0.696975]
# [Epoch 112/1000] [Train_Loss: 0.647685 /Valid_Loss: 0.651600]
# [Epoch 112/1000] [Accuracy  : 0.696700]
# [Epoch 113/1000] [Train_Loss: 0.631738 /Valid_Loss: 0.649188]
# [Epoch 113/1000] [Accuracy  : 0.699388]
# [Epoch 114/1000] [Train_Loss: 0.620167 /Valid_Loss: 0.644735]
# [Epoch 114/1000] [Accuracy  : 0.699350]
# [Epoch 115/1000] [Train_Loss: 0.628740 /Valid_Loss: 0.647329]
# [Epoch 115/1000] [Accuracy  : 0.697300]
# [Epoch 116/1000] [Train_Loss: 0.619031 /Valid_Loss: 0.647405]
# [Epoch 116/1000] [Accuracy  : 0.696225]
# [Epoch 117/1000] [Train_Loss: 0.616979 /Valid_Loss: 0.646595]
# [Epoch 117/1000] [Accuracy  : 0.699963]
# [Epoch 118/1000] [Train_Loss: 0.634234 /Valid_Loss: 0.645310]
# [Epoch 118/1000] [Accuracy  : 0.701550]
# [Epoch 119/1000] [Train_Loss: 0.618927 /Valid_Loss: 0.640397]
# [Epoch 119/1000] [Accuracy  : 0.700538]
# [Epoch 120/1000] [Train_Loss: 0.627786 /Valid_Loss: 0.638861]
# [Epoch 120/1000] [Accuracy  : 0.703688]
# [Epoch 121/1000] [Train_Loss: 0.630978 /Valid_Loss: 0.642034]
# [Epoch 121/1000] [Accuracy  : 0.702187]
# [Epoch 122/1000] [Train_Loss: 0.624001 /Valid_Loss: 0.640554]
# [Epoch 122/1000] [Accuracy  : 0.702538]
# [Epoch 123/1000] [Train_Loss: 0.624487 /Valid_Loss: 0.635286]
# [Epoch 123/1000] [Accuracy  : 0.706025]
# [Epoch 124/1000] [Train_Loss: 0.611068 /Valid_Loss: 0.637276]
# [Epoch 124/1000] [Accuracy  : 0.705488]
# [Epoch 125/1000] [Train_Loss: 0.601932 /Valid_Loss: 0.636385]
# [Epoch 125/1000] [Accuracy  : 0.705250]
# [Epoch 126/1000] [Train_Loss: 0.631479 /Valid_Loss: 0.634756]
# [Epoch 126/1000] [Accuracy  : 0.706412]
# [Epoch 127/1000] [Train_Loss: 0.623053 /Valid_Loss: 0.633128]
# [Epoch 127/1000] [Accuracy  : 0.707488]
# [Epoch 128/1000] [Train_Loss: 0.620526 /Valid_Loss: 0.632776]
# [Epoch 128/1000] [Accuracy  : 0.707725]
# [Epoch 129/1000] [Train_Loss: 0.598982 /Valid_Loss: 0.630604]
# [Epoch 129/1000] [Accuracy  : 0.710750]
# [Epoch 130/1000] [Train_Loss: 0.599292 /Valid_Loss: 0.630541]
# [Epoch 130/1000] [Accuracy  : 0.709987]
# [Epoch 131/1000] [Train_Loss: 0.607241 /Valid_Loss: 0.629751]
# [Epoch 131/1000] [Accuracy  : 0.708762]
# [Epoch 132/1000] [Train_Loss: 0.596091 /Valid_Loss: 0.629803]
# [Epoch 132/1000] [Accuracy  : 0.708013]
# [Epoch 133/1000] [Train_Loss: 0.595476 /Valid_Loss: 0.625173]
# [Epoch 133/1000] [Accuracy  : 0.712313]
# [Epoch 134/1000] [Train_Loss: 0.608019 /Valid_Loss: 0.625953]
# [Epoch 134/1000] [Accuracy  : 0.712688]
# [Epoch 135/1000] [Train_Loss: 0.601510 /Valid_Loss: 0.625910]
# [Epoch 135/1000] [Accuracy  : 0.712263]
# [Epoch 136/1000] [Train_Loss: 0.602499 /Valid_Loss: 0.624579]
# [Epoch 136/1000] [Accuracy  : 0.713550]
# [Epoch 137/1000] [Train_Loss: 0.611725 /Valid_Loss: 0.622529]
# [Epoch 137/1000] [Accuracy  : 0.714263]
# [Epoch 138/1000] [Train_Loss: 0.580305 /Valid_Loss: 0.620389]
# [Epoch 138/1000] [Accuracy  : 0.713975]
# [Epoch 139/1000] [Train_Loss: 0.604560 /Valid_Loss: 0.621847]
# [Epoch 139/1000] [Accuracy  : 0.715325]
# [Epoch 140/1000] [Train_Loss: 0.596457 /Valid_Loss: 0.618680]
# [Epoch 140/1000] [Accuracy  : 0.717063]
# [Epoch 141/1000] [Train_Loss: 0.598677 /Valid_Loss: 0.617808]
# [Epoch 141/1000] [Accuracy  : 0.718125]
# [Epoch 142/1000] [Train_Loss: 0.607488 /Valid_Loss: 0.615087]
# [Epoch 142/1000] [Accuracy  : 0.719113]
# [Epoch 143/1000] [Train_Loss: 0.581834 /Valid_Loss: 0.616563]
# [Epoch 143/1000] [Accuracy  : 0.719275]
# [Epoch 144/1000] [Train_Loss: 0.573301 /Valid_Loss: 0.616624]
# [Epoch 144/1000] [Accuracy  : 0.719700]
# [Epoch 145/1000] [Train_Loss: 0.576500 /Valid_Loss: 0.613497]
# [Epoch 145/1000] [Accuracy  : 0.721487]
# [Epoch 146/1000] [Train_Loss: 0.586683 /Valid_Loss: 0.615102]
# [Epoch 146/1000] [Accuracy  : 0.721375]
# [Epoch 147/1000] [Train_Loss: 0.581292 /Valid_Loss: 0.610390]
# [Epoch 147/1000] [Accuracy  : 0.724500]
# [Epoch 148/1000] [Train_Loss: 0.578249 /Valid_Loss: 0.611414]
# [Epoch 148/1000] [Accuracy  : 0.724050]
# [Epoch 149/1000] [Train_Loss: 0.589270 /Valid_Loss: 0.609582]
# [Epoch 149/1000] [Accuracy  : 0.724850]
# [Epoch 150/1000] [Train_Loss: 0.582209 /Valid_Loss: 0.613217]
# [Epoch 150/1000] [Accuracy  : 0.723662]
# [Epoch 151/1000] [Train_Loss: 0.574542 /Valid_Loss: 0.607820]
# [Epoch 151/1000] [Accuracy  : 0.725712]
# [Epoch 152/1000] [Train_Loss: 0.577836 /Valid_Loss: 0.609609]
# [Epoch 152/1000] [Accuracy  : 0.724838]
# [Epoch 153/1000] [Train_Loss: 0.574798 /Valid_Loss: 0.609218]
# [Epoch 153/1000] [Accuracy  : 0.725838]
# [Epoch 154/1000] [Train_Loss: 0.573663 /Valid_Loss: 0.608606]
# [Epoch 154/1000] [Accuracy  : 0.725125]
# [Epoch 155/1000] [Train_Loss: 0.573369 /Valid_Loss: 0.607438]
# [Epoch 155/1000] [Accuracy  : 0.725950]
# [Epoch 156/1000] [Train_Loss: 0.561148 /Valid_Loss: 0.607934]
# [Epoch 156/1000] [Accuracy  : 0.728287]
# [Epoch 157/1000] [Train_Loss: 0.580232 /Valid_Loss: 0.607125]
# [Epoch 157/1000] [Accuracy  : 0.726750]
# [Epoch 158/1000] [Train_Loss: 0.570869 /Valid_Loss: 0.604856]
# [Epoch 158/1000] [Accuracy  : 0.728200]
# [Epoch 159/1000] [Train_Loss: 0.574289 /Valid_Loss: 0.602882]
# [Epoch 159/1000] [Accuracy  : 0.729612]
# [Epoch 160/1000] [Train_Loss: 0.563610 /Valid_Loss: 0.602691]
# [Epoch 160/1000] [Accuracy  : 0.730513]
# [Epoch 161/1000] [Train_Loss: 0.561938 /Valid_Loss: 0.605511]
# [Epoch 161/1000] [Accuracy  : 0.728712]
# [Epoch 162/1000] [Train_Loss: 0.573911 /Valid_Loss: 0.600620]
# [Epoch 162/1000] [Accuracy  : 0.731300]
# [Epoch 163/1000] [Train_Loss: 0.575154 /Valid_Loss: 0.598731]
# [Epoch 163/1000] [Accuracy  : 0.732537]
# [Epoch 164/1000] [Train_Loss: 0.579796 /Valid_Loss: 0.601905]
# [Epoch 164/1000] [Accuracy  : 0.730175]
# [Epoch 165/1000] [Train_Loss: 0.567485 /Valid_Loss: 0.599310]
# [Epoch 165/1000] [Accuracy  : 0.731888]
# [Epoch 166/1000] [Train_Loss: 0.566678 /Valid_Loss: 0.603226]
# [Epoch 166/1000] [Accuracy  : 0.729762]
# [Epoch 167/1000] [Train_Loss: 0.558208 /Valid_Loss: 0.598135]
# [Epoch 167/1000] [Accuracy  : 0.732400]
# [Epoch 168/1000] [Train_Loss: 0.563720 /Valid_Loss: 0.597719]
# [Epoch 168/1000] [Accuracy  : 0.732612]
# [Epoch 169/1000] [Train_Loss: 0.563552 /Valid_Loss: 0.597664]
# [Epoch 169/1000] [Accuracy  : 0.732187]
# [Epoch 170/1000] [Train_Loss: 0.557826 /Valid_Loss: 0.595884]
# [Epoch 170/1000] [Accuracy  : 0.733975]
# [Epoch 171/1000] [Train_Loss: 0.578818 /Valid_Loss: 0.596728]
# [Epoch 171/1000] [Accuracy  : 0.734187]
# [Epoch 172/1000] [Train_Loss: 0.554699 /Valid_Loss: 0.596591]
# [Epoch 172/1000] [Accuracy  : 0.732525]
# [Epoch 173/1000] [Train_Loss: 0.551133 /Valid_Loss: 0.597752]
# [Epoch 173/1000] [Accuracy  : 0.734050]
# [Epoch 174/1000] [Train_Loss: 0.550288 /Valid_Loss: 0.592182]
# [Epoch 174/1000] [Accuracy  : 0.737150]
# [Epoch 175/1000] [Train_Loss: 0.556598 /Valid_Loss: 0.595454]
# [Epoch 175/1000] [Accuracy  : 0.733675]
# [Epoch 176/1000] [Train_Loss: 0.561997 /Valid_Loss: 0.594222]
# [Epoch 176/1000] [Accuracy  : 0.734563]
# [Epoch 177/1000] [Train_Loss: 0.555707 /Valid_Loss: 0.594787]
# [Epoch 177/1000] [Accuracy  : 0.734012]
# [Epoch 178/1000] [Train_Loss: 0.542099 /Valid_Loss: 0.595377]
# [Epoch 178/1000] [Accuracy  : 0.734137]
# [Epoch 179/1000] [Train_Loss: 0.545327 /Valid_Loss: 0.595447]
# [Epoch 179/1000] [Accuracy  : 0.735062]
# [Epoch 180/1000] [Train_Loss: 0.551559 /Valid_Loss: 0.593406]
# [Epoch 180/1000] [Accuracy  : 0.736225]
# [Epoch 181/1000] [Train_Loss: 0.563145 /Valid_Loss: 0.593111]
# [Epoch 181/1000] [Accuracy  : 0.736525]
# [Epoch 182/1000] [Train_Loss: 0.550671 /Valid_Loss: 0.594290]
# [Epoch 182/1000] [Accuracy  : 0.734125]
# [Epoch 183/1000] [Train_Loss: 0.552263 /Valid_Loss: 0.593427]
# [Epoch 183/1000] [Accuracy  : 0.736838]
# [Epoch 184/1000] [Train_Loss: 0.573661 /Valid_Loss: 0.593437]
# [Epoch 184/1000] [Accuracy  : 0.735788]
# [Epoch 185/1000] [Train_Loss: 0.543340 /Valid_Loss: 0.593472]
# [Epoch 185/1000] [Accuracy  : 0.735688]
# [Epoch 186/1000] [Train_Loss: 0.558109 /Valid_Loss: 0.596583]
# [Epoch 186/1000] [Accuracy  : 0.733513]
# [Epoch 187/1000] [Train_Loss: 0.557946 /Valid_Loss: 0.592857]
# [Epoch 187/1000] [Accuracy  : 0.736387]
# [Epoch 188/1000] [Train_Loss: 0.556144 /Valid_Loss: 0.592199]
# [Epoch 188/1000] [Accuracy  : 0.737912]
# [Epoch 189/1000] [Train_Loss: 0.568982 /Valid_Loss: 0.593984]
# [Epoch 189/1000] [Accuracy  : 0.735962]
# [Epoch 190/1000] [Train_Loss: 0.561853 /Valid_Loss: 0.591550]
# [Epoch 190/1000] [Accuracy  : 0.736375]
# [Epoch 191/1000] [Train_Loss: 0.531252 /Valid_Loss: 0.594123]
# [Epoch 191/1000] [Accuracy  : 0.735650]
# [Epoch 192/1000] [Train_Loss: 0.567870 /Valid_Loss: 0.590370]
# [Epoch 192/1000] [Accuracy  : 0.738125]
# [Epoch 193/1000] [Train_Loss: 0.563231 /Valid_Loss: 0.590799]
# [Epoch 193/1000] [Accuracy  : 0.737163]
# [Epoch 194/1000] [Train_Loss: 0.542095 /Valid_Loss: 0.593454]
# [Epoch 194/1000] [Accuracy  : 0.737175]
# [Epoch 195/1000] [Train_Loss: 0.545110 /Valid_Loss: 0.589680]
# [Epoch 195/1000] [Accuracy  : 0.739125]
# [Epoch 196/1000] [Train_Loss: 0.552320 /Valid_Loss: 0.592611]
# [Epoch 196/1000] [Accuracy  : 0.739675]
# [Epoch 197/1000] [Train_Loss: 0.572735 /Valid_Loss: 0.593004]
# [Epoch 197/1000] [Accuracy  : 0.736812]
# [Epoch 198/1000] [Train_Loss: 0.535148 /Valid_Loss: 0.588264]
# [Epoch 198/1000] [Accuracy  : 0.740613]
# [Epoch 199/1000] [Train_Loss: 0.558817 /Valid_Loss: 0.587250]
# [Epoch 199/1000] [Accuracy  : 0.740575]
# [Epoch 200/1000] [Train_Loss: 0.562814 /Valid_Loss: 0.588625]
# [Epoch 200/1000] [Accuracy  : 0.738625]
# [Epoch 201/1000] [Train_Loss: 0.542404 /Valid_Loss: 0.586998]
# [Epoch 201/1000] [Accuracy  : 0.741525]
# [Epoch 202/1000] [Train_Loss: 0.554774 /Valid_Loss: 0.596076]
# [Epoch 202/1000] [Accuracy  : 0.733600]
# [Epoch 203/1000] [Train_Loss: 0.545983 /Valid_Loss: 0.590653]
# [Epoch 203/1000] [Accuracy  : 0.738825]
# [Epoch 204/1000] [Train_Loss: 0.536916 /Valid_Loss: 0.587391]
# [Epoch 204/1000] [Accuracy  : 0.741575]
# [Epoch 205/1000] [Train_Loss: 0.565602 /Valid_Loss: 0.588594]
# [Epoch 205/1000] [Accuracy  : 0.740400]
# [Epoch 206/1000] [Train_Loss: 0.533850 /Valid_Loss: 0.590927]
# [Epoch 206/1000] [Accuracy  : 0.737912]
# [Epoch 207/1000] [Train_Loss: 0.547444 /Valid_Loss: 0.590350]
# [Epoch 207/1000] [Accuracy  : 0.738112]
# [Epoch 208/1000] [Train_Loss: 0.532352 /Valid_Loss: 0.588111]
# [Epoch 208/1000] [Accuracy  : 0.741075]
# [Epoch 209/1000] [Train_Loss: 0.554919 /Valid_Loss: 0.588845]
# [Epoch 209/1000] [Accuracy  : 0.739112]
# [Epoch 210/1000] [Train_Loss: 0.547328 /Valid_Loss: 0.588313]
# [Epoch 210/1000] [Accuracy  : 0.741200]
# [Epoch 211/1000] [Train_Loss: 0.527310 /Valid_Loss: 0.588998]
# [Epoch 211/1000] [Accuracy  : 0.740812]
# [Epoch 212/1000] [Train_Loss: 0.538417 /Valid_Loss: 0.589435]
# [Epoch 212/1000] [Accuracy  : 0.738613]
# [Epoch 213/1000] [Train_Loss: 0.537585 /Valid_Loss: 0.585898]
# [Epoch 213/1000] [Accuracy  : 0.742400]
# [Epoch 214/1000] [Train_Loss: 0.544873 /Valid_Loss: 0.587415]
# [Epoch 214/1000] [Accuracy  : 0.741550]
# [Epoch 215/1000] [Train_Loss: 0.550070 /Valid_Loss: 0.588605]
# [Epoch 215/1000] [Accuracy  : 0.741100]
# [Epoch 216/1000] [Train_Loss: 0.541926 /Valid_Loss: 0.586364]
# [Epoch 216/1000] [Accuracy  : 0.741888]
# [Epoch 217/1000] [Train_Loss: 0.555630 /Valid_Loss: 0.586251]
# [Epoch 217/1000] [Accuracy  : 0.742275]
# [Epoch 218/1000] [Train_Loss: 0.540609 /Valid_Loss: 0.587979]
# [Epoch 218/1000] [Accuracy  : 0.740775]
# [Epoch 219/1000] [Train_Loss: 0.548980 /Valid_Loss: 0.586718]
# [Epoch 219/1000] [Accuracy  : 0.741587]
# [Epoch 220/1000] [Train_Loss: 0.549133 /Valid_Loss: 0.587072]
# [Epoch 220/1000] [Accuracy  : 0.740750]
# [Epoch 221/1000] [Train_Loss: 0.559302 /Valid_Loss: 0.592600]
# [Epoch 221/1000] [Accuracy  : 0.737762]
# [Epoch 222/1000] [Train_Loss: 0.543269 /Valid_Loss: 0.589515]
# [Epoch 222/1000] [Accuracy  : 0.738175]
# [Epoch 223/1000] [Train_Loss: 0.546707 /Valid_Loss: 0.593696]
# [Epoch 223/1000] [Accuracy  : 0.737025]
# [Epoch 224/1000] [Train_Loss: 0.537086 /Valid_Loss: 0.585890]
# [Epoch 224/1000] [Accuracy  : 0.742600]
# [Epoch 225/1000] [Train_Loss: 0.537004 /Valid_Loss: 0.584180]
# [Epoch 225/1000] [Accuracy  : 0.743513]
# [Epoch 226/1000] [Train_Loss: 0.540161 /Valid_Loss: 0.591922]
# [Epoch 226/1000] [Accuracy  : 0.738637]
# [Epoch 227/1000] [Train_Loss: 0.547036 /Valid_Loss: 0.586828]
# [Epoch 227/1000] [Accuracy  : 0.741300]
# [Epoch 228/1000] [Train_Loss: 0.535122 /Valid_Loss: 0.587979]
# [Epoch 228/1000] [Accuracy  : 0.741100]
# [Epoch 229/1000] [Train_Loss: 0.534949 /Valid_Loss: 0.584550]
# [Epoch 229/1000] [Accuracy  : 0.743637]
# [Epoch 230/1000] [Train_Loss: 0.531285 /Valid_Loss: 0.587475]
# [Epoch 230/1000] [Accuracy  : 0.741550]
# [Epoch 231/1000] [Train_Loss: 0.553968 /Valid_Loss: 0.586711]
# [Epoch 231/1000] [Accuracy  : 0.742875]
# [Epoch 232/1000] [Train_Loss: 0.532120 /Valid_Loss: 0.590010]
# [Epoch 232/1000] [Accuracy  : 0.739400]
# [Epoch 233/1000] [Train_Loss: 0.530817 /Valid_Loss: 0.587315]
# [Epoch 233/1000] [Accuracy  : 0.739875]
# [Epoch 234/1000] [Train_Loss: 0.546712 /Valid_Loss: 0.585010]
# [Epoch 234/1000] [Accuracy  : 0.741200]
# [Epoch 235/1000] [Train_Loss: 0.543958 /Valid_Loss: 0.586842]
# [Epoch 235/1000] [Accuracy  : 0.741187]
# [Epoch 236/1000] [Train_Loss: 0.536141 /Valid_Loss: 0.588273]
# [Epoch 236/1000] [Accuracy  : 0.741012]
# [Epoch 237/1000] [Train_Loss: 0.535508 /Valid_Loss: 0.584279]
# [Epoch 237/1000] [Accuracy  : 0.742600]
# [Epoch 238/1000] [Train_Loss: 0.542865 /Valid_Loss: 0.590728]
# [Epoch 238/1000] [Accuracy  : 0.738962]
# [Epoch 239/1000] [Train_Loss: 0.552289 /Valid_Loss: 0.586548]
# [Epoch 239/1000] [Accuracy  : 0.741712]
# [Epoch 240/1000] [Train_Loss: 0.540920 /Valid_Loss: 0.584657]
# [Epoch 240/1000] [Accuracy  : 0.742413]
# [Epoch 241/1000] [Train_Loss: 0.531064 /Valid_Loss: 0.590669]
# [Epoch 241/1000] [Accuracy  : 0.739187]
# [Epoch 242/1000] [Train_Loss: 0.541006 /Valid_Loss: 0.585583]
# [Epoch 242/1000] [Accuracy  : 0.742675]
# [Epoch 243/1000] [Train_Loss: 0.547111 /Valid_Loss: 0.586565]
# [Epoch 243/1000] [Accuracy  : 0.742300]
# [Epoch 244/1000] [Train_Loss: 0.540400 /Valid_Loss: 0.590035]
# [Epoch 244/1000] [Accuracy  : 0.740637]
# [Epoch 245/1000] [Train_Loss: 0.541945 /Valid_Loss: 0.585341]
# [Epoch 245/1000] [Accuracy  : 0.742250]
# [Epoch 246/1000] [Train_Loss: 0.538152 /Valid_Loss: 0.584639]
# [Epoch 246/1000] [Accuracy  : 0.744138]
# [Epoch 247/1000] [Train_Loss: 0.540028 /Valid_Loss: 0.586488]
# [Epoch 247/1000] [Accuracy  : 0.742487]
# [Epoch 248/1000] [Train_Loss: 0.529834 /Valid_Loss: 0.585634]
# [Epoch 248/1000] [Accuracy  : 0.742738]
# [Epoch 249/1000] [Train_Loss: 0.547676 /Valid_Loss: 0.585329]
# [Epoch 249/1000] [Accuracy  : 0.742513]
# [Epoch 250/1000] [Train_Loss: 0.524720 /Valid_Loss: 0.586783]
# [Epoch 250/1000] [Accuracy  : 0.741950]
# [Epoch 251/1000] [Train_Loss: 0.540327 /Valid_Loss: 0.586744]
# [Epoch 251/1000] [Accuracy  : 0.741187]
# [Epoch 252/1000] [Train_Loss: 0.553421 /Valid_Loss: 0.586377]
# [Epoch 252/1000] [Accuracy  : 0.743162]
# [Epoch 253/1000] [Train_Loss: 0.521516 /Valid_Loss: 0.583718]
# [Epoch 253/1000] [Accuracy  : 0.743038]
# [Epoch 254/1000] [Train_Loss: 0.528748 /Valid_Loss: 0.588211]
# [Epoch 254/1000] [Accuracy  : 0.742700]
# [Epoch 255/1000] [Train_Loss: 0.549464 /Valid_Loss: 0.585835]
# [Epoch 255/1000] [Accuracy  : 0.741450]
# [Epoch 256/1000] [Train_Loss: 0.542558 /Valid_Loss: 0.585926]
# [Epoch 256/1000] [Accuracy  : 0.741525]
# [Epoch 257/1000] [Train_Loss: 0.513445 /Valid_Loss: 0.585318]
# [Epoch 257/1000] [Accuracy  : 0.742363]
# [Epoch 258/1000] [Train_Loss: 0.531467 /Valid_Loss: 0.584100]
# [Epoch 258/1000] [Accuracy  : 0.743125]
# [Epoch 259/1000] [Train_Loss: 0.536856 /Valid_Loss: 0.584404]
# [Epoch 259/1000] [Accuracy  : 0.743313]
# [Epoch 260/1000] [Train_Loss: 0.560149 /Valid_Loss: 0.586793]
# [Epoch 260/1000] [Accuracy  : 0.741175]
# [Epoch 261/1000] [Train_Loss: 0.532035 /Valid_Loss: 0.583038]
# [Epoch 261/1000] [Accuracy  : 0.744075]
# [Epoch 262/1000] [Train_Loss: 0.549963 /Valid_Loss: 0.588643]
# [Epoch 262/1000] [Accuracy  : 0.740025]
# [Epoch 263/1000] [Train_Loss: 0.524470 /Valid_Loss: 0.584431]
# [Epoch 263/1000] [Accuracy  : 0.742762]
# [Epoch 264/1000] [Train_Loss: 0.554794 /Valid_Loss: 0.583469]
# [Epoch 264/1000] [Accuracy  : 0.743938]
# [Epoch 265/1000] [Train_Loss: 0.527413 /Valid_Loss: 0.587738]
# [Epoch 265/1000] [Accuracy  : 0.740513]
# [Epoch 266/1000] [Train_Loss: 0.526292 /Valid_Loss: 0.582254]
# [Epoch 266/1000] [Accuracy  : 0.744062]
# [Epoch 267/1000] [Train_Loss: 0.534353 /Valid_Loss: 0.584432]
# [Epoch 267/1000] [Accuracy  : 0.742413]
# [Epoch 268/1000] [Train_Loss: 0.530141 /Valid_Loss: 0.585784]
# [Epoch 268/1000] [Accuracy  : 0.741900]
# [Epoch 269/1000] [Train_Loss: 0.526552 /Valid_Loss: 0.586676]
# [Epoch 269/1000] [Accuracy  : 0.742475]
# [Epoch 270/1000] [Train_Loss: 0.534879 /Valid_Loss: 0.587054]
# [Epoch 270/1000] [Accuracy  : 0.740788]
# [Epoch 271/1000] [Train_Loss: 0.533831 /Valid_Loss: 0.587446]
# [Epoch 271/1000] [Accuracy  : 0.741050]
# [Epoch 272/1000] [Train_Loss: 0.525658 /Valid_Loss: 0.584141]
# [Epoch 272/1000] [Accuracy  : 0.744600]
# [Epoch 273/1000] [Train_Loss: 0.543064 /Valid_Loss: 0.592414]
# [Epoch 273/1000] [Accuracy  : 0.740450]
# [Epoch 274/1000] [Train_Loss: 0.522142 /Valid_Loss: 0.583208]
# [Epoch 274/1000] [Accuracy  : 0.743463]
# [Epoch 275/1000] [Train_Loss: 0.521392 /Valid_Loss: 0.586539]
# [Epoch 275/1000] [Accuracy  : 0.743050]
# [Epoch 276/1000] [Train_Loss: 0.521528 /Valid_Loss: 0.583344]
# [Epoch 276/1000] [Accuracy  : 0.743587]
# [Epoch 277/1000] [Train_Loss: 0.510643 /Valid_Loss: 0.585939]
# [Epoch 277/1000] [Accuracy  : 0.744175]
# [Epoch 278/1000] [Train_Loss: 0.539815 /Valid_Loss: 0.584495]
# [Epoch 278/1000] [Accuracy  : 0.743450]
# [Epoch 279/1000] [Train_Loss: 0.530743 /Valid_Loss: 0.585498]
# [Epoch 279/1000] [Accuracy  : 0.742838]
# [Epoch 280/1000] [Train_Loss: 0.534998 /Valid_Loss: 0.583993]
# [Epoch 280/1000] [Accuracy  : 0.745387]
# [Epoch 281/1000] [Train_Loss: 0.526611 /Valid_Loss: 0.586477]
# [Epoch 281/1000] [Accuracy  : 0.741925]
# [Epoch 282/1000] [Train_Loss: 0.548443 /Valid_Loss: 0.584731]
# [Epoch 282/1000] [Accuracy  : 0.744550]
# [Epoch 283/1000] [Train_Loss: 0.525877 /Valid_Loss: 0.583899]
# [Epoch 283/1000] [Accuracy  : 0.744313]
# [Epoch 284/1000] [Train_Loss: 0.537484 /Valid_Loss: 0.586093]
# [Epoch 284/1000] [Accuracy  : 0.744062]
# [Epoch 285/1000] [Train_Loss: 0.537354 /Valid_Loss: 0.585555]
# [Epoch 285/1000] [Accuracy  : 0.743563]
# [Epoch 286/1000] [Train_Loss: 0.526986 /Valid_Loss: 0.584330]
# [Epoch 286/1000] [Accuracy  : 0.744025]
# [Epoch 287/1000] [Train_Loss: 0.540002 /Valid_Loss: 0.582406]
# [Epoch 287/1000] [Accuracy  : 0.745537]
# [Epoch 288/1000] [Train_Loss: 0.531136 /Valid_Loss: 0.585549]
# [Epoch 288/1000] [Accuracy  : 0.742250]
# [Epoch 289/1000] [Train_Loss: 0.516558 /Valid_Loss: 0.588412]
# [Epoch 289/1000] [Accuracy  : 0.741263]
# [Epoch 290/1000] [Train_Loss: 0.544887 /Valid_Loss: 0.583026]
# [Epoch 290/1000] [Accuracy  : 0.745600]
# [Epoch 291/1000] [Train_Loss: 0.544945 /Valid_Loss: 0.588179]
# [Epoch 291/1000] [Accuracy  : 0.740700]
# [Epoch 292/1000] [Train_Loss: 0.528325 /Valid_Loss: 0.585209]
# [Epoch 292/1000] [Accuracy  : 0.742012]
# [Epoch 293/1000] [Train_Loss: 0.527980 /Valid_Loss: 0.585488]
# [Epoch 293/1000] [Accuracy  : 0.744400]
# [Epoch 294/1000] [Train_Loss: 0.519332 /Valid_Loss: 0.582259]
# [Epoch 294/1000] [Accuracy  : 0.746375]
# [Epoch 295/1000] [Train_Loss: 0.514725 /Valid_Loss: 0.584581]
# [Epoch 295/1000] [Accuracy  : 0.742788]
# [Epoch 296/1000] [Train_Loss: 0.507994 /Valid_Loss: 0.584113]
# [Epoch 296/1000] [Accuracy  : 0.744175]
# [Epoch 297/1000] [Train_Loss: 0.548726 /Valid_Loss: 0.583012]
# [Epoch 297/1000] [Accuracy  : 0.744250]
# [Epoch 298/1000] [Train_Loss: 0.516831 /Valid_Loss: 0.584783]
# [Epoch 298/1000] [Accuracy  : 0.746062]
# [Epoch 299/1000] [Train_Loss: 0.530863 /Valid_Loss: 0.583001]
# [Epoch 299/1000] [Accuracy  : 0.745175]
# [Epoch 300/1000] [Train_Loss: 0.539074 /Valid_Loss: 0.583376]
# [Epoch 300/1000] [Accuracy  : 0.744012]
# [Epoch 301/1000] [Train_Loss: 0.526695 /Valid_Loss: 0.583969]
# [Epoch 301/1000] [Accuracy  : 0.745450]
# [Epoch 302/1000] [Train_Loss: 0.530709 /Valid_Loss: 0.588422]
# [Epoch 302/1000] [Accuracy  : 0.741088]
# [Epoch 303/1000] [Train_Loss: 0.532411 /Valid_Loss: 0.583241]
# [Epoch 303/1000] [Accuracy  : 0.744062]
# [Epoch 304/1000] [Train_Loss: 0.532572 /Valid_Loss: 0.588142]
# [Epoch 304/1000] [Accuracy  : 0.741125]
# [Epoch 305/1000] [Train_Loss: 0.543133 /Valid_Loss: 0.583745]
# [Epoch 305/1000] [Accuracy  : 0.743912]
# [Epoch 306/1000] [Train_Loss: 0.537490 /Valid_Loss: 0.583745]
# [Epoch 306/1000] [Accuracy  : 0.744625]
# [Epoch 307/1000] [Train_Loss: 0.529083 /Valid_Loss: 0.587519]
# [Epoch 307/1000] [Accuracy  : 0.742962]
# [Epoch 308/1000] [Train_Loss: 0.528027 /Valid_Loss: 0.587300]
# [Epoch 308/1000] [Accuracy  : 0.741100]
# [Epoch 309/1000] [Train_Loss: 0.518798 /Valid_Loss: 0.582947]
# [Epoch 309/1000] [Accuracy  : 0.745962]
# [Epoch 310/1000] [Train_Loss: 0.543106 /Valid_Loss: 0.585274]
# [Epoch 310/1000] [Accuracy  : 0.743762]
# [Epoch 311/1000] [Train_Loss: 0.526358 /Valid_Loss: 0.583082]
# [Epoch 311/1000] [Accuracy  : 0.744413]
# [Epoch 312/1000] [Train_Loss: 0.515022 /Valid_Loss: 0.584214]
# [Epoch 312/1000] [Accuracy  : 0.745475]
# [Epoch 313/1000] [Train_Loss: 0.525312 /Valid_Loss: 0.584221]
# [Epoch 313/1000] [Accuracy  : 0.743500]
# [Epoch 314/1000] [Train_Loss: 0.539226 /Valid_Loss: 0.583037]
# [Epoch 314/1000] [Accuracy  : 0.744762]
# [Epoch 315/1000] [Train_Loss: 0.538023 /Valid_Loss: 0.588543]
# [Epoch 315/1000] [Accuracy  : 0.741575]
# [Epoch 316/1000] [Train_Loss: 0.537254 /Valid_Loss: 0.585080]
# [Epoch 316/1000] [Accuracy  : 0.744625]
# [Epoch 317/1000] [Train_Loss: 0.524950 /Valid_Loss: 0.583738]
# [Epoch 317/1000] [Accuracy  : 0.744062]
# [Epoch 318/1000] [Train_Loss: 0.553740 /Valid_Loss: 0.581109]
# [Epoch 318/1000] [Accuracy  : 0.746900]
# [Epoch 319/1000] [Train_Loss: 0.534215 /Valid_Loss: 0.582520]
# [Epoch 319/1000] [Accuracy  : 0.746563]
# [Epoch 320/1000] [Train_Loss: 0.530203 /Valid_Loss: 0.584747]
# [Epoch 320/1000] [Accuracy  : 0.744263]
# [Epoch 321/1000] [Train_Loss: 0.515156 /Valid_Loss: 0.583688]
# [Epoch 321/1000] [Accuracy  : 0.744038]
# [Epoch 322/1000] [Train_Loss: 0.540837 /Valid_Loss: 0.587517]
# [Epoch 322/1000] [Accuracy  : 0.743463]
# [Epoch 323/1000] [Train_Loss: 0.516009 /Valid_Loss: 0.584089]
# [Epoch 323/1000] [Accuracy  : 0.744175]
# [Epoch 324/1000] [Train_Loss: 0.527281 /Valid_Loss: 0.588199]
# [Epoch 324/1000] [Accuracy  : 0.741112]
# [Epoch 325/1000] [Train_Loss: 0.527861 /Valid_Loss: 0.583322]
# [Epoch 325/1000] [Accuracy  : 0.744912]
# [Epoch 326/1000] [Train_Loss: 0.534271 /Valid_Loss: 0.584469]
# [Epoch 326/1000] [Accuracy  : 0.743875]
# [Epoch 327/1000] [Train_Loss: 0.516371 /Valid_Loss: 0.585695]
# [Epoch 327/1000] [Accuracy  : 0.742225]
# [Epoch 328/1000] [Train_Loss: 0.512302 /Valid_Loss: 0.584118]
# [Epoch 328/1000] [Accuracy  : 0.744725]
# [Epoch 329/1000] [Train_Loss: 0.529985 /Valid_Loss: 0.585062]
# [Epoch 329/1000] [Accuracy  : 0.744587]
# [Epoch 330/1000] [Train_Loss: 0.526700 /Valid_Loss: 0.585270]
# [Epoch 330/1000] [Accuracy  : 0.742788]
# [Epoch 331/1000] [Train_Loss: 0.518135 /Valid_Loss: 0.581750]
# [Epoch 331/1000] [Accuracy  : 0.746537]
# [Epoch 332/1000] [Train_Loss: 0.528448 /Valid_Loss: 0.583341]
# [Epoch 332/1000] [Accuracy  : 0.744938]
# [Epoch 333/1000] [Train_Loss: 0.517316 /Valid_Loss: 0.583799]
# [Epoch 333/1000] [Accuracy  : 0.745012]
# [Epoch 334/1000] [Train_Loss: 0.521650 /Valid_Loss: 0.586912]
# [Epoch 334/1000] [Accuracy  : 0.743775]
# [Epoch 335/1000] [Train_Loss: 0.526132 /Valid_Loss: 0.586576]
# [Epoch 335/1000] [Accuracy  : 0.743112]
# [Epoch 336/1000] [Train_Loss: 0.513482 /Valid_Loss: 0.583200]
# [Epoch 336/1000] [Accuracy  : 0.744513]
# [Epoch 337/1000] [Train_Loss: 0.531511 /Valid_Loss: 0.581723]
# [Epoch 337/1000] [Accuracy  : 0.745513]
# [Epoch 338/1000] [Train_Loss: 0.509678 /Valid_Loss: 0.587719]
# [Epoch 338/1000] [Accuracy  : 0.741788]
# [Epoch 339/1000] [Train_Loss: 0.525119 /Valid_Loss: 0.581410]
# [Epoch 339/1000] [Accuracy  : 0.745513]
# [Epoch 340/1000] [Train_Loss: 0.526965 /Valid_Loss: 0.582798]
# [Epoch 340/1000] [Accuracy  : 0.745350]
# [Epoch 341/1000] [Train_Loss: 0.527679 /Valid_Loss: 0.580644]
# [Epoch 341/1000] [Accuracy  : 0.746687]
# [Epoch 342/1000] [Train_Loss: 0.533422 /Valid_Loss: 0.587582]
# [Epoch 342/1000] [Accuracy  : 0.741675]
# [Epoch 343/1000] [Train_Loss: 0.523840 /Valid_Loss: 0.582051]
# [Epoch 343/1000] [Accuracy  : 0.745625]
# [Epoch 344/1000] [Train_Loss: 0.527249 /Valid_Loss: 0.584741]
# [Epoch 344/1000] [Accuracy  : 0.744850]
# [Epoch 345/1000] [Train_Loss: 0.515710 /Valid_Loss: 0.583406]
# [Epoch 345/1000] [Accuracy  : 0.746313]
# [Epoch 346/1000] [Train_Loss: 0.522025 /Valid_Loss: 0.587793]
# [Epoch 346/1000] [Accuracy  : 0.740725]
# [Epoch 347/1000] [Train_Loss: 0.526402 /Valid_Loss: 0.581290]
# [Epoch 347/1000] [Accuracy  : 0.747150]
# [Epoch 348/1000] [Train_Loss: 0.511959 /Valid_Loss: 0.583528]
# [Epoch 348/1000] [Accuracy  : 0.744762]
# [Epoch 349/1000] [Train_Loss: 0.535387 /Valid_Loss: 0.582533]
# [Epoch 349/1000] [Accuracy  : 0.745988]
# [Epoch 350/1000] [Train_Loss: 0.534312 /Valid_Loss: 0.584821]
# [Epoch 350/1000] [Accuracy  : 0.743812]
# [Epoch 351/1000] [Train_Loss: 0.516058 /Valid_Loss: 0.581601]
# [Epoch 351/1000] [Accuracy  : 0.745450]
# [Epoch 352/1000] [Train_Loss: 0.541273 /Valid_Loss: 0.583676]
# [Epoch 352/1000] [Accuracy  : 0.744188]
# [Epoch 353/1000] [Train_Loss: 0.520173 /Valid_Loss: 0.584856]
# [Epoch 353/1000] [Accuracy  : 0.744663]
# [Epoch 354/1000] [Train_Loss: 0.533530 /Valid_Loss: 0.584941]
# [Epoch 354/1000] [Accuracy  : 0.743075]
# [Epoch 355/1000] [Train_Loss: 0.523927 /Valid_Loss: 0.586136]
# [Epoch 355/1000] [Accuracy  : 0.744500]
# [Epoch 356/1000] [Train_Loss: 0.520853 /Valid_Loss: 0.583202]
# [Epoch 356/1000] [Accuracy  : 0.744925]
# [Epoch 357/1000] [Train_Loss: 0.526808 /Valid_Loss: 0.584549]
# [Epoch 357/1000] [Accuracy  : 0.744250]
# [Epoch 358/1000] [Train_Loss: 0.506994 /Valid_Loss: 0.585049]
# [Epoch 358/1000] [Accuracy  : 0.744100]
# [Epoch 359/1000] [Train_Loss: 0.527347 /Valid_Loss: 0.580342]
# [Epoch 359/1000] [Accuracy  : 0.746237]
# [Epoch 360/1000] [Train_Loss: 0.520164 /Valid_Loss: 0.584262]
# [Epoch 360/1000] [Accuracy  : 0.745637]
# [Epoch 361/1000] [Train_Loss: 0.510666 /Valid_Loss: 0.582569]
# [Epoch 361/1000] [Accuracy  : 0.746613]
# [Epoch 362/1000] [Train_Loss: 0.525700 /Valid_Loss: 0.581767]
# [Epoch 362/1000] [Accuracy  : 0.745762]
# [Epoch 363/1000] [Train_Loss: 0.530722 /Valid_Loss: 0.583597]
# [Epoch 363/1000] [Accuracy  : 0.744138]
# [Epoch 364/1000] [Train_Loss: 0.533701 /Valid_Loss: 0.587779]
# [Epoch 364/1000] [Accuracy  : 0.742337]
# [Epoch 365/1000] [Train_Loss: 0.515539 /Valid_Loss: 0.581985]
# [Epoch 365/1000] [Accuracy  : 0.745263]
# [Epoch 366/1000] [Train_Loss: 0.521662 /Valid_Loss: 0.582029]
# [Epoch 366/1000] [Accuracy  : 0.746400]
# [Epoch 367/1000] [Train_Loss: 0.536472 /Valid_Loss: 0.585811]
# [Epoch 367/1000] [Accuracy  : 0.742563]
# [Epoch 368/1000] [Train_Loss: 0.520118 /Valid_Loss: 0.584933]
# [Epoch 368/1000] [Accuracy  : 0.745275]
# [Epoch 369/1000] [Train_Loss: 0.541771 /Valid_Loss: 0.582213]
# [Epoch 369/1000] [Accuracy  : 0.746363]
# [Epoch 370/1000] [Train_Loss: 0.515922 /Valid_Loss: 0.581687]
# [Epoch 370/1000] [Accuracy  : 0.746587]
# [Epoch 371/1000] [Train_Loss: 0.512082 /Valid_Loss: 0.586336]
# [Epoch 371/1000] [Accuracy  : 0.743625]
# [Epoch 372/1000] [Train_Loss: 0.507101 /Valid_Loss: 0.580936]
# [Epoch 372/1000] [Accuracy  : 0.746463]
# [Epoch 373/1000] [Train_Loss: 0.547603 /Valid_Loss: 0.582073]
# [Epoch 373/1000] [Accuracy  : 0.747162]
# [Epoch 374/1000] [Train_Loss: 0.526546 /Valid_Loss: 0.585890]
# [Epoch 374/1000] [Accuracy  : 0.742775]
# [Epoch 375/1000] [Train_Loss: 0.523332 /Valid_Loss: 0.581368]
# [Epoch 375/1000] [Accuracy  : 0.746375]
# [Epoch 376/1000] [Train_Loss: 0.513462 /Valid_Loss: 0.579935]
# [Epoch 376/1000] [Accuracy  : 0.748150]
# [Epoch 377/1000] [Train_Loss: 0.509377 /Valid_Loss: 0.586842]
# [Epoch 377/1000] [Accuracy  : 0.743125]
# [Epoch 378/1000] [Train_Loss: 0.510807 /Valid_Loss: 0.584829]
# [Epoch 378/1000] [Accuracy  : 0.743287]
# [Epoch 379/1000] [Train_Loss: 0.526156 /Valid_Loss: 0.585827]
# [Epoch 379/1000] [Accuracy  : 0.743637]
# [Epoch 380/1000] [Train_Loss: 0.528950 /Valid_Loss: 0.581336]
# [Epoch 380/1000] [Accuracy  : 0.746263]
# [Epoch 381/1000] [Train_Loss: 0.519486 /Valid_Loss: 0.584816]
# [Epoch 381/1000] [Accuracy  : 0.744788]
# [Epoch 382/1000] [Train_Loss: 0.530250 /Valid_Loss: 0.581558]
# [Epoch 382/1000] [Accuracy  : 0.747450]
# [Epoch 383/1000] [Train_Loss: 0.542688 /Valid_Loss: 0.583121]
# [Epoch 383/1000] [Accuracy  : 0.746038]
# [Epoch 384/1000] [Train_Loss: 0.523832 /Valid_Loss: 0.583471]
# [Epoch 384/1000] [Accuracy  : 0.745300]
# [Epoch 385/1000] [Train_Loss: 0.529245 /Valid_Loss: 0.580254]
# [Epoch 385/1000] [Accuracy  : 0.746862]
# [Epoch 386/1000] [Train_Loss: 0.520369 /Valid_Loss: 0.579785]
# [Epoch 386/1000] [Accuracy  : 0.747012]
# [Epoch 387/1000] [Train_Loss: 0.538363 /Valid_Loss: 0.581058]
# [Epoch 387/1000] [Accuracy  : 0.747088]
# [Epoch 388/1000] [Train_Loss: 0.522642 /Valid_Loss: 0.580284]
# [Epoch 388/1000] [Accuracy  : 0.747463]
# [Epoch 389/1000] [Train_Loss: 0.504452 /Valid_Loss: 0.584552]
# [Epoch 389/1000] [Accuracy  : 0.745088]
# [Epoch 390/1000] [Train_Loss: 0.516629 /Valid_Loss: 0.582145]
# [Epoch 390/1000] [Accuracy  : 0.746713]
# [Epoch 391/1000] [Train_Loss: 0.527466 /Valid_Loss: 0.583638]
# [Epoch 391/1000] [Accuracy  : 0.746387]
# [Epoch 392/1000] [Train_Loss: 0.515434 /Valid_Loss: 0.582459]
# [Epoch 392/1000] [Accuracy  : 0.746600]
# [Epoch 393/1000] [Train_Loss: 0.525214 /Valid_Loss: 0.581292]
# [Epoch 393/1000] [Accuracy  : 0.745237]
# [Epoch 394/1000] [Train_Loss: 0.521877 /Valid_Loss: 0.582833]
# [Epoch 394/1000] [Accuracy  : 0.746962]
# [Epoch 395/1000] [Train_Loss: 0.507903 /Valid_Loss: 0.583075]
# [Epoch 395/1000] [Accuracy  : 0.745175]
# [Epoch 396/1000] [Train_Loss: 0.541220 /Valid_Loss: 0.582929]
# [Epoch 396/1000] [Accuracy  : 0.746600]
# [Epoch 397/1000] [Train_Loss: 0.530837 /Valid_Loss: 0.580329]
# [Epoch 397/1000] [Accuracy  : 0.747400]
# [Epoch 398/1000] [Train_Loss: 0.538224 /Valid_Loss: 0.588308]
# [Epoch 398/1000] [Accuracy  : 0.741363]
# [Epoch 399/1000] [Train_Loss: 0.538942 /Valid_Loss: 0.582590]
# [Epoch 399/1000] [Accuracy  : 0.745563]
# [Epoch 400/1000] [Train_Loss: 0.513362 /Valid_Loss: 0.586186]
# [Epoch 400/1000] [Accuracy  : 0.742637]
# [Epoch 401/1000] [Train_Loss: 0.517903 /Valid_Loss: 0.582178]
# [Epoch 401/1000] [Accuracy  : 0.745587]
# [Epoch 402/1000] [Train_Loss: 0.536957 /Valid_Loss: 0.581649]
# [Epoch 402/1000] [Accuracy  : 0.746475]
# [Epoch 403/1000] [Train_Loss: 0.556956 /Valid_Loss: 0.581957]
# [Epoch 403/1000] [Accuracy  : 0.745900]
# [Epoch 404/1000] [Train_Loss: 0.531792 /Valid_Loss: 0.580586]
# [Epoch 404/1000] [Accuracy  : 0.747000]
# [Epoch 405/1000] [Train_Loss: 0.529451 /Valid_Loss: 0.580443]
# [Epoch 405/1000] [Accuracy  : 0.746988]
# [Epoch 406/1000] [Train_Loss: 0.499825 /Valid_Loss: 0.583870]
# [Epoch 406/1000] [Accuracy  : 0.744587]
# [Epoch 407/1000] [Train_Loss: 0.524963 /Valid_Loss: 0.581710]
# [Epoch 407/1000] [Accuracy  : 0.745450]
# [Epoch 408/1000] [Train_Loss: 0.542491 /Valid_Loss: 0.581709]
# [Epoch 408/1000] [Accuracy  : 0.746938]
# [Epoch 409/1000] [Train_Loss: 0.512048 /Valid_Loss: 0.581932]
# [Epoch 409/1000] [Accuracy  : 0.746713]
# [Epoch 410/1000] [Train_Loss: 0.532867 /Valid_Loss: 0.582389]
# [Epoch 410/1000] [Accuracy  : 0.745275]
# [Epoch 411/1000] [Train_Loss: 0.533223 /Valid_Loss: 0.580747]
# [Epoch 411/1000] [Accuracy  : 0.747200]
# [Epoch 412/1000] [Train_Loss: 0.517856 /Valid_Loss: 0.580721]
# [Epoch 412/1000] [Accuracy  : 0.747112]
# [Epoch 413/1000] [Train_Loss: 0.506783 /Valid_Loss: 0.581975]
# [Epoch 413/1000] [Accuracy  : 0.745600]
# [Epoch 414/1000] [Train_Loss: 0.524820 /Valid_Loss: 0.581207]
# [Epoch 414/1000] [Accuracy  : 0.747350]
# [Epoch 415/1000] [Train_Loss: 0.524317 /Valid_Loss: 0.586959]
# [Epoch 415/1000] [Accuracy  : 0.742838]
# [Epoch 416/1000] [Train_Loss: 0.532977 /Valid_Loss: 0.586375]
# [Epoch 416/1000] [Accuracy  : 0.743687]
# [Epoch 417/1000] [Train_Loss: 0.517173 /Valid_Loss: 0.585064]
# [Epoch 417/1000] [Accuracy  : 0.744300]
# [Epoch 418/1000] [Train_Loss: 0.525499 /Valid_Loss: 0.580092]
# [Epoch 418/1000] [Accuracy  : 0.747600]
# [Epoch 419/1000] [Train_Loss: 0.531688 /Valid_Loss: 0.581921]
# [Epoch 419/1000] [Accuracy  : 0.746862]
# [Epoch 420/1000] [Train_Loss: 0.525642 /Valid_Loss: 0.584272]
# [Epoch 420/1000] [Accuracy  : 0.745500]
# [Epoch 421/1000] [Train_Loss: 0.518520 /Valid_Loss: 0.581089]
# [Epoch 421/1000] [Accuracy  : 0.746225]
# [Epoch 422/1000] [Train_Loss: 0.518644 /Valid_Loss: 0.582272]
# [Epoch 422/1000] [Accuracy  : 0.746375]
# [Epoch 423/1000] [Train_Loss: 0.530765 /Valid_Loss: 0.586305]
# [Epoch 423/1000] [Accuracy  : 0.742463]
# [Epoch 424/1000] [Train_Loss: 0.504307 /Valid_Loss: 0.583694]
# [Epoch 424/1000] [Accuracy  : 0.745088]
# [Epoch 425/1000] [Train_Loss: 0.511954 /Valid_Loss: 0.582207]
# [Epoch 425/1000] [Accuracy  : 0.745287]
# [Epoch 426/1000] [Train_Loss: 0.525891 /Valid_Loss: 0.581002]
# [Epoch 426/1000] [Accuracy  : 0.746637]
# [Epoch 427/1000] [Train_Loss: 0.514054 /Valid_Loss: 0.583159]
# [Epoch 427/1000] [Accuracy  : 0.745413]
# This is time to do early stopping
# 모델 저장: /content/gdrive/My Drive/Colab Notebooks/kamp/14. Dataset_Rotor/rnn_model.pt
